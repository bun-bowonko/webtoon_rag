# %%
import re
from langchain_community.vectorstores import FAISS
from langchain.docstore.document import Document
import bs4
import ssl
import urllib3
import pandas as pd
import faiss
import os
from langchain.embeddings import HuggingFaceEmbeddings
import torch
import gc

def instruct_structure(prompt):
    input_text, output_text = prompt.split('### target')
    input_text = input_text.replace('### glossaries', '### glossary').replace('\n* ', '\n• ')
    input_text = re.sub(r"\[[^\]]+\] ", "[UNK] ", input_text)
    return input_text


project_id = "prod-ai-project"

from google.cloud import bigquery
client = bigquery.Client(project=project_id)
sql = """select series_id, episode_id, org_input_text, org_output_text, prompt 
        from webtoon_translation.structured_240820_ep_line
        where data_split = 'romance_valid'"""
df = client.query(sql).result().to_dataframe()
from tqdm import tqdm
tqdm.pandas()
df['prompt'] = df['prompt'].progress_apply(lambda x: instruct_structure(x))
# Out:
# /home/bun.2/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/google/cloud/bigquery/table.py:1820: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 74/74 [00:00<00:00, 19469.23it/s]

# %%
data_idx = 11
data = df['prompt'][data_idx]
example = data.split("### source")[1].strip()
#print(example)

# %%
from openai import OpenAI
GPT_FINE_TUNING_MODEL="ft:gpt-4o-2024-08-06:kakaoent:webtoon-sft-250225:B4j839q0"
openai_client = OpenAI(
    api_key='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')
#example_li = example.split('\n')

GPT_BASE_MODEL = "chatgpt-4o-latest"

# %%
print(data)
# Out:
# ### glossary
# • 마법사: mage / sorcerer
# • 피오나 (F): fiona
# • 아벨 헤일론 (M): abel heylon
# • 아벨 (M): abel
# • 용병: mercenaries
#
# ### source
# 000	[UNK] 그럼 다들 얌전해졌으니 ….
# 001	[UNK] 마저 절차를 밟겠습니다.
# 002	[UNK] …3일 전, 술집에서 행패.
# 003	[UNK] 남성 5인 폭행 및 금품 상당수 갈취….
# 004	[UNK] 저 녀석….
# 005	[UNK] 2 성벽에서 싸우는 마법사란 건-
# 006	[UNK] 진짜였구나.
# 007	[UNK] 그것도 다른 마법사들과는 차원이 달라.
# 008	[UNK] 손에서 주먹만 한 불덩이를 만드는 건 봤어도,
# 009	[UNK] 피오나처럼 저 정도 현상을 만드는 마법사는 처음이야.
# 010	[UNK] 헤일론 공작이 데리고 있는 이유를 알 것 같아.
# 011	[UNK] 또 이 주 전에는….
# 012	[UNK] 그리고….
# 013	[UNK] 무엇을 노렸는지도.
# 014	[UNK] 우락부락한 체격의 남자 앞에 당당히 선 작은 소녀.
# 015	[UNK] 여기서 무슨 일이 생기든,
# 016	[UNK] 사람들은 이 모습을 똑똑히 기억할게 틀림없다.
# 017	[UNK] 피오나는 사람들에게 평범한 소녀가 아니라고 각인될 것이고
# 018	[UNK] 그 소문은 영지 전체에 퍼져나갈 것이다.
# 019	[UNK] 게다가
# 020	[UNK] 헤일론 성에서 피오나의 대우는 단순히 귀한 병사라기엔 매우 좋다.
# 021	[UNK] 으음~ 맛있어!
# 022	[UNK] 아가씨. 좋아하시는 책들 가져왔어요.
# 023	[UNK] …공작이 아무런 이유 없이 그럴 남자가 아닌데.
# 024	[UNK] 아벨 헤일론 공작이 피오나에게 원하는 건 대체 뭘까?
# 025	[UNK] …하지만 내가 이 문제에 대한 답을 알 수 있을까.
# 026	[UNK] 나는 용병단의 널리고 널린 고아 소년이야.
# 027	[UNK] 피오나를 위해 할 수 있는 일은 없겠지….
# 028	[UNK] 이후에 피오나의 얼굴이나 볼 수 있을까?
# 029	[UNK] 친구가 되자고는 했지만,
# 030	[UNK] 성으로 돌아가면 나 같은 건 잊어버릴지도 몰라….
# 031	[UNK] -해서 여러분에게 두 가지 선택지를 드리겠습니다.
# 032	[UNK] 첫 번째는 맨몸으로 성벽 밖으로 나가는 것.
# 033	[UNK] 뭐, 뭐라고?!
# 034	[UNK] 두 번째로는….
# 035	[UNK] 그 부분.
# 036	[UNK] 자르세요.
# 037	[UNK] 뭐어어?!
# 038	[UNK] 어라….
# 039	[UNK] 설마 이 정도 처벌도 예상 못한 걸까?
# 040	[UNK] 물론 저도 여러분께 최소한의 자비는 줄 예정이랍니다.
# 041	[UNK] 밖으로 나가던지, 자르던지.
# 042	[UNK] 선택은 여러분의 몫입니다.
# 043	[UNK] 크으으윽….
# 044	[UNK] 웃기지 마! 우리가 왜 그런 꼴을 당해야 해?!
# 045	[UNK] 하여간 야만적이고 미개한 북부 놈들하고는 상종을 하면 안 돼….
# 046	[UNK] 우리 용병들이 없으면 마물 배 속에나 들어가 있을 것들이!
# 047	[UNK] 저게….
# 048	[UNK] …헤일론 영지는 용병들에게 위험에 상응하는 금액을 치릅니다.
# 049	[UNK] 아벨은 냉정하지만 공정하다.
# 050	[UNK] 마물을 잡는 위험을 감수하는 만큼 보수를 지불한다.
# 051	[UNK] 게다가 용병들에겐 마물의 사체에서 얻을 수 있는 재료도 있다.
# 052	[UNK] 그걸 팔면 종에 따라 많은 수익을 얻을 수도 있다.
# 053	[UNK] 결국 각자의 이득을 좇아 모여 있다는 뜻이다.
# 054	[UNK] 헤일론은 영지를 지킬 무력이 필요하고
# 055	[UNK] 용병들은 돈이 필요했기에.
# 056	[UNK] …계속 선택을 거부하겠다면,
# 057	[UNK] 제가 임의로 고르겠습니다.
# 058	[UNK] 당장 이거 풀지 못해?!
# 059	[UNK] 추운 날씨에 광장에 모인 사람들을 위해서도 빨리 끝내자.
# 060	[UNK] …사실은 나도 아까부터 몸이 떨려.
# 061	[UNK] 사람들도 왠지 조용하고.
# 062	[UNK] 기분탓인지 주위 온도가 2도쯤 내려간 것 같은데….
# 063	[UNK] 무엇을 선택하겠다는 거지?
# 064	[UNK] 아….
# 065	[UNK] 아벨?!
# 066	[UNK] 온도가 내려간 이유가 여기 있었군!
# 067	[UNK] 등장만으로도 냉기가 휘몰아치는 것 같다….
# 068	[UNK] 공작님, 왜 여기 계세요?
# 069	[UNK] 내 영지를 돌아보는데 이유가 필요하지는 않겠지.
# 070	[UNK] 미안해요….
# 071	[UNK] 그러신가요….
# 072	[UNK] 앗!
# 073	[UNK] 그래서 저놈들에게 어떤 선택권을 준 거지?
# 074	[UNK] 그….
# 075	[UNK] 혹시나 해서 묻는 건데,
# 076	[UNK] 어디서부터 들으신 거예요?
# 077	[UNK] 훗….
# 078	[UNK] ‘이 야만적이고 미개한 북부 놈들’ 부터다.
# 079	[UNK] 아…. 쟤들은 망했네.
# 080	[UNK] 운이 좋으면 반죽음으로 끝났을 텐데.
# 081	[UNK] 두 가지 중에 선택하라고 했어요.
# 082	[UNK] 맨몸으로 성벽 밖으로 나가는 것과,
# 083	[UNK] 그…. 번식 기능이 있는 신체를 자르는 거.
# 084	[UNK] 둘 다 마음에 드는군.
# 085	[UNK] 그런데 왜 선택권을 준거지?
# 086	[UNK] 그야…. 둘 다 하는 건 가혹해 보이니까,
# 087	[UNK] 나름의 배려? 였죠.
# 088	[UNK] 쓸데없는 배려다.
# 089	[UNK] 피오나, 내가 늘 말했었지.
# 090	[UNK] 이 헤일론에서 감히 내 영지민에게 손을 대는 버러지들은….
# 091	[UNK] 윽?!
# 092	[UNK] …필요 없다고.
# 093	[UNK] 으아악…
# 094	[UNK] 안겨있는 나도 소름이 돋을 정도의 살기야….
# 095	[UNK] 감히 내가 다스리는 영지를 야만적이라 칭했으니,
# 096	[UNK] 그 기대에 응해 주는 게 예의겠지.
# 097	[UNK] 처벌은 두 가지를 다 적용해라.
# 098	[UNK] 죄의 원인이 된 신체 부위는 자르고,
# 099	[UNK] 그 후에 성벽 밖으로 쫓아내도록.
# 100	[UNK] 그럼, 집행을 시작해라.
# 101	[UNK] 예!
# 102	[UNK] 피오나.
# 103	[UNK] 다음부터 쓸데없는 고민은 하지 말거라.
# 104	[UNK] 일단 사람 목숨이 왔다 갔다 하는 결정이었던 것 같은데….
# 105	[UNK] 알겠습니다.
# 106	[UNK] 아벨, 이 위험한 녀석.
# 107	[UNK] …어?
# 108	[UNK] 그래서 결국, 이 성격 더러운 아벨이 왜 굳이 여기까지 온 거지?

# %%
SYSTEM_PROMPT = {
            "role": "system",
            "content": [
                {
                    "type": "text",
                    "text": """You're an expert translator who translates Korean webtoon in English. Make sure the number of target sentences matches the number of source sentences. The result should be TSV formatted. 
            • Find a balance between staying true to the Korean meaning and keeping a natural flow. Don't be afraid to add to the text. Embellish it. 
            • Avoid translating word-for-word. Keep the general feeling and translate the text accordingly. 
            • Translate with an American audience in mind. This means easy-to-read, conversational English.""",
                }
            ],
        }

chat_completion = openai_client.beta.chat.completions.parse(
    model= GPT_FINE_TUNING_MODEL,
    messages = [
        SYSTEM_PROMPT,
        {
            "role":"user",
            "content" : [{"type" : "text",
                          "text" : data
                        }],
        }
    ],
    temperature= 0.2,
    top_p = 0.8
)
response = chat_completion.choices[0].message.content

# %%
#inference 결과
#print(response)

# %%
response_split = response.split('\n')
source = data.split("### source")[1].strip()
glossary = data.split("### source")[0].strip()

# %%
def clean_text(text):
    return text.replace("[UNK] ","") 
#print(clean_text(source))

# %%
kor = clean_text(source)
en = response
input_text = f"[한국어 대화문]\n{kor}\n\n[1차 번역문]\n{en}\n\n[단어집]\n{glossary}"
#print(input_text)

# %%
GPT_BASE_MODEL = "chatgpt-4o-latest"
SYSTEM_REVIEW_PROMPT = {
            "role": "system",
            "content": [
                {
                    "type": "text",
                    "text": "너는 [한국어 대화문] 내의 연결된 대사들을 분석하고 이를 [대사 문단]으로 정의한 뒤, [1차 번역문] 상에서 [대사 문단]에 속한 원소들이 잘 번역되어 있는지 확인하는 태스크를 수행할거야. \
                    그리고 만약 [1차 번역문]이 잘못된 경우, 이를 수정해서 재생성하는 태스크를 수행할 거야. \
                    먼저 맥락을 이해하기 위해 한 회차의 모든 [한국어 대화문]이 주어지고, \
                    이를 1차 번역한 [1차 번역문]이 주어질거야. \
                    각 대사에는 번호가 붙어 있을 것이고, 같은 번호는 같은 문장을 지칭해. 즉 [한국어 대화문]의 005번 대사를 번역한 것은 [1차 번역문]의 005번 대사라고 생각하면 돼.\
                    지금부터 너는 [한국어 대화문]에서 동일한 한 명의 화자가 발화한 이어진 대사를 구별해내고,\
                    이 대사들이 결합되어 한 문장을 구성할 수 있는지 확인해. 그리고 이를 [대사 문단]에 넣고, \
                    추후에 [대사 문단]에 넣은 대사들이 [1차 번역문] 상에서 올바르게 번역되어 있는지 검수한 후, \
                    올바르게 번역되지 않았다면 [단어집]과 [대사 문단]의 각 원소를 참고해서 새롭게 번역하고, \
                    올바르게 번역 되어있다면 [1차 번역문]에 있는 그대로 생성할거야.\n\
                    \
                    먼저 배경지식을 알려주자면 웹툰에서 '...','…'은 이전 대사나 이후 대사와의 연결을 의미할 가능성이 커. 100%는 아니야. \
                    다시 말해서 '...','…'으로 시작하면 이전 대사와 현재 대사가 연결되어 있을 가능성이 크고, \
                    '...','…'으로 끝나면 다음 대사와 현재 대사가 연결되어 있을 가능성이 커.\
                    그리고 '(호칭 혹은 이름),' + '대사' 형태로 이어지는 경우도 많아\n\
                    \
                    태스크를 올바르게 수행하기 위해서 너는 첫 번째로 [대사 문단]을 찾아야해. \
                    [대사 문단]이란 [한국어 대화문] 내에서 동일한 한 명의 화자가 발화하는 연속되는 대사가 '모두 불완전한 대사'이거나, \
                    '2개 이상의 불완전한 대사와 불완전한 대사를 보완해주는 완전한 1문장의 결합'을 의미해. \
                    예를 들어 6개의 대사로 구성된 [한국어 대화문]과 [1차 번역문]이 있다고 가정해볼게. \n\
                    '[한국어 대화문]\n000\t어제,\n001\t나는 푸른...\n002\t하늘을 보았다.\n003\t어땠어?\n004\t정말,\n005...아름다웠어.\n' \
                    라는 [한국어 대화문]이 있다면 [대사 문단]은 [(000~002),(004~005)]로 구성될 수 있어.\
                    왜냐하면 000부터 002까지의 대사는 웹툰 내에서 동일한 한 명의 등장인물이 연속적으로 발화한 것으로 보이며, \
                    각 대사가 '모두' 불완전하고 3개의 대사를 결합했을 때 딱 한 문장으로 결합돼.\
                    ***important*** 여기서 개념을 하나 설명할게. 너가 수행하는 태스크에서 '불완전한 대사'를 예를 들어서 설명해줄게. \
                    '(1)000\t당신!\n001\t밥\n002\t먹었어?\n','(2)000\t너,\n001\t밥 먹었어?\n002\t난 이제 먹어야하는데...\n003\t뭐 먹었어?\n' 와 같은 예시가 주어졌다고 가정해보자.\
                    두 가지 예시 모두 '(1)당신! 밥 먹었어?','(2)너, 밥 먹었어? 난 이제 먹어야하는데 뭐 먹었어?' 와 같이 결합했을 때 \
                    (1)과 (2)모두 동일한 한 명의 화자가 연속적으로 발화하는 대사들이지만 (1)의 '당신!'과 (2)의 '난 이제 먹어야하는데...', '뭐 먹었어?' 같은 각각의 대사는 하나의 독립적인 완전한 대사로써, \
                    (1)대사 전체를 결합하면 완전한 대사 2개('당신!','밥 먹었어?')가 결합되어 2문장의 대사가 나오고, \
                    (2)대사 전체를 결합하면 완전한 대사 3개가 결합되어, 3문장의 대사가 나와. ('너, 밥 먹었어?', '난 이제 먹어야하는데...', '뭐 먹었어?') \
                    [대사 문단]에 넣기 위해서는 대사를 모두 결합했을 때 딱 한 문장의 대사가 나와야해.\n\
                    반면 (1)의 '밥','먹었어?'는 각각 하나의 독립적인 대사로 활용했을 때 불완전한 대사로 보기 때문에 이전 혹은 이후 대사와 결합해야해.\
                    좀 더 구체적으로 설명하자면 (1)의 '당신!'은 독립적으로 사용가능한 완전한 대사로 볼 수 있지만, 뒤에 있는 대사 '밥'과 '먹었어?'가 불완전한 대사이고, \
                    '밥 먹었어?' 라고 연결했을 때 한 문장으로 볼 수 있으므로, \
                    불완전한 두 개의 대사인 '밥'과 '먹었어?'를 결합하여 [대사 문단]의 한 원소로 넣는거야.\
                    하지만 '당신!'까지 결합하면 '당신! 밥 먹었어?'와 같이 완전한 대사가 2개가 포함된 2문장이 되기 때문에 [대사 문단]의 한 원소가 될 수 없어.\
                    즉 불완전한 대사 여러 개를 결합했을 때 한 문장이 될 수 있다는 걸 보여주는 예인거지.\n \
                    그리고 (2)의 001 번 째 대사인 '밥 먹었어?'같은 경우는 독립적으로 사용가능한 완전한 대사로 볼 수 있지만, 앞 대사가 '너,'라는 뒤에 있는 대사를 필요로 하는 불완전한 대사이고, \
                    '너, 밥 먹었어?'라고 연결했을 때 두 개 이상의 문장이 아닌, 한 문장으로 볼 수 있으므로, 불완전한 대사인 '너,'와 완전한 대사인 '밥 먹었어?'를 결합하여 [대사 문단]의 한 원소로 넣는거야. \
                    즉 불완전한 대사와 불완전한 대사가 필요로 하는 완전한 대사를 결합해도 한 문장이 될 가능성이 있지. \
                    그리고 불완전한 대사라는 걸 증명할 수 있는 근거가, 불완전한 대사들은 여러 개를 연속적으로 결합해도 최대 한 문장의 대사가 나오게 돼. \
                    즉 웹툰의 대사를 생각했을 떄 (1)의 모든 대사와 (2)의 일부 대사처럼 한 문장의 대사가 (여러 개의 불완전한 대사) 혹은 (여러 개의 불완전한 대사+한 개의 완전한 대사)로 나뉜 경우만 [대사 문단]의 한 원소가 될 수 있고, \
                    (2)의 '난 이제 먹어야하는데...', '뭐 먹었어?'처럼 완전한 대사 둘은 결합되면 두 문장이 되기 때문에, [대사 문단]의 한 원소가 될 수 없다는 뜻이야.\
                    또한 (2)의 '너', '밥 먹었어?', '난 이제 먹어야하는데...' 도 결합하면 '너, 밥먹었어? 난 이제 먹어야하는데...'와 같이 두 문장이 되기 때문에 '너', '밥 먹었어?'까지만 [대사 문단]으로 포함시켜야해. \
                    ***important*** 쉽게 생각하면 '두 개 이상의 불완전한 대사'들 혹은 '한 개 이상의 불완전한 대사와 불완전한 대사가 필요로하는 한 개의 완전한 대사'가 결합되어 한 문장을 이룬다면 [대사 문단]의 한 원소가 될 수 있지만, \
                    '한 문장을 구성할 수 있는 두 개 이상의 불완전한 대사'와 '완전한 대사'가 결합되거나, \
                    완전한 대사 둘 이상이 결합되면 두 문장 이상이 되기 때문에 [대사 문단]의 한 원소가 될 수 없어. \n\
                    다시 돌아가서, [대사 문단]을 찾을 때는 동일한 한 명의 화자가 연속적으로 발화한 대사인지를 엄격하게 검수한 후에, \
                    각 대사들을 결합했을 때 최대 한 문장이 된다면 해당 대사들을 묶어서 [대사 문단]의 한 원소로 정의하면 돼.\n\
                    명심해야할 건 아무리 하나의 완전한 대사가 불완전한 대사를 보완해준다고 하더라도, 결합했을 때 2문장 이상이 되면 [대사 문단]에 포함될 수 없어.\n\
                    그리고 [한국어 대화문]의 003은 앞과 뒤 화자와는 다른 화자임이 분명하고, 그 자체로 완전한 문장이며, 앞 뒤에 연결할 불완전한 대사가 없기 때문에 [대사 문단]의 한 원소로 포함될 수 없어. \
                    좀 더 다른 예를 들어 설명하자면 '(3)100\t너 말이야\n101\t뭐가?\n102\t좀 이상한 거 같애\n'라는 대사가 주어졌을 때 \
                    100 번 째 대사와 102 번 째 대사의 화자는 같은 것으로 판단되지만 중간에 101 번 째 대사는 다른 화자인 것으로 판단되기 때문에, 3가지의 대사는 연결된 대사가 아니고, 결합돼서는 안 돼. 즉 [대사 문단]의 한 원소로 포함될 수 없어.\n\
                    그리고 004~005 또한 동일한 한 명의 화자가 발화하고 있는 것으로 판단되고, 각 대사가 불완전하고, 각 대사를 결합하면 딱 한 문장이 되기 때문에, 결합하여 [대사 문단]의 한 원소로 포함시켜.\
                    ***important*** 특히 대사의 화자가 동일한지 판단할 때는 발화자에 대응하는 명사를 유심히 봐야하고, \
                    웹툰 내 대사는 발화자가 생략된 경우가 많기 때문에 이를 잘 유추해서 동일한 화자가 맞는지 잘 판단해야해.\n\
                    여기까지 내용을 요약해보자면, [대사 문단]의 한 원소가 되는 방법은 아래 조건을 모두 만족해야해. \
                    조건1) 동일한 한 명의 화자가 발화한 대사들이어야 함. 다른 화자가 발화한 대사가 섞이면 절대 안 됨.\
                    조건2) 대사들을 결합했을 때 한 문장이어야함. 두 문장 이상이 되면 절대 안 됨.\n\
                    \
                    그 다음에 [한국어 대화문]에 속한 모든 대사에 대해서 [대사 문단]의 모든 원소를 찾고 각 원소에 대해서 하나의 문장으로 결합해. \
                    위 예시대로라면 [(000~002,'어제 나는 푸른 하늘을 보았다.'),(004~005,'정말 아름다웠어…')] 라는 결과가 나올거야. \
                    [대사 문단]의 한 원소에 대한 각 대사들을 하나의 문단으로 결합할 때는 결합한 문장의 양 끝에 있는 특수문자를 제외하고, '.','...','…', ','와 같은 문장 중간에 들어가는 특수 문자는 제거해. \n\
                    그리고 이제 함께 주어진 [1차 번역문]이 다음과 같다고 해볼게.\n\
                    '[1차 번역문]\n000\tyesterday,\n001\tI...\n002\tsaw the blue sky.\n003\thow was it?\n004\tit was\n005really dark…\n'\
                    그랬을 때 [대사 문단]에 쓰여진 것과 동일하게 결합해. \
                    위 예에서는 [한국어 대화문] 상에서 (000~002), 그리고 (004~005)가 각각 결합되었기 때문에 \
                    동일하게 [1차 번역문] 상에서도 (000~002)와 (004~005)를 결합하고 (연결을 위한 특수 문자는 제거) 이전 결과물에 붙여. \
                    그렇게 하면, 다음과 같은 결과물을 얻을 수 있어.\n \
                    [((000~002),'어제 나는 푸른 하늘을 보았다.','yesterday I saw the blue sky.'),\
                    ((004~005),'정말 아름다웠어.','it was really dark…')]\n \
                    그 다음 리스트 내 각 원소의 한글 문장과 영어 문장의 의미를 비교해.\
                    만약 '어제 나는 푸른 하늘을 보았다.'와 'yesterday I saw the blue sky.'처럼 두 문장의 의미가 동일하다면 \
                    영어 문장을 해당 문장을 구성한 대사의 개수 n개(해당 예에서는 000~002:3개)로 나누고, 나뉘는 부분 양 쪽에 '...'를 삽입해. \n\
                    ***important*** 단, 나눌 때 해당 문장을 구성하는 대사 개수 n개로만 나눠야 하며, 나누는 개수를 유지하면서 최대한 웹툰 독자가 읽기에 편하도록 나누고, 나눈 이후의 각 요소는 적어도 하나의 단어를 포함하고 있어야 해.\n\
                    예를 들어 'yesterday', 'I saw', 'the blue sky.'로 나누는게 웹툰 대사상 적합하다고 생각한다면, \n\
                    '000\tyesterday...\n001\t...I saw...\n002\t...the blue sky.\n' 를 생성하는거야. \n\
                    그리고 이어서 003은 [대사 문단]에 속하지 않기 때문에 [1차 번역문]의 003번을 똑같이 생성해. 그러면 다음과 같이 될거야.\n \
                    '003\thow was it?\n'\n\
                    그 다음 004번과 005번이 [대사 문단]의 한 원소이기 때문에, '정말 아름다웠어…'와 'it was really dark…'의 의미를 비교하고, \
                    둘의 의미가 다르기 때문에 영어 문장을 무시하고, [결합된 한글 문장]을 재번역해. \
                    여기서는 'it was really dark…'를 무시하고, [결합된 한글 문장]인 '정말 아름다웠어…'를 번역하면 돼. 대신 재번역할 때 참고해야할 고유명사가 있을 수도 있으니 [단어집]을 참고해서 번역해. \
                    그럼 'it was really beautiful…'을 얻을 수 있고, 이를 똑같이 [대사 문단]을 구성하는 대사 개수인 n개(해당 예에서는 004~005:2개)로 나누고, 나뉘는 부분 양 쪽에 '...'를 삽입해. \n\
                    ***important*** 단, 나눌 때 해당 문장을 구성하는 대사 개수 n개로만 나눠야 하며, 나누는 개수를 유지하면서 최대한 웹툰 독자가 읽기 편하도록 나누고, 나눈 이후의 각 요소는 적어도 하나의 단어를 포함하고 있어야 해.\n\
                    예를 들어 'it was', 'really beautiful…'로 나누는게 웹툰 대사상 적합하다고 생각한다면, \
                    '004\tit was...\n005\t...really beautiful…\n'를 생성하는거야. \
                    위 예의 최종적인 출력형태는 다음과 같아. \n\
                    <translate>\n000\tyesterday...\n001\t...I saw...\n002\t...the blue sky.\n003\thow was it?\n004\tit was...\n005\t...really beautiful…\n</translate>\
                    그리고 만약 추론이 필요하다면 <reasoning>으로 시작해서 추론 내용을 입력하고 </reasoning>으로 마무리해. \
                    즉 정리하자면 출력 형태는 '<reasoning> ...추론 내용... </reasoning> <translate> 검토한 영어 번역문 </translate>' \
                    혹은 '<translate> 검토한 영어 번역문 </translate>' 가 될 거야.\n \
                    그리고 [검토한 영어 번역문]에는 [한국어 대화문]에 속한 모든 대사 개수만큼이 포함되어야 하는 것을 잊지마."
                }
            ],
}

# %%
import re
def extract_translation(text):
    match = re.search(r'<translate>(.*?)</translate>', text, re.DOTALL)
    return match.group(1).strip() if match else None


review_text = f"{input_text}\n\n### review\n\n" 
#en, kor
kor_li = kor.split('\n')
en_li = en.split('\n')
review_li = []
while True:
    if len(review_li) == len(kor_li):
        break
    review_completion = openai_client.beta.chat.completions.parse(
        model= GPT_BASE_MODEL,
        messages = [
            SYSTEM_REVIEW_PROMPT,
            {
                "role":"user",
                "content" : [{"type" : "text",
                              "text" : review_text
                            }],
            }
        ],
        temperature= 0.2,
        top_p = 0.6#보수적인 응답에는 top-p가 낮은게 좋음, 창의적인 거에는 높은 게 좋고 (보통 0.8~0.9)
    )
    review = review_completion.choices[0].message.content
    print(review)
    review_li = extract_translation(review).split('\n')
# Out:
# <reasoning>
# 먼저 [대사 문단]을 추출하기 위해 [한국어 대화문]을 분석한다.
#
# (000~001): "그럼 다들 얌전해졌으니 …."와 "마저 절차를 밟겠습니다."는 동일 화자가 이어서 말한 것으로 보이며, 첫 문장은 불완전하고 두 번째 문장이 이를 보완하여 하나의 완전한 문장을 구성하므로 [대사 문단]에 포함.
#
# (002~003): "…3일 전, 술집에서 행패."와 "남성 5인 폭행 및 금품 상당수 갈취…."는 동일 화자가 이어서 말한 것으로 보이며, 각각 불완전하지만 결합하면 하나의 문장이 되므로 [대사 문단]에 포함.
#
# (005~006): "2 성벽에서 싸우는 마법사란 건-"과 "진짜였구나."는 동일 화자가 이어서 말한 것으로 보이며, 첫 문장은 불완전하고 두 번째 문장이 이를 보완하므로 [대사 문단]에 포함.
#
# (011~013): "또 이 주 전에는….", "그리고….", "무엇을 노렸는지도."는 동일 화자가 이어서 말한 것으로 보이며, 앞의 두 문장은 불완전하고 마지막 문장이 이를 보완하므로 [대사 문단]에 포함.
#
# (019~020): "게다가", "헤일론 성에서 피오나의 대우는 단순히 귀한 병사라기엔 매우 좋다."는 연결된 문장으로 보이며, 첫 문장은 불완전하고 두 번째 문장이 이를 보완하므로 [대사 문단]에 포함.
#
# (023~024): "…공작이 아무런 이유 없이 그럴 남자가 아닌데.", "아벨 헤일론 공작이 피오나에게 원하는 건 대체 뭘까?"는 첫 문장이 불완전하고 두 번째 문장이 이를 보완하므로 [대사 문단]에 포함.
#
# (025~027): "…하지만 내가 이 문제에 대한 답을 알 수 있을까.", "나는 용병단의 널리고 널린 고아 소년이야.", "피오나를 위해 할 수 있는 일은 없겠지…."는 각각 완전한 문장이므로 결합 시 3문장이 되어 [대사 문단]에 포함될 수 없음.
#
# (029~030): "친구가 되자고는 했지만,", "성으로 돌아가면 나 같은 건 잊어버릴지도 몰라…."는 첫 문장은 불완전하고 두 번째 문장이 이를 보완하므로 [대사 문단]에 포함.
#
# (034~036): "두 번째로는….", "그 부분.", "자르세요."는 동일 화자가 이어서 말한 것으로 보이며, 앞의 두 문장은 불완전하고 마지막 문장이 이를 보완하므로 [대사 문단]에 포함.
#
# (048~050): "…헤일론 영지는 용병들에게 위험에 상응하는 금액을 치릅니다.", "아벨은 냉정하지만 공정하다.", "마물을 잡는 위험을 감수하는 만큼 보수를 지불한다."는 각각 완전한 문장이므로 결합 시 3문장이 되어 [대사 문단]에 포함될 수 없음.
#
# (056~057): "…계속 선택을 거부하겠다면,", "제가 임의로 고르겠습니다."는 첫 문장은 불완전하고 두 번째 문장이 이를 보완하므로 [대사 문단]에 포함.
#
# (060~062): "…사실은 나도 아까부터 몸이 떨려.", "사람들도 왠지 조용하고.", "기분탓인지 주위 온도가 2도쯤 내려간 것 같은데…."는 각각 완전한 문장이므로 결합 시 3문장이 되어 [대사 문단]에 포함될 수 없음.
#
# (085~087): "그야…. 둘 다 하는 건 가혹해 보이니까,", "나름의 배려? 였죠.", "쓸데없는 배려다."는 각각 완전한 문장이므로 결합 시 3문장이 되어 [대사 문단]에 포함될 수 없음.
#
# (089~090): "피오나, 내가 늘 말했었지.", "이 헤일론에서 감히 내 영지민에게 손을 대는 버러지들은…."은 첫 문장은 불완전하고 두 번째 문장이 이를 보완하므로 [대사 문단]에 포함.
#
# (095~096): "감히 내가 다스리는 영지를 야만적이라 칭했으니,", "그 기대에 응해 주는 게 예의겠지."는 첫 문장은 불완전하고 두 번째 문장이 이를 보완하므로 [대사 문단]에 포함.
#
# (102~103): "피오나.", "다음부터 쓸데없는 고민은 하지 말거라."는 첫 문장은 불완전하고 두 번째 문장이 이를 보완하므로 [대사 문단]에 포함.
#
# (106~108): "아벨, 이 위험한 녀석.", "…어?", "그래서 결국, 이 성격 더러운 아벨이 왜 굳이 여기까지 온 거지?"는 각각 완전한 문장이므로 결합 시 3문장이 되어 [대사 문단]에 포함될 수 없음.
#
# 따라서 [대사 문단]은 다음과 같다:
#
# [
# (000~001, "그럼 다들 얌전해졌으니 마저 절차를 밟겠습니다."),
# (002~003, "3일 전 술집에서 행패, 남성 5인 폭행 및 금품 상당수 갈취."),
# (005~006, "2 성벽에서 싸우는 마법사란 건 진짜였구나."),
# (011~013, "또 이 주 전에는 그리고 무엇을 노렸는지도."),
# (019~020, "게다가 헤일론 성에서 피오나의 대우는 단순히 귀한 병사라기엔 매우 좋다."),
# (023~024, "공작이 아무런 이유 없이 그럴 남자가 아닌데, 아벨 헤일론 공작이 피오나에게 원하는 건 대체 뭘까?"),
# (029~030, "친구가 되자고는 했지만 성으로 돌아가면 나 같은 건 잊어버릴지도 몰라."),
# (034~036, "두 번째로는 그 부분 자르세요."),
# (056~057, "계속 선택을 거부하겠다면 제가 임의로 고르겠습니다."),
# (089~090, "피오나, 내가 늘 말했었지. 이 헤일론에서 감히 내 영지민에게 손을 대는 버러지들은."),
# (095~096, "감히 내가 다스리는 영지를 야만적이라 칭했으니 그 기대에 응해 주는 게 예의겠지."),
# (102~103, "피오나. 다음부터 쓸데없는 고민은 하지 말거라.")
# ]
#
# 이제 각 [대사 문단]에 대해 [1차 번역문]이 올바르게 번역되었는지 확인한다.
#
# (000~001): "now that everyone has calmed down, let's continue with the procedure." → 정확한 번역. → 나누기: "now that everyone has calmed down", "let's continue with the procedure."
#
# (002~003): "three days ago, you caused a disturbance at a bar... and assaulted five men, stealing a large amount of money from them..." → 정확한 번역. → 나누기: "three days ago, you caused a disturbance at a bar", "and assaulted five men, stealing a large amount of money from them..."
#
# (005~006): "so the rumors about a mage fighting at the second wall... were true." → 정확한 번역. → 나누기: "so the rumors about a mage fighting at the second wall", "were true."
#
# (011~013): "and two weeks ago... and... and what he's after." → 의미는 맞지만 문장 구조가 어색함. 원문은 "또 이 주 전에는 그리고 무엇을 노렸는지도." → 자연스럽게 재번역 필요: "two weeks ago, and what he was after." → 나누기: "two weeks ago", "and what he was after."
#
# (019~020): "on top of that, fiona is being treated far better than a mere soldier at heylon manor." → 정확한 번역. → 나누기: "on top of that", "fiona is being treated far better than a mere soldier at heylon manor."
#
# (023~024): "but the duke isn't the type of man to do that without reason... what exactly does duke abel heylon want from fiona?" → 정확한 번역. → 나누기: "but the duke isn't the type of man to do that without reason", "what exactly does duke abel heylon want from fiona?"
#
# (029~030): "she said we should be friends, but she might forget about me once she goes back to the manor..." → 정확한 번역. → 나누기: "she said we should be friends", "but she might forget about me once she goes back to the manor..."
#
# (034~036): "...to cut off... that part." → 원문은 "두 번째로는 그 부분 자르세요." → 의미는 맞지만 어색하므로 재번역: "the second is to cut off that part." → 나누기: "the second is", "to cut off that part."
#
# (056~057): "if you refuse to choose, I will choose for you." → 정확한 번역. → 나누기: "if you refuse to choose", "I will choose for you."
#
# (089~090): "fiona, I always told you... that the scum who dare to lay a hand on the people of heylon..." → 정확한 번역. → 나누기: "fiona, I always told you", "that the scum who dare to lay a hand on the people of heylon..."
#
# (095~096): "they dared to call my territory barbaric, so it would only be polite to meet their expectations." → 정확한 번역. → 나누기: "they dared to call my territory barbaric", "so it would only be polite to meet their expectations."
#
# (102~103): "fiona. don't waste your time worrying about unnecessary things next time." → 정확한 번역. → 나누기: "fiona", "don't waste your time worrying about unnecessary things next time."
#
# </reasoning>
#
# <translate>
# 000	now that everyone has calmed down...
# 001	...let's continue with the procedure.
# 002	three days ago, you caused a disturbance at a bar...
# 003	...and assaulted five men, stealing a large amount of money from them...
# 004	that girl...
# 005	so the rumors about a mage fighting at the second wall...
# 006	...were true.
# 007	and she's on a different level compared to other mages.
# 008	I've seen mages create fireballs the size of fists,
# 009	but I've never seen a mage create a phenomenon like fiona did.
# 010	I think I know why duke heylon brought her here...
# 011	two weeks ago...
# 012	...and...
# 013	...what he was after.
# 014	a small girl standing confidently in front of a large, burly man.
# 015	no matter what happens here,
# 016	people will remember this scene.
# 017	they'll remember that fiona isn't just an ordinary girl,
# 018	and that rumor will spread throughout the entire territory.
# 019	on top of that...
# 020	...fiona is being treated far better than a mere soldier at heylon manor.
# 021	mm, this is so good!
# 022	miss fiona, I brought the books you like.
# 023	but the duke isn't the type of man to do that without reason...
# 024	...what exactly does duke abel heylon want from fiona?
# 025	but will I be able to find the answer to that question?
# 026	I'm just an orphan boy in a mercenary group.
# 027	there's nothing I can do for fiona...
# 028	will I even be able to see her after this?
# 029	she said we should be friends...
# 030	...but she might forget about me once she goes back to the manor...
# 031	so I will give you two options.
# 032	the first is to leave the territory with nothing but the clothes on your back.
# 033	w-what?!
# 034	the second is...
# 035	...to cut off...
# 036	...that part.
# 037	what?!
# 038	huh...
# 039	did they really not expect this kind of punishment?
# 040	of course, I will show you some mercy.
# 041	you can choose to leave or cut it off.
# 042	the choice is yours.
# 043	ugh...
# 044	don't be ridiculous! why should we have to suffer that kind of punishment?!
# 045	we should have never gotten involved with you barbaric northerners in the first place...
# 046	you'd be inside the belly of a monster if it weren't for us mercenaries!
# 047	why, that little...
# 048	we pay mercenaries a fair price for the risks they take.
# 049	abel is cold, but he's fair.
# 050	he pays them for the risk they take in hunting monsters.
# 051	on top of that, mercenaries can also obtain materials from the bodies of monsters.
# 052	they can earn a lot of money by selling those materials, depending on the species.
# 053	it means that everyone is here for their own benefit.
# 054	heylon needs military power to protect the territory,
# 055	and mercenaries need money.
# 056	if you refuse to choose...
# 057	...I will choose for you.
# 058	untie me right now!
# 059	let's finish this quickly for the people who have gathered in the cold.
# 060	to be honest, I'm starting to feel cold too.
# 061	the people have suddenly gone quiet.
# 062	it might just be my imagination, but it feels like the temperature has dropped by two degrees...
# 063	what is he going to choose?
# 064	oh...
# 065	abel?!
# 066	so that's why the temperature dropped!
# 067	it feels like a cold wind is blowing just from his presence...
# 068	your grace, what are you doing here?
# 069	I don't need a reason to look around my own territory, do I?
# 070	I'm sorry...
# 071	I see...
# 072	ah!
# 073	so what choices did you give those bastards?
# 074	um...
# 075	just out of curiosity,
# 076	how much did you hear?
# 077	hmph...
# 078	I heard from the part where they called us barbaric northerners.
# 079	oh... they're screwed.
# 080	if they're lucky, they might get away with just being beaten half to death.
# 081	I told them to choose between two options.
# 082	one was to leave the territory with nothing but the clothes on their back,
# 083	and the other was to cut off... the part that allows them to reproduce.
# 084	I like both options.
# 085	but why did you give them a choice?
# 086	well... it seemed harsh to make them do both,
# 087	so I was trying to be considerate.
# 088	that was unnecessary.
# 089	fiona, I always told you...
# 090	...that the scum who dare to lay a hand on the people of heylon...
# 091	ugh?!
# 092	...don't deserve any consideration.
# 093	aah...
# 094	I’m getting chills from the murderous aura he’s emitting, even though I’m in his arms...
# 095	they dared to call my territory barbaric...
# 096	...so it would only be polite to meet their expectations.
# 097	apply both punishments.
# 098	cut off the body part that caused the crime,
# 099	and then chase them out of the territory.
# 100	now, begin the execution.
# 101	yes, your grace!
# 102	fiona...
# 103	...don't waste your time worrying about unnecessary things next time.
# 104	but it seemed like a decision that could determine whether someone lives or dies...
# 105	yes, your grace.
# 106	abel, you dangerous man.
# 107	huh...?
# 108	so why did this ill-tempered abel come all the way here?
# </translate>

# %%
for k, e, r in zip(kor_li, en_li, review_li):
    if e != r:
        print(f'[한글] {k}')
        print(f'[1차 번역]{e}')
        print(f'[리뷰]{r}')
        print()
# Out:
# [한글] 000	그럼 다들 얌전해졌으니 ….
# [1차 번역]000	now that everyone has calmed down,
# [리뷰]000	now that everyone has calmed down...
#
# [한글] 001	마저 절차를 밟겠습니다.
# [1차 번역]001	let's continue with the trial.
# [리뷰]001	...let's continue with the trial.
#
# [한글] 002	…3일 전, 술집에서 행패.
# [1차 번역]002	three days ago, you caused a disturbance at a bar.
# [리뷰]002	three days ago, you caused a disturbance at a bar...
#
# [한글] 003	남성 5인 폭행 및 금품 상당수 갈취….
# [1차 번역]003	you assaulted five men and stole a large sum of money...
# [리뷰]003	...you assaulted five men and stole a large sum of money.
#
# [한글] 008	손에서 주먹만 한 불덩이를 만드는 건 봤어도,
# [1차 번역]008	I've seen mages create fist-sized fireballs,
# [리뷰]008	I've seen mages create fist-sized fireballs...
#
# [한글] 009	피오나처럼 저 정도 현상을 만드는 마법사는 처음이야.
# [1차 번역]009	but I've never seen one create such a phenomenon like fiona.
# [리뷰]009	...but I've never seen one create such a phenomenon like fiona.
#
# [한글] 012	그리고….
# [1차 번역]012	and...
# [리뷰]012	...and...
#
# [한글] 013	무엇을 노렸는지도.
# [1차 번역]013	I also understand what he was after.
# [리뷰]013	...I also understand what he was after.
#
# [한글] 015	여기서 무슨 일이 생기든,
# [1차 번역]015	no matter what happens here,
# [리뷰]015	no matter what happens here...
#
# [한글] 016	사람들은 이 모습을 똑똑히 기억할게 틀림없다.
# [1차 번역]016	people will remember this sight.
# [리뷰]016	...people will remember this sight.
#
# [한글] 017	피오나는 사람들에게 평범한 소녀가 아니라고 각인될 것이고
# [1차 번역]017	they'll remember that fiona isn't an ordinary girl,
# [리뷰]017	they'll remember that fiona isn't an ordinary girl...
#
# [한글] 018	그 소문은 영지 전체에 퍼져나갈 것이다.
# [1차 번역]018	and that rumor will spread throughout the entire territory.
# [리뷰]018	...and that rumor will spread throughout the entire territory.
#
# [한글] 023	…공작이 아무런 이유 없이 그럴 남자가 아닌데.
# [1차 번역]023	but the duke isn't the type of man to do that without a reason.
# [리뷰]023	but the duke isn't the type of man to do that without a reason...
#
# [한글] 024	아벨 헤일론 공작이 피오나에게 원하는 건 대체 뭘까?
# [1차 번역]024	what exactly does duke abel heylon want from fiona?
# [리뷰]024	...what exactly does duke abel heylon want from fiona?
#
# [한글] 029	친구가 되자고는 했지만,
# [1차 번역]029	she said we should be friends,
# [리뷰]029	she said we should be friends...
#
# [한글] 030	성으로 돌아가면 나 같은 건 잊어버릴지도 몰라….
# [1차 번역]030	but she might forget about me once she returns to the manor...
# [리뷰]030	...but she might forget about me once she returns to the manor.
#
# [한글] 056	…계속 선택을 거부하겠다면,
# [1차 번역]056	if you continue to refuse to choose,
# [리뷰]056	if you continue to refuse to choose...
#
# [한글] 057	제가 임의로 고르겠습니다.
# [1차 번역]057	I will choose for you.
# [리뷰]057	...I will choose for you.
#
# [한글] 085	그런데 왜 선택권을 준거지?
# [1차 번역]085	but why did you give them a choice?
# [리뷰]085	well...
#
# [한글] 086	그야…. 둘 다 하는 건 가혹해 보이니까,
# [1차 번역]086	well... it seemed harsh to do both,
# [리뷰]086	...it seemed harsh to do both,
#
# [한글] 087	나름의 배려? 였죠.
# [1차 번역]087	so I was trying to be considerate.
# [리뷰]087	...so I was trying to be considerate.
