# %%
import re
from langchain_community.vectorstores import FAISS
from langchain.docstore.document import Document
import bs4
import ssl
import urllib3
import pandas as pd
import faiss
import os
from langchain.embeddings import HuggingFaceEmbeddings
import torch
import gc

def instruct_structure(prompt):
    input_text, output_text = prompt.split('### target')
    input_text = input_text.replace('### glossaries', '### glossary').replace('\n* ', '\n• ')
    input_text = re.sub(r"\[[^\]]+\] ", "[UNK] ", input_text)
    return input_text


project_id = "prod-ai-project"

from google.cloud import bigquery
client = bigquery.Client(project=project_id)
sql = """select series_id, episode_id, org_input_text, org_output_text, prompt 
        from webtoon_translation.structured_240820_ep_line
        where data_split = 'romance_valid'"""
df = client.query(sql).result().to_dataframe()
from tqdm import tqdm
tqdm.pandas()
df['prompt'] = df['prompt'].progress_apply(lambda x: instruct_structure(x))
# Out:
# /home/bun.2/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/google/cloud/bigquery/table.py:1820: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 74/74 [00:00<00:00, 19497.36it/s]

# %%
data_idx = 58
data = df['prompt'][data_idx]
example = data.split("### source")[1].strip()
#glossary + source data
print(data)
# Out:
# ### glossary
# • 시그렌 (M): siegren
# • 유니스 (F): eunice
# • 피오나 (F): fiona
# • 마법사: mage / sorcerer
# • 하녀: maid
#
# ### source
# 000	[UNK] 『금일 오후,
# 001	[UNK] 온실에서 있을 티 파티에 영애를 초대하고 싶습니다.』
# 002	[UNK] 『시간이 나신다면 꼭 참석해 주세요,
# 003	[UNK] 헤더 아덴 자작 영애.』
# 004	[UNK] 이 사람,
# 005	[UNK] 어제 시그렌이랑 일이 있었던 그 영애 아냐?
# 006	[UNK] 그런 사람이 여는 티파티에 내가 가도 되는 건가?
# 007	[UNK] 내가 괜히 신경 쓸 만한 이유는 없지.
# 008	[UNK] 잘못한 건 그쪽이고.
# 009	[UNK] 어쩌면 티파티에서 유니스를 만날 수 있을지도 모르니까.
# 010	[UNK] 기쁜 마음으로 응하겠다고 전해줘.
# 011	[UNK] 유니스 영애.
# 012	[UNK] 피오나 영애…!
# 013	[UNK] 유니스 영애도 초대받은 건가요?
# 014	[UNK] 네.
# 015	[UNK] 피오나 영애와는 같은 일행임에도 계속 얼굴을 볼 수가 없었네요.
# 016	[UNK] 전 말을 타고 있었거든요.
# 017	[UNK] …그래도 마차에도 와 주세요.
# 018	[UNK] 혼자서는 심심해서….
# 019	[UNK] 주변에 온통 기사랑 병사라서 쓸쓸했나 봐.
# 020	[UNK] 어서 오십시오.
# 021	[UNK] 이쪽이 온실입니다.
# 022	[UNK] 아가씨께서는 안쪽에서 기다리고 계십니다.
# 023	[UNK] 어머나,
# 024	[UNK] 피오나 영애,
# 025	[UNK] 유니스 영애…
# 026	[UNK] 초대에 응해주셔서 감사해요.
# 027	[UNK] 기다리고 있었답니다.
# 028	[UNK] 와, 역시 화려한 미인이야.
# 029	[UNK] 이런 사람이 시그렌에게 달려들었단 말이지.
# 030	[UNK] 자, 어서 앉으세요.
# 031	[UNK] 네, 고마워요.
# 032	[UNK] 이쪽은 근처 영지의 영애들이에요.
# 033	[UNK] 명성이 자자한 두 분을 만나서 영광이에요.
# 034	[UNK] 네…
# 035	[UNK] 잘 부탁해요.
# 036	[UNK] 뭐지?
# 037	[UNK] 묘하게 시선이 불온한 것 같은 느낌이….
# 038	[UNK] 헤일론 영애는 북부에 있었다면서요.
# 039	[UNK] 맞아요.
# 040	[UNK] 힘들지는 않았나요?
# 041	[UNK] 거기에는 굉장히 야만적이고 잔혹한 마법사가 산다고 들었는데….
# 042	[UNK] 사람 사는 곳이라 다들 비슷하답니다.
# 043	[UNK] 아니, 이 소문 여기까지 돌았냐!
# 044	[UNK] 소문 이야기가 나와서 말인데요,
# 045	[UNK] 듣자 하니…
# 046	[UNK] 영애의 핏줄은 조금 특별하다면서요?
# 047	[UNK] 본래는 헤일론 쪽이 아니라고 들었어요.
# 048	[UNK] 제가 알기로는,
# 049	[UNK] 사생아라던데.
# 050	[UNK] 네, 맞는 말이에요.
# 051	[UNK] 전 사생아입니다.
# 052	[UNK] 정확히 알고 계시네요.
# 053	[UNK] 웃어?
# 054	[UNK] 게다가 그 본가는…
# 055	[UNK] 네. 마약 사업 혐의로 재산을 몰수당했죠.
# 056	[UNK] 제가 직접 고발한 일이고요.
# 057	[UNK] 세상에, 저라면 도저히 못할 거예요.
# 058	[UNK] 무슨 이유에서든 가족을 자기 손으로 배신하는 건…
# 059	[UNK] 짐승이나 할 짓이죠.
# 060	[UNK] 자, 잠깐만요!
# 061	[UNK] 피오나 영애…
# 062	[UNK] 그래서,
# 063	[UNK] 하고 싶은 말이 뭔가요?
# 064	[UNK] 적당히 하라는 소리예요!
# 065	[UNK] 운 좋게 양녀가 되었다고 해도,
# 066	[UNK] 귀족 영애라면 정도를 지켜야죠.
# 067	[UNK] …해서, …
# 068	[UNK] 영애도……
# 069	[UNK] 시그렌.
# 070	[UNK] 피오나 영애 왜 딴 곳을 보시죠.
# 071	[UNK] 지금 제가 말하고 있는 게 안 보이나요?
# 072	[UNK] 아직 할 말이 더 있답니다.
# 073	[UNK] 영애,
# 074	[UNK] 남의 저택에서 신세를 지고 있는 와중에 전하께 꼬리를 치셨죠?
# 075	[UNK] 제 하녀가 말해주었단 말이에요. 어젯밤에-
# 076	[UNK] 잠깐.
# 077	[UNK] 아덴 영애, 말이 심하세요!
# 078	[UNK] 심하긴 뭐가 심해요.
# 079	[UNK] 저는 그저 사실을 말하는 것뿐…
# 080	[UNK] 꺄,
# 081	[UNK] 꺄아아악!
# 082	[UNK] 영애의 말은 다 맞아요.
# 083	[UNK] 전 사생아고, 제가 태어난 가문도 직접 부수었죠.
# 084	[UNK] 하지만 똑똑한 아덴 영애가 하나 파악하지 못한 게 있네요.
# 085	[UNK] 저는 그 덕분에 권력과 힘,
# 086	[UNK] 두 개 다 가지고 있답니다.
# 087	[UNK] 지금 이 자리에서 제가 영애의 머리카락을 불태워도
# 088	[UNK] 아덴 자작님은 제 아버지께 항의서 몇 장 보내는 게 고작일 거란 뜻이죠.
# 089	[UNK] 망아지처럼 구는 것도 상대를 보면서 하세요.
# 090	[UNK] 그러다 목 잘려요.
# 091	[UNK] 그리고,
# 092	[UNK] 화,
# 093	[UNK] 황자 전하….
# 094	[UNK] 티파티가 꽤나 즐거워 보이는군.
# 095	[UNK] 헤더 아덴 영애.
# 096	[UNK] 그, 그게…
# 097	[UNK] 어제 그런 일이 있었으니 고개를 못 들겠지.
# 098	[UNK] 마지막으로 충고 하나 할게요.
# 099	[UNK] 남의 남자 탐내지 마세요.
# 100	[UNK] 이건 지금 내 거거든.

# %%
from openai import OpenAI
GPT_FINE_TUNING_MODEL="ft:gpt-4o-2024-08-06:kakaoent:webtoon-sft-250225:B4j839q0"
openai_client = OpenAI(
    api_key='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')

SYSTEM_PROMPT = {
            "role": "system",
            "content": [
                {
                    "type": "text",
                    "text": """You're an expert translator who translates Korean webtoon in English. Make sure the number of target sentences matches the number of source sentences. The result should be TSV formatted. 
            • Find a balance between staying true to the Korean meaning and keeping a natural flow. Don't be afraid to add to the text. Embellish it. 
            • Avoid translating word-for-word. Keep the general feeling and translate the text accordingly. 
            • Translate with an American audience in mind. This means easy-to-read, conversational English.""",
                }
            ],
        }

chat_completion = openai_client.beta.chat.completions.parse(
    model= GPT_FINE_TUNING_MODEL,
    messages = [
        SYSTEM_PROMPT,
        {
            "role":"user",
            "content" : [{"type" : "text",
                          "text" : data
                        }],
        }
    ],
    temperature= 0.2,
    top_p = 0.8
)
response = chat_completion.choices[0].message.content

# %%
#초벌 번역
#print(response)

# %%
response_split = response.split('\n')
source = data.split("### source")[1].strip().split('\n')

# %%
print(response_split[0])
# Out:
# 000	“my lady, I would like to invite you...

# %%
GPT_BASE_MODEL = "chatgpt-4o-latest"

SYSTEM_REVIEW_PROMPT = {
            "role": "system",
            "content": [
                {
                    "type": "text",
                    "text": "너는 1차 번역된 웹툰 대화를 검토하고 이를 수정하거나 아예 재생성하는 태스크를 수행할 거야. \
                    먼저 맥락을 이해하기 위해 한 회차의 모든 [한국어 대화문]이 주어지고, \
                    그 중에서 맨 마지막 두 줄에 [한글 대화]와 이 대화에 대응되는 [1차 영어 번역문]이 주어질 거야. \
                    먼저 [1차 영어 번역문]을 한글로 번역해서 [1차 한글 번역문]을 생성하고, [한글 대화]의 의미가 일치하는지 비교해.\n\
                    만약 의미가 일치한다면 그대로 생성해도 돼. \
                    하지만 만약 [1차 한글 번역문]과 [한글 대화]의 1)의미가 일치하지 않거나 2)정보의 양이 다르거나 \
                    3)[1차 한글 번역문]과 [한글 대화] 모두 수동태(피동태)라면,\
                    [1차 영어 번역문]과 [1차 한글 번역문]은 무시하고 [한글 대화]에 대응하는 영어 번역문을 능동태로 생성해.\
                    ***important*** 정보의 양에 대해서 설명할게. \
                    예를 들어 [한글 대화]가 '사과'인데 [1차 한글 번역문]이 '붉은 사과'라면 \
                    이는 [한글 대화]에 [1차 한글 번역문]의 일부만 제공된 상태이기 때문에 정보의 양이 다른 것으로 판단해. \
                    하지만 예외적으로 [한글 대화]가 '달렸다'인데 [1차 한글 번역문]이 '주어가 달렸다'라면 \
                    이는 정보의 양이 같은 것으로 판단해. \
                    왜냐하면 웹툰은 평서문이나 의문문의 대사의 경우, 영어로 번역할 때 생략된 주어도 넣어줘야하기 때문에 주어의 추가는 정보의 양이 다른 걸로 판단하지 않아.\
                    하지만 반대로 [한글 대화]가 '주어가 달렸다'인데 [1차 한글 번역문]이 '달렸다'라면 이건 정보의 누락이 발생한 것으로 보고 정보의 양이 다르다고 판단해.\n\
                    그리고 주어가 다른 거 같지만 정보의 양이 같은 경우를 알려줄게.\
                    예를 들어, [한글 대화]가 '그녀는 잠을 잔다'인데 [1차 한글 번역문]이 '그것은 잠을 잔다'라면 [한국어 대화문]의 문맥에서 그것(that)이 그녀(she)와 일치하는지를 판단해.\
                    만약 문맥상 가리키는 대상이 일치한다면 이는 정보의 양이 같은 거야. \
                    다시 말해서 텍스트 상에 표시된 글자가 다를지라도, 해당 텍스트가 문맥상 가리키는 대상이 동일하다면 정보의 양이 다른 게 아니라 같다고 판단해야해. \
                    참고로 웹툰은 사람도 '이것(this)', '저것(that)'이라고 표현할 수 있어.\
                    그리고 다른 예로 [한글 대화]가 '그는 나를 때렸다'와 같이 능동태인데 [1차 한글 번역문]이 '나는 그에게 맞았다'와 같이 수동태(피동태)라면 \
                    이는 동일한 상황이지만, 정보의 양이 다른 것으로 판단해. \
                    [1차 한글 번역문]이 능동태이고 [한글 대화]가 수동태(피동태)인 경우도 마찬가지로 정보의 양이 다른 것으로 판단해. \n\
                    \
                    따라서 [1차 한글 번역문]과 [한글 대화]의 의미가 일치하지 않거나 정보의 양이 다르거나 둘 다 수동태(피동태)이면,\
                    [1차 한글 번역문]과 [1차 영어 번역문]은 무시하고 [한글 대화]만을 가지고 다시 번역하면 돼.\n\
                    ***important*** 단 다시 번역할 때 [한글 대화]가 수동태(피동태)라면, 이를 능동태로 변경한 뒤 번역하면 돼.\
                    그리고 새롭게 생성한 영어 번역문은 <translate>로 시작하고 </translate>로 끝내, \
                    만약 추론이 필요하다면 <reasoning>으로 시작해서 추론 내용을 입력하고 </reasoning>으로 마무리해. \
                    추론할 때는 이 대사의 주어가 무엇인지도 생각해. 평서문이나 의문문에서 주어는 무조건 [검토한 영어 번역문]에 있어야 해.\
                    ***important*** 그리고 출력에 다음 대사나 이전 대사의 내용을 추가하지말고, 주어진 [한글 대화]의 내용만으로 번역문을 구성해. \
                    대신 [한글 대화]가 의문문이나 평서문인데 주어가 없는 경우 알맞은 주어를 추가해서 번역해야해. \
                    대신 의문문이나 평서문이 아닌 다른 종류의 문장인 경우, 주어를 생략해도 괜찮아. \
                    즉 정리하자면 출력 형태는 '<reasoning> ...추론 내용... </reasoning>\n<translate> 검토한 영어 번역문 </translate>' \
                    혹은 '<translate> 검토한 영어 번역문 </translate>' 가 될 거야"
                }
            ],
}
#[한글 대화]의 내용만으로 번역문을 구성하라고 한 이유는 이어진 문장을 먼저 처리하고 남은 문장을 처리하는 것이기 때문에임 (즉 이어진 문장이 없다고 가정)

# %%
import re

def clean_text(text):
    return re.sub(r'^\d+\s+\[UNK\]\s+', '', text)
def clean_text2(text):
    return re.sub(r'^\d+\s+','', text)

def extract_translation(text):
    match = re.search(r'<translate>(.*?)</translate>', text, re.DOTALL)
    return match.group(1).strip() if match else None

review_li = []
for i, r in enumerate(response_split):
    # if i == 10:#10줄만 스캔
    #     break
    review_text = f"{source}\n\n### review\n[한글 대화] {source[i]}\n[1차 영어 번역문] {clean_text2(r)}\n\n" 
    # if i == 0:
    #     print(review_text)
    review_completion = openai_client.beta.chat.completions.parse(
        model= GPT_BASE_MODEL,
        messages = [
            SYSTEM_REVIEW_PROMPT,
            {
                "role":"user",
                "content" : [{"type" : "text",
                              "text" : review_text
                            }],
            }
        ],
        temperature= 0.2,
        top_p = 0.7
    )
    review = review_completion.choices[0].message.content
    print(review)
    review_li.append(extract_translation(review))
# Out:
# <reasoning> [한글 대화]는 "『금일 오후,"로, 이는 "This afternoon," 또는 "Today afternoon," 정도로 번역될 수 있는 문장이다. 반면 [1차 영어 번역문]은 “my lady, I would like to invite you...”로, 이는 "아가씨, 당신을 초대하고 싶습니다..."라는 의미이다. 즉, [1차 영어 번역문]은 [한글 대화]보다 훨씬 더 많은 정보를 담고 있으며, 이는 정보의 양이 다른 경우에 해당한다. 따라서 [1차 영어 번역문]은 무시하고, [한글 대화]만을 기반으로 다시 번역해야 한다. [한글 대화]는 인용문 형태이며, 문장의 일부로 보인다. 주어는 생략되어 있지만, 문맥상 편지를 쓰는 사람이 말하는 것으로 보이므로 "I"를 주어로 설정할 수 있다. </reasoning>
# <translate>"This afternoon,"</translate>
# <reasoning> [한글 대화]는 "온실에서 있을 티 파티에 영애를 초대하고 싶습니다."로, 이는 "I would like to invite you to a tea party in the greenhouse." 정도로 번역될 수 있다. 그런데 [1차 영어 번역문]은 "...to a tea party in the greenhouse this afternoon.”으로, 주어와 동사가 생략되어 있고, 시간 정보 "this afternoon"이 추가되어 있다. 원문에는 "금일 오후"라는 시간 정보가 앞 문장(000번)에 있으므로, 이 문장 자체에는 시간 정보가 없다. 따라서 [1차 영어 번역문]은 정보의 양이 더 많고, 문장의 구조도 불완전하다. 또한 주어와 동사가 빠져 있어 문법적으로도 완전하지 않다. 따라서 [1차 영어 번역문]을 무시하고 [한글 대화]를 능동태로 다시 번역해야 한다. 주어는 편지를 쓴 사람으로 추정되며, 일반적으로 "I"로 번역한다. </reasoning>
# <translate>I would like to invite you to a tea party in the greenhouse. </translate>
# <reasoning>
# [한글 대화]는 "시간이 나신다면 꼭 참석해 주세요,"로, 정중한 요청의 표현이다.
# [1차 영어 번역문]은 “please come if you have time,”으로 번역되어 있다.
# 이를 한글로 다시 번역하면 [1차 한글 번역문]은 "시간이 있다면 와 주세요." 정도가 된다.
# 하지만 원문에는 "꼭 참석해 주세요"라는 강조 표현이 포함되어 있고, "참석하다(attend)"라는 단어가 사용되어야 자연스럽다.
# 반면 [1차 영어 번역문]은 단순히 "come"을 사용하여 "참석하다"의 의미를 충분히 전달하지 못하고 있으며, "꼭"이라는 강조도 빠져 있다.
# 따라서 정보의 양이 다르다고 판단된다.
# 또한 원문은 수동태가 아니므로, 능동태로 자연스럽게 다시 번역해야 한다.
# 주어는 생략되어 있으므로, 영어에서는 주어를 넣어야 하며, 문맥상 초대하는 사람이 말하는 것이므로 "I"를 주어로 사용한다.
# </reasoning>
# <translate>I sincerely hope you can attend if you have time. </translate>
# <reasoning> [한글 대화]는 "헤더 아덴 자작 영애."로, 이는 "헤더 아덴"이라는 이름을 가진 자작의 딸(영애)을 지칭하는 표현이다. [1차 영어 번역문]은 "lady heather arden.”으로, 표면적으로는 의미가 일치하는 것처럼 보인다. 하지만 "자작 영애"는 "daughter of Viscount Arden" 또는 "Lady Heather Arden, daughter of Viscount Arden"처럼 번역할 수 있으며, 단순히 "Lady Heather Arden"이라고만 하면 "자작의 딸"이라는 정보가 누락된다. 따라서 정보의 양이 다르다고 판단된다. 그러므로 [1차 영어 번역문]은 무시하고 [한글 대화]를 능동태로 번역해야 한다. 다만 이 문장은 단순한 호칭이므로, 능동태로 바꿀 필요 없이 적절한 호칭으로 번역하면 된다. 영어에서는 귀족 호칭이 이름 앞에 붙는 것이 일반적이므로 "Lady Heather Arden"이 적절하다. 하지만 "daughter of Viscount Arden"이라는 정보가 포함되어야 정보의 양이 일치한다. </reasoning>
# <translate>Lady Heather Arden, daughter of Viscount Arden.</translate>
# <reasoning> [한글 대화] "이 사람,"은 특정 인물을 보고 놀라거나 알아보는 상황에서 쓰이는 감탄 또는 인식의 표현이다. 이는 감탄사에 가까운 짧은 문장으로, 주어가 생략되어 있지만 문맥상 화자가 어떤 사람을 보고 있다는 것을 의미한다. [1차 영어 번역문] "isn’t this..."는 문법적으로 주어가 "this"이고, 의문문 형태로 되어 있다. 그러나 "이 사람,"은 의문문이 아니라 감탄 또는 인식의 표현이므로 문장 유형이 다르다. 또한 "isn’t this..."는 문장이 완성되지 않은 채로 끝나 있어서 의미 전달이 불완전하다. 따라서 의미가 일치하지 않으며, [한글 대화]에 기반해 감탄의 의미를 살려 능동적인 영어 표현으로 새롭게 번역해야 한다. 주어는 생략되어 있지만 문맥상 화자가 보고 있는 인물을 지칭하므로 "That person" 또는 "It's her"와 같은 표현이 적절하다. </reasoning>
# <translate>That person... </translate>
# <reasoning>
# [한글 대화]는 "어제 시그렌이랑 일이 있었던 그 영애 아냐?"로, 이는 특정 여성이 어제 시그렌과 어떤 일이 있었다는 사실을 상기하며 그 여성을 지칭하는 의문문이다.
# [1차 영어 번역문]은 "the lady who caused a scene with siegren yesterday?"로, 이는 "어제 시그렌과 소란을 일으킨 그 여자인가?"라는 의미이다.
# 하지만 "일이 있었다"는 표현은 중립적인 사건을 의미할 수 있는 반면, "caused a scene"은 부정적인 의미를 담고 있어 의미가 일치하지 않는다.
# 또한, 원문은 "그 영애 아냐?"라는 의문형인데, 영어 번역문은 주어가 생략되어 있어 문법적으로 완전하지 않다.
# 따라서 [1차 영어 번역문]은 의미가 다르고, 주어도 없으므로 새로 번역해야 한다.
# 이 문장의 주어는 화자이며, 의문문이므로 주어를 포함한 문장으로 번역해야 한다.
# </reasoning>
# <translate>Isn't she the lady who had something going on with Siegren yesterday?</translate>
# <reasoning>
# [한글 대화]는 "그런 사람이 여는 티파티에 내가 가도 되는 건가?"로, 주어는 '내가'이고, 의문문이다.
# [1차 영어 번역문] "should I really go to a tea party hosted by someone like that?"을 한글로 번역하면 "정말 그런 사람이 여는 티파티에 내가 가야 할까?" 정도가 된다.
# 여기서 '정말'이라는 부사가 추가되어 있어 [1차 한글 번역문]은 원문보다 정보가 더 많다. 따라서 정보의 양이 다르다.
# 또한 "hosted by someone like that"은 수동태 표현이다. [한글 대화]의 "그런 사람이 여는"도 수동이 아닌 듯 보이지만, 영어로 번역할 때 수동태가 되었다.
# 따라서 정보의 양이 다르고 수동태이므로, [1차 영어 번역문]은 무시하고 [한글 대화]를 능동태로 다시 번역해야 한다.
# 주어는 'I'이고, "go to a tea party"가 핵심 동작이며, "someone like that is hosting"으로 능동태로 표현해야 한다.
# </reasoning>
# <translate>Should I go to a tea party that someone like that is hosting?</translate>
# <reasoning> [한글 대화]는 "내가 괜히 신경 쓸 만한 이유는 없지."로, 이는 화자가 어떤 일에 대해 걱정하거나 신경 쓸 필요가 없다고 스스로 판단하는 내용이다. 반면 [1차 영어 번역문] "well, I don’t see why not."은 일반적으로 어떤 제안이나 행동에 대해 "굳이 안 될 이유는 없지"라는 의미로, 긍정적인 수락의 의미에 가깝다. 즉, [한글 대화]는 걱정할 필요가 없다는 자기 확신의 표현이고, [1차 영어 번역문]은 어떤 제안을 수락하는 뉘앙스이므로 의미가 일치하지 않는다. 따라서 [한글 대화]를 기준으로 다시 번역해야 하며, 주어는 "I"로 설정하고 능동태로 번역한다. </reasoning>
# <translate>I don't have any reason to worry about it. </translate>
# <reasoning> [한글 대화]는 "잘못한 건 그쪽이고."로, 주어가 명시되어 있지 않지만 문맥상 '그쪽'은 앞서 언급된 인물(시그렌과 일이 있었던 영애)로 추론할 수 있다. [1차 영어 번역문]은 "she’s the one who was in the wrong, not me."로, 주어가 'she'로 명확히 드러나 있으며, 'not me'라는 표현을 통해 화자가 잘못하지 않았음을 강조하고 있다. 이는 원문에는 없는 정보이므로 정보의 양이 다르다. 따라서 [1차 영어 번역문]은 사용할 수 없으며, [한글 대화]를 능동태로 재번역해야 한다. 원문의 수동 표현 "잘못한 건 그쪽이고"를 능동태로 바꾸면 "그쪽이 잘못했다"가 되며, 이를 영어로 번역하면 "She did something wrong." 또는 "She was wrong."이 될 수 있다. 하지만 좀 더 자연스럽고 강한 어조를 위해 "She was the one who did wrong."으로 번역하는 것이 적절하다. </reasoning>
# <translate>She was the one who did wrong.</translate>
# <reasoning> [한글 대화]는 "어쩌면 티파티에서 유니스를 만날 수 있을지도 모르니까."로, 이는 말하는 사람이 티파티에 가는 이유를 설명하는 문장이다. "어쩌면"이라는 불확실성을 나타내는 부사와 "티파티에서"라는 장소, 그리고 "유니스를 만날 수 있을지도 모른다"는 가능성을 표현하고 있다. 반면 [1차 영어 번역문] "and I might be able to see eunice there."는 "and"로 시작해 앞 문장이 있어야 자연스러운 연결이 되며, "there"라는 지시어가 등장하지만 구체적인 장소(티파티)가 명시되지 않았다. 따라서 정보의 양이 다르며, "티파티"라는 장소 정보가 누락되었기 때문에 [1차 영어 번역문]은 사용할 수 없다. 또한 원문은 평서문이므로 주어가 필요하며, 주어는 말하는 사람인 "I"이다. 이를 바탕으로 능동태로 다시 번역해야 한다. </reasoning>
# <translate>I might be able to see Eunice at the tea party. </translate>
# <reasoning> [한글 대화]는 "기쁜 마음으로 응하겠다고 전해줘."로, 이는 "내가 기쁜 마음으로 응하겠다"는 의사를 제3자에게 전달해달라는 요청이다. [1차 영어 번역문] "tell her I’ll be happy to attend"는 이를 잘 반영하고 있으며, 주어 "I"가 명시되어 있고, "기쁜 마음으로 응하겠다"는 의미도 "I'll be happy to attend"로 정확히 전달되었다. 정보의 양도 동일하며, 수동태도 아니다. 따라서 그대로 사용해도 된다. </reasoning>
# <translate>Tell her I’ll be happy to attend.</translate>
# <reasoning> [한글 대화]는 "유니스 영애."로, 이는 누군가를 부르는 호칭이다. [1차 영어 번역문]은 "lady eunice."로, 대소문자 오류를 제외하면 의미는 일치한다. 영어에서는 이름 앞에 호칭이 붙을 경우 첫 글자를 대문자로 써야 하므로 "Lady Eunice."가 맞다. 정보의 양이나 의미는 동일하므로, 단순히 문법적 오류만 수정하면 된다. </reasoning>
# <translate>Lady Eunice.</translate>
# <reasoning> [한글 대화]는 "피오나 영애…!"로, 감탄사와 함께 특정 인물을 부르는 표현이다. [1차 영어 번역문]은 "lady fiona!"로, 감탄사 없이 단순히 이름만 번역되어 있다. 원문의 감탄사("…!")는 놀람이나 반가움, 당황스러움 등의 감정을 담고 있으며, 영어에서도 이를 반영하려면 감탄사(!)와 함께 감정이 실린 표현이 필요하다. 따라서 정보의 양이 다르다고 판단되며, 새로 번역해야 한다. 주어는 생략 가능한 감탄문이므로 굳이 넣지 않아도 된다. </reasoning>
# <translate>Lady Fiona!</translate>
# <reasoning> [한글 대화]는 "유니스 영애도 초대받은 건가요?"로, 주어는 생략되어 있지만 문맥상 화자가 유니스 영애에게 묻고 있는 것으로 보이며, 이는 의문문이다. [1차 영어 번역문] "were you invited to the tea party as well?"은 수동태 문장이다. [한글 대화] 역시 피동 표현인 "초대받은"을 사용하고 있어 수동태이다. 따라서 [한글 대화]와 [1차 영어 번역문] 모두 수동태이므로, 능동태로 다시 번역해야 한다. 주어는 "they" 또는 "someone"으로 추론할 수 있으며, "Did someone invite you to the tea party as well?"로 능동태로 바꿔 표현할 수 있다. </reasoning>
# <translate>Did someone invite you to the tea party as well?</translate>
# <translate> Yes. </translate>
# <reasoning> [한글 대화]는 "피오나 영애와는 같은 일행임에도 계속 얼굴을 볼 수가 없었네요."로, 주어는 화자이며, 피오나 영애와 같은 일행이었음에도 불구하고 얼굴을 볼 수 없었다는 아쉬움을 표현하고 있다. [1차 영어 번역문] "I haven’t been able to see you even though we’re traveling together."는 주어가 "I", 목적어가 "you"로 되어 있어, 피오나 영애가 아닌 유니스 영애에게 말하는 것으로 해석된다. 그러나 원문에서는 피오나 영애에 대해 말하고 있으므로, 대상이 다르다. 즉, 의미가 일치하지 않으며 정보의 양도 다르다. 따라서 [1차 영어 번역문]은 무시하고 [한글 대화]를 능동태로 새롭게 번역해야 한다. 주어는 화자이며, 피오나 영애와 같은 일행이었음에도 얼굴을 볼 수 없었다는 내용이다. </reasoning>
# <translate>Even though I was in the same group as Lady Fiona, I haven’t been able to see her at all. </translate>
# <reasoning> [한글 대화] "전 말을 타고 있었거든요."는 과거에 말을 타고 있었다는 설명이다. [1차 영어 번역문] "I’ve been riding a horse."는 현재완료 진행형으로, 최근까지 말을 타고 있었던 상태를 의미한다. 하지만 원문은 단순히 과거에 말을 탔다고 말하는 것이므로 시제 차이가 있다. 또한, 원문은 "전"이라는 주어가 명확히 존재하므로 영어 번역에서도 주어를 명시해야 한다. 따라서 단순 과거 시제를 사용해 "I was riding a horse."로 번역하는 것이 적절하다. </reasoning>
# <translate>I was riding a horse. </translate>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 19
#      16 review_text = f"{source}\n\n### review\n[한글 대화] {source[i]}\n[1차 영어 번역문] {clean_text2(r)}\n\n"
#      17 # if i == 0:
#      18 #     print(review_text)
# ---> 19 review_completion = openai_client.beta.chat.completions.parse(
#      20     model= GPT_BASE_MODEL,
#      21     messages = [
#      22         SYSTEM_REVIEW_PROMPT,
#      23         {
#      24             "role":"user",
#      25             "content" : [{"type" : "text",
#      26                           "text" : review_text
#      27                         }],
#      28         }
#      29     ],
#      30     temperature= 0.2,
#      31     top_p = 0.7
#      32 )
#      33 review = review_completion.choices[0].message.content
#      34 print(review)
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/openai/resources/beta/chat/completions.py:161, in Completions.parse(self, messages, model, audio, response_format, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, seed, service_tier, stop, store, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     154 def parser(raw_completion: ChatCompletion) -> ParsedChatCompletion[ResponseFormatT]:
#     155     return _parse_chat_completion(
#     156         response_format=response_format,
#     157         chat_completion=raw_completion,
#     158         input_tools=tools,
#     159     )
# --> 161 return self._post(
#     162     "/chat/completions",
#     163     body=maybe_transform(
#     164         {
#     165             "messages": messages,
#     166             "model": model,
#     167             "audio": audio,
#     168             "frequency_penalty": frequency_penalty,
#     169             "function_call": function_call,
#     170             "functions": functions,
#     171             "logit_bias": logit_bias,
#     172             "logprobs": logprobs,
#     173             "max_completion_tokens": max_completion_tokens,
#     174             "max_tokens": max_tokens,
#     175             "metadata": metadata,
#     176             "modalities": modalities,
#     177             "n": n,
#     178             "parallel_tool_calls": parallel_tool_calls,
#     179             "prediction": prediction,
#     180             "presence_penalty": presence_penalty,
#     181             "reasoning_effort": reasoning_effort,
#     182             "response_format": _type_to_response_format(response_format),
#     183             "seed": seed,
#     184             "service_tier": service_tier,
#     185             "stop": stop,
#     186             "store": store,
#     187             "stream": False,
#     188             "stream_options": stream_options,
#     189             "temperature": temperature,
#     190             "tool_choice": tool_choice,
#     191             "tools": tools,
#     192             "top_logprobs": top_logprobs,
#     193             "top_p": top_p,
#     194             "user": user,
#     195         },
#     196         completion_create_params.CompletionCreateParams,
#     197     ),
#     198     options=make_request_options(
#     199         extra_headers=extra_headers,
#     200         extra_query=extra_query,
#     201         extra_body=extra_body,
#     202         timeout=timeout,
#     203         post_parser=parser,
#     204     ),
#     205     # we turn the `ChatCompletion` instance into a `ParsedChatCompletion`
#     206     # in the `parser` function above
#     207     cast_to=cast(Type[ParsedChatCompletion[ResponseFormatT]], ChatCompletion),
#     208     stream=False,
#     209 )
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/openai/_base_client.py:1290, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1276 def post(
#    1277     self,
#    1278     path: str,
#    (...)
#    1285     stream_cls: type[_StreamT] | None = None,
#    1286 ) -> ResponseT | _StreamT:
#    1287     opts = FinalRequestOptions.construct(
#    1288         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1289     )
# -> 1290     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/openai/_base_client.py:967, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     964 else:
#     965     retries_taken = 0
# --> 967 return self._request(
#     968     cast_to=cast_to,
#     969     options=options,
#     970     stream=stream,
#     971     stream_cls=stream_cls,
#     972     retries_taken=retries_taken,
#     973 )
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/openai/_base_client.py:1003, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1000 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#    1002 try:
# -> 1003     response = self._client.send(
#    1004         request,
#    1005         stream=stream or self._should_stream_response_body(request=request),
#    1006         **kwargs,
#    1007     )
#    1008 except httpx.TimeoutException as err:
#    1009     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /opt/conda/lib/python3.10/ssl.py:1292, in SSLSocket.recv(self, buflen, flags)
#    1288     if flags != 0:
#    1289         raise ValueError(
#    1290             "non-zero flags not allowed in calls to recv() on %s" %
#    1291             self.__class__)
# -> 1292     return self.read(buflen)
#    1293 else:
#    1294     return super().recv(buflen, flags)
#
# File /opt/conda/lib/python3.10/ssl.py:1165, in SSLSocket.read(self, len, buffer)
#    1163         return self._sslobj.read(len, buffer)
#    1164     else:
# -> 1165         return self._sslobj.read(len)
#    1166 except SSLError as x:
#    1167     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
#assert len(response_split) == len(review_li) == len(source)
def clean_text(text):
    return re.sub(r'^\d+\s+\[UNK\]\s+', '', text)
def clean_text2(text):
    return re.sub(r'^\d+\s+','', text)
for i in range(10):#len(response_split)):
    hangle = clean_text(source[i])
    print(f'[한글]{hangle}')
    first_translate = clean_text2(response_split[i])
    print(f'[기존]{first_translate}')
    second_translate = review_li[i]
    print(f'[리뷰]{second_translate}')
    print()
# Out:
# [한글]『금일 오후,
# [기존]“my lady, I would like to invite you to a tea party in the greenhouse this afternoon.”
# [리뷰]"This afternoon,"
#
# [한글]온실에서 있을 티 파티에 영애를 초대하고 싶습니다.』
# [기존]“my lady, I would like to invite you to a tea party in the greenhouse this afternoon.”
# [리뷰]“My lady, I would like to invite you to the tea party that will be held in the greenhouse.”
#
# [한글]『시간이 나신다면 꼭 참석해 주세요,
# [기존]“please attend if you have time,
# [리뷰]Please make sure to attend if you have time.
#
# [한글]헤더 아덴 자작 영애.』
# [기존]lady heather adens.”
# [리뷰]Lady Heather Aden.
#
# [한글]이 사람,
# [기존]isn’t she...
# [리뷰]That person,
#
# [한글]어제 시그렌이랑 일이 있었던 그 영애 아냐?
# [기존]...the lady who was with siegren yesterday?
# [리뷰]Isn't she the lady who had an incident with Siegren yesterday?
#
# [한글]그런 사람이 여는 티파티에 내가 가도 되는 건가?
# [기존]should I really go to a tea party hosted by someone like that?
# [리뷰]Am I even allowed to attend a tea party hosted by someone like that?
#
# [한글]내가 괜히 신경 쓸 만한 이유는 없지.
# [기존]well, I guess there’s no reason for me to be worried.
# [리뷰]There’s no reason for me to care.
#
# [한글]잘못한 건 그쪽이고.
# [기존]she’s the one who did something wrong.
# [리뷰]She's the one at fault.
#
# [한글]어쩌면 티파티에서 유니스를 만날 수 있을지도 모르니까.
# [기존]I might be able to see eunice at the tea party.
# [리뷰]I might be able to see Eunice at the tea party.
