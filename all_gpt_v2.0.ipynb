# %%
import re
from langchain_community.vectorstores import FAISS
from langchain.docstore.document import Document
import bs4
import ssl
import urllib3
import pandas as pd
import faiss
import os
from langchain.embeddings import HuggingFaceEmbeddings
import torch
import gc
from tqdm import tqdm
from openai import OpenAI

def instruct_structure(prompt):
    input_text, output_text = prompt.split('### target')
    input_text = input_text.replace('### glossaries', '### glossary').replace('\n* ', '\n• ')
    input_text = re.sub(r"\[[^\]]+\] ", "[UNK] ", input_text)
    return input_text

project_id = "prod-ai-project"

from google.cloud import bigquery
client = bigquery.Client(project=project_id)
sql = """select series_id, episode_id, org_input_text, org_output_text, prompt 
        from webtoon_translation.structured_240820_ep_line
        where data_split = 'romance_valid'"""
df = client.query(sql).result().to_dataframe()
tqdm.pandas()
df['prompt'] = df['prompt'].progress_apply(lambda x: instruct_structure(x))


GPT_FINE_TUNING_MODEL="ft:gpt-4o-2024-08-06:kakaoent:webtoon-sft-250225:B4j839q0"
openai_client = OpenAI(
    api_key='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')

GPT_BASE_MODEL = "chatgpt-4o-latest"
SYSTEM_PROMPT = {
            "role": "system",
            "content": [
                {
                    "type": "text",
                    "text": """You're an expert translator who translates Korean webtoon in English. Make sure the number of target sentences matches the number of source sentences. The result should be TSV formatted. 
            • Find a balance between staying true to the Korean meaning and keeping a natural flow. Don't be afraid to add to the text. Embellish it. 
            • Avoid translating word-for-word. Keep the general feeling and translate the text accordingly. 
            • Translate with an American audience in mind. This means easy-to-read, conversational English.""",
                }
            ],
        }

SYSTEM_REVIEW_PROMPT = {
            "role": "system",
            "content": [
                {
                    "type": "text",
                    "text": "너는 [한국어 대화문] 내의 연결된 대사들을 분석하고 이를 [대사 문단]으로 정의한 뒤, [1차 번역문] 상에서 잘 번역되어 있는지 확인하는 태스크를 수행할거야. \
                    그리고 만약 [1차 번역문]이 잘못된 경우, 이를 수정해서 재생성하는 태스크를 수행할 거야. \
                    먼저 맥락을 이해하기 위해 한 회차의 모든 [한국어 대화문]이 주어지고, \
                    이를 1차 번역한 [1차 번역문]이 주어질거야. \
                    각 대사에는 번호가 붙어 있을 것이고, 같은 번호는 같은 문장을 지칭해. 즉 [한국어 대화문]의 005번 대사를 번역한 것은 [1차 번역문]의 005번 대사라고 생각하면 돼.\
                    지금부터 너는 [한국어 대화문]에서 이어진 대사를 구별해내고, 이어진 대사들이 [1차 번역문] 상에서 올바르게 번역되어 있는지 검수한 후, \
                    올바르게 번역되지 않았다면 [단어집]을 참고해서 수정하고, \
                    올바르게 번역 되어있다면 그대로 생성할거야.\n\
                    먼저 배경지식을 알려주자면 웹툰에서 '...'은 이전 대사나 이후 대사와의 연결성을 의미할 가능성이 커. 100%는 아니야. \
                    다시 말해서 '...'으로 시작하면 이전 대사와 현재 대사가 연결되어 있을 가능성이 크고, \
                    '...'으로 끝나면 다음 대사와 현재 대사가 연결되어 있을 가능성이 커.\n\
                    태스크를 올바르게 수행하기 위해서 너는 첫 번째로 [대사 문단]을 찾아야해. \
                    [대사 문단]이란 [한국어 대화문] 내에서 화자가 동일한 연속되는 대사가 '모두' 불완전하고, 이전 혹은 다음 대사와 연결했을 때 더 자연스러운 대사들을 결합한 것을 의미해. \
                    예를 들어 6개의 대사로 구성된 [한국어 대화문]과 [1차 번역문]이 있다고 가정해볼게. \n\
                    '[한국어 대화문]\n000\t어제,\n001\t나는 푸른...\n002\t하늘을 보았다.\n003\t어땠어?\n004\t정말,\n005...아름다웠어.\n' \
                    라는 [한국어 대화문]이 있다면 [대사 문단]은 [(000,001,002),(004,005)]로 구성될 수 있어.\
                    왜냐하면 000, 001, 002 대사는 웹툰 내에서 동일한 한 명의 등장인물이 연속적으로 발화한 것으로 보이며, 각 대사가 '모두' 불완전하고 세 개의 대사를 결합했을 때 딱 한 문장으로 결합돼.\
                    ***important*** 여기서 개념을 하나 설명할게. 너가 수행하는 태스크에서 '불완전한 대사'를 명확히 설명해줄게. \
                    '(1)000\t당신!\n001\t밥\n002\t먹었어?\n','(2)000\t너,\n001\t밥 먹었어?\n002\t난 이제 먹어야하는데.\n003\t뭐 먹었어?\n' 와 같은 예시가 주어졌다고 가정해보자.\
                    두 가지 예시 모두 '(1)당신 밥 먹었어?','(2)너 밥 먹었어? 난 이제 먹어야하는데. 뭐 먹었어?' 와 같이 결합했을 때 \
                    (1)과 (2)모두 동일한 화자가 연속적으로 발화하는 대사들이지만 (2)의 '난 이제 먹어야하는데.', '뭐 먹었어?' 같은 대사는 하나의 독립적인 완전한 대사로써, \
                    (2) 전체를 결합하면 3문장의 대사가 나와. 이건 완전한 대사 3개가 결합되어 있다는 뜻이야. [대사 문단]에 넣기 위해서는 불안전한 대사를 모두 결합했을 때 딱 한 문장의 대사가 나와야해.\n\
                    반면 (1)의 '당신!','밥','먹었어?'와 (2)의 '너,','밥 먹었어?'는 각각 하나의 독립적인 대사로 활용했을 때 불완전한 대사로 보기 때문에 이전 혹은 이후 대사와 결합해야해.\
                    좀 더 구체적으로 설명하자면 (1)의 '당신!'은 독립적으로 사용가능한 완전한 대사로 볼 수 있지만, 뒤에 있는 대사 '밥'이 불완전한 대사이고, '당신! 밥 먹었어?' 라고 연결했을 때 한 문장으로 볼 수 있으므로, \
                    완전한 대사인 '당신!'과 불완전한 대사인 '밥'과 '먹었어?'를 결합하여 [대사 문단]의 한 원소로 넣는거야.\
                    그리고 (2)의 001 번 째 대사인 '밥 먹었어?'같은 경우는 독립적으로 사용가능한 완전한 대사로 볼 수 있지만, 앞 대사가 '너,'라는 뒤에 있는 대사를 필요로 하는 불완전한 대사이고, \
                    '너, 밥 먹었어?'라고 연결했을 때 한 문장으로 볼 수 있으므로, 불완전한 대사인 '너,'와 완전한 대사인 '밥 먹었어?'를 결합하여 [대사 문단]의 한 원소로 넣는거야.\
                    그리고 불완전한 대사라는 걸 증명할 수 있는 근거가 불완전한 대사들을 결합하면 한 문장의 대사가 나오게 돼. \
                    즉 웹툰의 대사를 생각했을 떄 (1)의 모든 대사와 (2)의 일부 대사처럼 한 문장의 대사가 불완전하게 여러 대사로 나뉜 경우만 [대사 문단]의 한 원소가 될 수 있고,\
                    (2)의 '난 이제 먹어야하는데.', '뭐 먹었어?'처럼 현재 대사가 완전한 문장인데, 앞 뒤 대사에 불완전한 문장이 없고, 각 대사가 한 문장인 경우는 [대사 문단]의 한 원소가 될 수 없다는 뜻이야.\n\
                    다시 돌아가서, [대사 문단]을 찾을 때는 동일한 화자가 연속적으로 발화한 대사인지를 엄격하게 검수한 후에, \
                    각 대사를 결합했을 때 한 문장이 된다면 해당 대사들을 묶어서 [대사 문단]의 한 원소로 정의하면 돼. \
                    그리고 003은 앞과 뒤 화자와는 다른 화자임이 분명하기 때문에 [대사 문단]의 한 원소로 포함될 수 없어. \
                    좀 더 다른 예를 들어 설명하자면 '(3)100\t너 말이야\n101\t뭐가?\n102\t좀 이상한 거 같애\n'라는 대사가 주어졌을 때 \
                    100 번 째 대화와 102 번 째 대화의 화자는 같은 것으로 판단되지만 중간에 101 번 째 대화는 다른 화자인 것으로 판단되기 때문에 3가지의 대사는 결합돼서는 안 돼. 즉 [대사 문단]의 한 원소로 포함될 수 없어.\n\
                    그리고 004,005 또한 동일한 화자가 발화하고 있는 것으로 판단되고, 각 대사가 독립적으로 사용하기엔 불완전하고, 각 대사를 결합하면 딱 한 문장이 되기 때문에, \
                    결합하여 [대사 문단]의 한 원소로 포함시켜. \n\
                    그 다음에 [한국어 대화문]에 속한 모든 대사에 대해서 [대사 문단]을 찾고 실제 하나의 대사 문단으로 결합해. \
                    위 예시대로라면 [(000,001,002,'어제 나는 푸른 하늘을 보았다.'),(004,005,'정말 아름다웠어.')]라는 결과가 나올거야. \
                    [대사 문단]의 한 원소에 대한 각 대사들을 하나의 문단으로 결합할 때는 '...', ','와 같은 연결을 위한 특수 문자는 제거해.\n\
                    그리고 이제 함께 주어진 [1차 번역문]이 다음과 같다고 해볼게.\n\
                    '[1차 번역문]\n000\tyesterday,\n001\tI...\n002\tsaw the blue sky.\n003\thow was it?\n004\tit was\n005really dark.\n'\
                    그랬을 때 [대사 문단]에 쓰여진 것과 동일하게 결합해. 위 예에서는 [한국어 대화문] 상에서 (000,001,002), 그리고 (004,005)가 각각 결합되었기 때문에 \
                    동일하게 [1차 번역문] 상에서도 (000,001,002)와 (004,005)를 결합하고 (연결을 위한 특수 문자는 제거) 이전 결과물에 붙여. \
                    그렇게 하면, 다음과 같은 결과물을 얻을 수 있어.\n \
                    [((000,001,002),'어제 나는 푸른 하늘을 보았다.','yesterday I saw the blue sky.'),\
                    ((004,005),'정말 아름다웠어.','it was really dark.')]\n \
                    그 다음 리스트 내 각 원소의 한글 문장과 영어 문장의 의미를 비교해.\
                    만약 '어제 나는 푸른 하늘을 보았다.'와 'yesterday I saw the blue sky.'처럼 두 문장의 의미가 동일하다면 \
                    영어 문장을 해당 문장을 구성한 대사의 개수 n개(해당 예에서는 000,001,002:3개)로 나누고, 나뉘는 부분 양 쪽에 '...'를 삽입해. \n\
                    ***important*** 단, 나눌 때 해당 문장을 구성하는 대사 개수 n개로만 나눠야 하며, 나누는 개수를 유지하면서 최대한 웹툰 독자가 읽기에 편하도록 나누고, 나눈 이후의 각 요소는 적어도 하나의 단어를 포함하고 있어야 해.\n\
                    예를 들어 'yesterday', 'I saw', 'the blue sky.'로 나누는게 웹툰 대사상 적합하다고 생각한다면, \n\
                    '000\tyesterday...\n001\t...I saw...\n002\t...the blue sky.\n' 를 생성하는거야. \n\
                    그리고 이어서 003은 [대사 문단]에 속하지 않기 때문에 [1차 번역문]의 003번을 똑같이 생성해. 그러면 다음과 같이 될거야.\n \
                    '003\thow was it?\n'\n\
                    그 다음 004번과 005번이 [대사 문단]의 한 원소이기 때문에 '정말 아름다웠어.'와 'it was really dark.'의 의미를 비교하고, \
                    둘의 의미가 다른 경우에는 영어 문장을 무시하고, 한글 문장을 번역해. \
                    여기서는 'it was really dark.'를 무시하고, '정말 아름다웠어.'를 번역하면 돼. 대신 재번역할 때 참고해야할 고유명사가 있을 수도 있으니 [단어집]을 참고해서 번역해. \
                    그럼 'it was really beautiful.'을 얻을 수 있고, 이를 똑같이 [대사 문단]을 구성하는 대사 개수인 n개(해당 예에서는 004,005:2개)로 나누고, 나뉘는 부분 양 쪽에 '...'를 삽입해. \n\
                    ***important*** 단, 나눌 때 해당 문장을 구성하는 대사 개수 n개로만 나눠야 하며, 나누는 개수를 유지하면서 최대한 웹툰 독자가 읽기 편하도록 나누고, 나눈 이후의 각 요소는 적어도 하나의 단어를 포함하고 있어야 해.\n\
                    예를 들어 'it was', 'really beautiful'로 나누는게 웹툰 대사상 적합하다고 생각한다면, \
                    '004\tit was...\n005\t...really beautiful.\n'를 생성하는거야. \
                    위 예의 최종적인 출력형태는 다음과 같아. \n\
                    <translate>\n000\tyesterday...\n001\t...I saw...\n002\t...the blue sky.\n003\thow was it?\n004\tit was...\n005\t...really beautiful.\n</translate>\
                    그리고 만약 추론이 필요하다면 <reasoning>으로 시작해서 추론 내용을 입력하고 </reasoning>으로 마무리해. \
                    즉 정리하자면 출력 형태는 '<reasoning> ...추론 내용... </reasoning> <translate> 검토한 영어 번역문 </translate>' \
                    혹은 '<translate> 검토한 영어 번역문 </translate>' 가 될 거야.\n \
                    그리고 [검토한 영어 번역문]에는 [한국어 대화문]에 속한 모든 대사 개수만큼이 포함되어야 하는 것을 잊지마."
                }
            ],
}

SYSTEM_REVIEW_PROMPT2 = {
            "role": "system",
            "content": [
                {
                    "type": "text",
                    "text": "너는 1차 번역된 웹툰 대화를 검토하고 이를 수정하거나 아예 재생성하는 태스크를 수행할 거야. \
                    먼저 맥락을 이해하기 위해 한 회차의 모든 한국어 대화문이 주어지고, \
                    그 중에서 맨 마지막 두 줄에 [한글 대화]와 이 대화에 대응되는 [1차 영어 번역문]이 주어질 거야. \
                    먼저 [1차 영어 번역문]을 한글로 번역해서 [1차 한글 번역문]을 생성하고, [한글 대화]의 의미가 일치하는지 비교해.\n\
                    만약 의미가 일치한다면 \
                    [한글 대화]에서 glossary에서 존재하는 표현은 없는지 검토하고, 만약 있다면 이를 반영해서 \
                    더 나은 [검토한 영어 번역문]을 생성해줘. 물론 [한글 대화]에 glossary에 존재하는 표현도 없고 기존 영어 번역문이 완벽하다면 그대로 생성해도 돼. \
                    하지만 만약 [1차 한글 번역문]과 [한글 대화]의 의미가 일치하지 않거나 정보의 양이 다르다면 \
                    [1차 영어 번역문]과 [1차 한글 번역문]은 무시하고 [한글 대화]에 대응하는 영어 번역문을 생성해.\
                    예를 들어 [한글 대화]가 '사과'인데 [1차 한글 번역문]이 '붉은 사과'라면 \
                    이는 [한글 대화]에 [1차 한글 번역문]의 일부만 제공된 상태이기 때문에 정보의 양이 다른 것으로 판단해. \
                    그렇기 때문에 [1차 한글 번역문]과 [1차 영어 번역문]은 무시하고 [한글 대화]만을 가지고 다시 번역하면 돼.\n \
                    그리고 새롭게 생성한 영어 번역문은 <translate>로 시작하고 </translate>로 끝내, \
                    만약 추론이 필요하다면 <reasoning>으로 시작해서 추론 내용을 입력하고 </reasoning>으로 마무리해. \
                    추론할 때는 이 대사의 주어가 무엇인지도 생각해. 필요없으면 주어가 없어도 돼.\
                    ***important*** 그리고 출력에 다음 대사나 이전 대사의 내용을 추가하지말고, 주어진 [한글 대화]의 내용만으로 번역문을 구성해. \
                    쉽게 생각하면 너가 생성한 영어 번역문을 한글로 번역했을 때 주어진 [한글 대화]와 의미가 일치해야해\n \
                    즉 정리하자면 출력 형태는 '<reasoning> ...추론 내용... </reasoning> <translate> 검토한 영어 번역문 </translate>' \
                    혹은 '<translate> 검토한 영어 번역문 </translate>' 가 될 거야"
                }
            ],
}
# Out:
# /home/bun.2/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/google/cloud/bigquery/table.py:1820: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 74/74 [00:00<00:00, 18861.11it/s]

# %%
def clean_text(text):
    return text.replace("[UNK] ","")

def extract_translation(text):
    match = re.search(r'<translate>(.*?)</translate>', text, re.DOTALL)
    return match.group(1).strip() if match else None

for data_idx in range(58, 58+1):
    data = df['prompt'][data_idx]
    example = data.split("### source")[1].strip()
    chat_completion = openai_client.beta.chat.completions.parse(
        model= GPT_FINE_TUNING_MODEL,
        messages = [
            SYSTEM_PROMPT,
            {
                "role":"user",
                "content" : [{"type" : "text",
                              "text" : data
                            }],
            }
        ],
        temperature= 0.2,
        top_p = 0.8
    )
    response = chat_completion.choices[0].message.content
    response_split = response.split('\n')
    source = data.split("### source")[1].strip()
    glossary = data.split("### source")[0].strip()
    
    kor = clean_text(source)
    kor_li = kor.split('\n')
    en = response
    input_text = f"[한국어 대화문]\n{kor}\n\n[1차 번역문]\n{en}\n\n[단어집]\n{glossary}"

    review_text = f"{input_text}\n\n### review\n\n" 
    kor_li = kor.split('\n')
    en_li = en.split('\n')
    #print(kor_li)
    review_li = []
    while True:
        if len(review_li) == len(kor_li):
            break
        # else:
        #     print(len(review_li),len(kor_li))
        review_completion = openai_client.beta.chat.completions.parse(
            model= GPT_BASE_MODEL,
            messages = [
                SYSTEM_REVIEW_PROMPT,
                {
                    "role":"user",
                    "content" : [{"type" : "text",
                                  "text" : input_text
                                }],
                }
            ],
            temperature= 0.2,
            top_p = 0.8
        )
        review = review_completion.choices[0].message.content
        print(review)
        review_li = extract_translation(review).split('\n')
        print(len(review_li),len(kor_li))

    #review_li : 1차 번역문에서 이어진 문장 처리한 2차 번역문
    #kor : 한글 대화문
    #glossary : 용어집
    print("="*20)
    input_text = f"{glossary}\n\n{kor}"
    review_li2 = []
    for i, r in enumerate(review_li):
        if '...' in review_li[i]:
            review_li2.append(review_li[i])
        elif '...' not in review_li[i]:
            review_text2 = f"{input_text}\n\n## review\n[한글 대화] {kor_li[i]}\n[1차 영어 번역문] {review_li[i]}\n\n"
            review_completion2 = openai_client.beta.chat.completions.parse(
                model= GPT_BASE_MODEL,
                messages = [
                    SYSTEM_REVIEW_PROMPT2,
                    {
                        "role":"user",
                        "content" : [{"type" : "text",
                                      "text" : review_text2
                                    }],
                    }
                ],
                temperature= 0.2,
                top_p = 0.8
            )
            review2 = review_completion2.choices[0].message.content
            print(review2)
            review_li2.append(extract_translation(review2))
    assert len(review_li2) == len(review_li)
# Out:
# <reasoning>
# [대사 문단]을 먼저 추출하자.
#
# (000,001,002,003): 동일 화자가 연속적으로 발화한 것으로 보이며, 각 대사가 불완전하고 결합하면 “『금일 오후, 온실에서 있을 티 파티에 영애를 초대하고 싶습니다.』 『시간이 나신다면 꼭 참석해 주세요, 헤더 아덴 자작 영애.』”라는 하나의 문장이 된다.
#
# (004,005): 동일 화자이며, “이 사람, 어제 시그렌이랑 일이 있었던 그 영애 아냐?”로 결합 가능.
#
# (067,068): “해서, 영애도……”로 결합 가능. 불완전한 문장이며 동일 화자.
#
# (073,074,075): “영애, 남의 저택에서 신세를 지고 있는 와중에 전하께 꼬리를 치셨죠? 제 하녀가 말해주었단 말이에요. 어젯밤에-”로 결합 가능. 동일 화자이며, 075는 문장이 끊기지 않고 이어짐.
#
# (085,086): “저는 그 덕분에 권력과 힘, 두 개 다 가지고 있답니다.”로 결합 가능.
#
# (091,092,093): “그리고, 화, 황자 전하….”로 결합 가능.
#
# 따라서 [대사 문단]은 다음과 같다:
# [(000,001,002,003), (004,005), (067,068), (073,074,075), (085,086), (091,092,093)]
#
# 이제 각 대사 문단에 대해 [1차 번역문]이 올바르게 번역되었는지 확인한다.
#
# (000,001,002,003): “『금일 오후, 온실에서 있을 티 파티에 영애를 초대하고 싶습니다.』 『시간이 나신다면 꼭 참석해 주세요, 헤더 아덴 자작 영애.』” → “I would like to invite you to a tea party in the greenhouse this afternoon. Please come if you have time, Lady Heather.” 의미 동일. 다만 000과 001이 동일 문장으로 번역되어 중복되었으므로, 하나만 사용하고 나머지는 분할.
#
# (004,005): “이 사람, 어제 시그렌이랑 일이 있었던 그 영애 아냐?” → “isn’t this... the lady who had a run-in with siegren yesterday?” 의미 동일.
#
# (067,068): “해서, 영애도……” → “so... you too...” 의미 동일.
#
# (073,074,075): “영애, 남의 저택에서 신세를 지고 있는 와중에 전하께 꼬리를 치셨죠? 제 하녀가 말해주었단 말이에요. 어젯밤에-” → “you... even tried to seduce his highness while staying at someone else’s manor, didn’t you? my maid told me about it last night--” 의미 동일.
#
# (085,086): “저는 그 덕분에 권력과 힘, 두 개 다 가지고 있답니다.” → “thanks to that, I now have both power... and strength.” 의미 동일.
#
# (091,092,093): “그리고, 화, 황자 전하….” → “and... your... your highness...” 의미 동일.
#
# 이제 각 문단을 구성한 대사 수에 맞춰 영어 문장을 나누고, 나눈 부분 양쪽에 '...'를 삽입한다. 단, 000~003은 4개 대사이므로 4개로 나누고, 073~075는 3개로 나눈다.
#
# </reasoning>
# <translate>
# 000	I would like...
# 001	...to invite you...
# 002	...to a tea party in the greenhouse this afternoon...
# 003	...Please come if you have time, Lady Heather.
# 004	isn’t this...
# 005	...the lady who had a run-in with siegren yesterday?
# 006	is it okay for me to go to a tea party hosted by someone like that?
# 007	well, there’s no reason for me to be concerned.
# 008	she was the one in the wrong, after all.
# 009	and I might be able to see eunice there.
# 010	please tell her that I will gladly attend.
# 011	lady eunice.
# 012	lady fiona!
# 013	were you invited to the tea party as well?
# 014	yes.
# 015	we’re traveling together, but I haven’t been able to see you.
# 016	that’s because I’ve been riding a horse.
# 017	still, please come to the carriage.
# 018	it’s boring being alone...
# 019	she must have felt lonely being surrounded by knights and soldiers.
# 020	welcome.
# 021	this way to the greenhouse.
# 022	lady heather is waiting inside.
# 023	oh my.
# 024	lady fiona,
# 025	lady eunice...
# 026	thank you for accepting my invitation.
# 027	I’ve been waiting for you.
# 028	wow, she really is a stunning beauty.
# 029	so this is the person who tried to throw herself at siegren.
# 030	please, have a seat.
# 031	yes, thank you.
# 032	these ladies are from nearby territories.
# 033	it’s an honor to meet such renowned ladies.
# 034	yes...
# 035	it’s nice to meet you.
# 036	what is it?
# 037	I feel like they’re giving me strange looks...
# 038	I heard you were in the north, lady fiona.
# 039	that’s right.
# 040	wasn’t it difficult?
# 041	I heard a very barbaric and cruel mage lives there...
# 042	it’s not that different from any other place.
# 043	wait, that rumor spread all the way here?!
# 044	speaking of rumors,
# 045	I heard...
# 046	...that you have a rather special bloodline.
# 047	I heard you weren’t originally from house hylon.
# 048	from what I know,
# 049	you’re an illegitimate child.
# 050	yes, that’s true.
# 051	I am an illegitimate child.
# 052	you know very well.
# 053	she’s smiling?
# 054	and your original family...
# 055	yes, their wealth was confiscated due to their involvement in the drug trade.
# 056	I was the one who reported them.
# 057	my goodness, I could never do that.
# 058	betraying your own family, no matter the reason...
# 059	only a beast would do something like that.
# 060	w-wait!
# 061	lady fiona...
# 062	so,
# 063	what are you trying to say?
# 064	I’m telling you to know your place!
# 065	even if you were lucky enough to be adopted,
# 066	you should know your place as a noble lady.
# 067	so...
# 068	...you too...
# 069	siegren.
# 070	lady fiona, why are you looking elsewhere?
# 071	can’t you see that I’m talking to you?
# 072	I still have more to say.
# 073	you...
# 074	...even tried to seduce his highness...
# 075	...while staying at someone else’s manor, didn’t you? my maid told me about it last night--
# 076	wait.
# 077	lady heather, you’re going too far!
# 078	what do you mean?
# 079	I’m just stating the facts--
# 080	ah,
# 081	aaah!
# 082	you’re right about everything.
# 083	I’m an illegitimate child, and I destroyed the family I was born into.
# 084	but there’s one thing that a smart lady like you failed to realize.
# 085	thanks to that, I now have both power...
# 086	...and strength.
# 087	that means even if I burn your hair right here and now,
# 088	the most your father could do is send a few letters of protest to my father.
# 089	you should know who you’re dealing with before you act like a brat.
# 090	you might lose your head.
# 091	and...
# 092	...your...
# 093	...your highness...
# 094	it looks like you’re having a very enjoyable tea party,
# 095	lady heather.
# 096	I-I...
# 097	after what happened yesterday, she won’t be able to look him in the eye.
# 098	let me give you one last piece of advice.
# 099	don’t covet someone else’s man.
# 100	he’s mine now.
# </translate>
# 101 101
# ====================
# <reasoning>
# [1차 영어 번역문] "is it okay for me to go to a tea party hosted by someone like that?"를 한글로 번역하면 [1차 한글 번역문]은 "그런 사람이 주최하는 티파티에 내가 가도 괜찮을까?" 정도가 됩니다.
# 이는 [한글 대화] "그런 사람이 여는 티파티에 내가 가도 되는 건가?"와 의미가 거의 일치합니다.
# 다만, "someone like that"이라는 표현은 다소 모호할 수 있으므로, 원문의 뉘앙스를 살려 "a tea party hosted by her" 또는 "by that lady"처럼 구체적으로 바꿔주는 것이 더 자연스럽고 명확합니다.
# 또한, 문장 구조를 조금 더 자연스럽게 다듬어 "Should I really be going to..."처럼 표현하면 더 부드럽고 내면의 독백처럼 들립니다.
# </reasoning>
# <translate>
# Should I really be going to a tea party hosted by that lady?
# </translate>
# <reasoning> [한글 대화] "내가 괜히 신경 쓸 만한 이유는 없지."는 말하는 사람이 어떤 상황에 대해 굳이 걱정하거나 신경 쓸 필요가 없다고 스스로 납득하는 문장이다. 여기서 "괜히"는 "헛되이", "쓸데없이"라는 의미로, "신경 쓸 만한 이유가 없다"는 말은 "신경 쓸 필요가 없다"는 뜻이다. 1차 영어 번역문 "well, there’s no reason for me to be concerned."는 의미상으로는 거의 일치하지만, "괜히"라는 뉘앙스를 충분히 살리지 못했다. "괜히"는 단순히 이유가 없다는 것뿐 아니라, 신경 쓰는 것이 쓸데없는 일이라는 뉘앙스를 포함한다. 따라서 "no reason for me to be concerned"보다는 "no point in worrying about it" 또는 "no need to worry unnecessarily" 같은 표현이 더 자연스럽고 원문의 뉘앙스를 잘 살릴 수 있다. </reasoning> <translate>There's no point in worrying about it. </translate>
# <reasoning>
# [1차 영어 번역문] "she was the one in the wrong, after all."을 한글로 번역하면 [1차 한글 번역문]은 "결국 잘못한 건 그녀야." 정도가 됩니다.
# [한글 대화] "잘못한 건 그쪽이고."는 특정 인물을 지칭하는 표현이긴 하지만, "그쪽"이라는 표현은 "그녀"로 번역될 수도 있고, 상황에 따라 성별 불문으로 "that person"이나 "they"로도 번역될 수 있습니다.
# 하지만 이 장면의 앞뒤 맥락을 보면, 시그렌과 일이 있었던 "그 영애"가 주어이므로 여성임이 분명하고, 따라서 "she"로 번역한 것은 적절합니다.
# 또한 "after all"은 문장 전체의 뉘앙스를 강조하는 표현으로, 원문의 의미와 크게 다르지 않으며 자연스럽습니다.
# glossary에 해당 표현도 없고, 의미도 일치하므로 기존 번역을 유지해도 무방합니다.
# </reasoning>
# <translate> she was the one in the wrong, after all. </translate>
# <reasoning>
# [1차 영어 번역문] "and I might be able to see eunice there."를 한글로 번역하면 "그리고 거기서 유니스를 볼 수 있을지도 몰라."가 됩니다.
# [한글 대화]는 "어쩌면 티파티에서 유니스를 만날 수 있을지도 모르니까."로, '어쩌면'이라는 불확실성을 나타내는 부사와 '티파티에서'라는 장소 정보가 명확히 포함되어 있습니다.
# 하지만 [1차 영어 번역문]에서는 '어쩌면'에 해당하는 maybe나 perhaps가 빠져 있고, '티파티'라는 구체적인 장소도 'there'로만 처리되어 있어 정보가 축약되었습니다.
# 따라서 정보의 양이 다르므로 [1차 영어 번역문]은 무시하고 [한글 대화]를 기준으로 다시 번역해야 합니다.
# 또한 glossary에 따라 유니스는 eunice로 표기해야 하므로 이를 반영합니다.
# </reasoning>
# <translate>
# Maybe I'll get to see Eunice at the tea party.
# </translate>
# <reasoning>
# [1차 영어 번역문] "please tell her that I will gladly attend."을 한글로 번역하면 "그녀에게 내가 기꺼이 참석하겠다고 전해줘."가 됩니다.
# [한글 대화] "기쁜 마음으로 응하겠다고 전해줘."와 비교했을 때, 의미는 대체로 일치합니다.
# "기쁜 마음으로"는 "gladly"로 잘 번역되었고, "응하겠다"는 "attend"로 자연스럽게 표현되었습니다.
# 다만 "응하다"는 꼭 "attend"만을 의미하지 않고 "응답하다", "수락하다"의 의미도 포함하므로, "accept the invitation" 또는 "respond positively" 같은 표현도 가능하지만, 이 문맥에서는 티파티 초대에 대한 응답이므로 "attend"가 적절합니다.
# glossary에 특별히 반영할 표현도 없으므로, 기존 번역문은 자연스럽고 의미도 일치합니다.
# </reasoning>
# <translate> Please tell her that I will gladly attend. </translate>
# <translate>Lady Eunice.</translate>
# <translate>Lady Fiona…!</translate>
# <reasoning>
# [1차 영어 번역문] "were you invited to the tea party as well?"을 한글로 번역하면 "당신도 티파티에 초대받았나요?"가 됩니다.
# [한글 대화]는 "유니스 영애도 초대받은 건가요?"로, 특정 인물(유니스 영애)이 초대받았는지를 묻는 문장입니다.
# 1차 번역문은 일반적인 '당신'을 주어로 사용하고 있어, 화자가 유니스 영애에게 직접 묻는 것처럼 보입니다.
# 하지만 원문은 제3자에게 유니스 영애가 초대받았는지를 묻는 뉘앙스를 가질 수도 있습니다.
# 그러나 직전 대사인 "피오나 영애…!"와 연결해서 보면, 화자가 유니스 영애에게 직접 묻는 상황으로 해석하는 것이 자연스럽습니다.
# 따라서 1차 번역문은 의미상 큰 문제는 없으며, 다만 "tea party" 앞에 정관사 "the"를 붙여 명확하게 해주는 것이 좋습니다.
# 또한 glossary에 따라 "유니스 영애"는 "Lady Eunice"로 번역되어야 하므로 이를 반영합니다.
# </reasoning>
# <translate>
# Lady Eunice, were you invited to the tea party as well?
# </translate>
# <translate> Yes. </translate>
# <reasoning>
# [1차 영어 번역문] "we’re traveling together, but I haven’t been able to see you."를 한글로 번역하면 "우리는 함께 여행 중인데, 당신을 볼 수가 없었어요." 정도가 됩니다.
# 하지만 [한글 대화]는 "피오나 영애와는 같은 일행임에도 계속 얼굴을 볼 수가 없었네요."로, '같은 일행'이라는 표현은 단순히 여행을 함께 한다는 의미보다는 같은 그룹, 같은 무리로 움직이고 있다는 뉘앙스를 포함합니다. 또한 "계속 얼굴을 볼 수가 없었네요"는 반복적으로 마주치지 못했다는 의미를 담고 있어, 단순히 한 번 못 본 것이 아니라 지속적으로 마주치지 못했다는 점이 강조됩니다.
# 따라서 [1차 영어 번역문]은 의미 전달이 부족하며, [한글 대화]에 맞춰 새롭게 번역해야 합니다.
# </reasoning>
# <translate>
# Even though we’re part of the same group, I haven’t been able to see you at all.
# </translate>
# <reasoning>
# [1차 영어 번역문] "that’s because I’ve been riding a horse."를 한글로 번역하면 [1차 한글 번역문]은 "그건 내가 말을 타고 있었기 때문이야."가 됩니다.
# [한글 대화]는 "전 말을 타고 있었거든요."로, 이는 말하고 있는 사람이 자신이 말을 타고 있었다는 사실을 설명하는 문장입니다.
# 의미적으로는 1차 번역문과 유사하지만, 1차 번역문은 "that’s because"라는 표현으로 앞 문장에 대한 이유를 설명하는 형태입니다.
# 하지만 원문에는 앞 문장과의 인과 관계를 명확히 드러내는 접속사는 없습니다.
# 즉, "전 말을 타고 있었거든요."는 단순히 자신이 말을 타고 있었다는 사실을 전달하는 문장이므로, 영어로는 "I was riding a horse." 정도가 더 적절합니다.
# 또한, 말투의 정중함을 고려하면 "I was on horseback." 또는 "I was riding." 정도도 자연스럽습니다.
# 하지만 "전 말을 타고 있었거든요."는 앞 문장 "피오나 영애와는 같은 일행임에도 계속 얼굴을 볼 수가 없었네요."에 대한 설명이므로,
# "I was riding a horse." 또는 "I was on horseback."가 더 자연스럽고 정확한 대응입니다.
# </reasoning>
# <translate>I was riding a horse.</translate>
# <reasoning>
# [1차 영어 번역문] "still, please come to the carriage."를 한글로 번역하면 [1차 한글 번역문]은 "그래도 마차에 와 주세요."입니다.
# [한글 대화]는 "…그래도 마차에도 와 주세요."로, 여기서 "도"는 "말을 타고 있었지만 마차에도 함께 해달라"는 의미로, 앞 문장(016: 전 말을 타고 있었거든요.)과 연결되어 있습니다.
# 즉, "말을 타고 있었지만 그래도 마차에도 와 달라"는 의미로, 단순히 "please come to the carriage"보다는 "even so, please come to the carriage too"처럼 "too"를 포함해 앞 문장과의 연결을 살려야 의미가 정확히 전달됩니다.
# </reasoning>
# <translate>
# Still, please come to the carriage too.
# </translate>
# <translate>She must've felt lonely, being surrounded only by knights and soldiers. </translate>
# <reasoning>
# [1차 영어 번역문] "welcome."을 한글로 번역하면 "환영합니다." 또는 "어서 오세요." 정도로 해석할 수 있습니다.
# [한글 대화]는 "어서 오십시오."로, 이는 좀 더 격식 있는 표현입니다.
# "welcome"은 너무 간단하고 캐주얼한 표현으로, 원문의 존댓말 뉘앙스를 충분히 반영하지 못합니다.
# 따라서 더 적절한 번역은 "Welcome, my lady." 또는 "Welcome, please come in." 정도가 될 수 있습니다.
# 하지만 상황상 하인이 귀족 영애를 맞이하는 장면이므로, 격식을 갖춘 "Welcome, my lady."가 가장 적절합니다.
# </reasoning>
# <translate>Welcome, my lady.</translate>
# <reasoning>
# [1차 영어 번역문] "this way to the greenhouse."를 한글로 번역하면 "온실로 가는 이쪽 길입니다." 또는 "이쪽이 온실로 가는 길입니다." 정도로 해석할 수 있습니다.
# 하지만 [한글 대화]는 "이쪽이 온실입니다."로, 단순히 위치를 안내하는 것이 아니라 "여기가 온실입니다"라는 의미입니다.
# 즉, [1차 영어 번역문]은 "이쪽으로 가면 온실입니다"라는 의미로, 아직 도착하지 않은 상태를 전제로 하고 있지만, [한글 대화]는 이미 도착해서 "여기가 온실입니다"라고 말하는 상황입니다.
# 따라서 정보의 양과 의미가 다르므로, [1차 영어 번역문]은 무시하고 [한글 대화]를 기준으로 새롭게 번역해야 합니다.
# </reasoning>
# <translate>This is the greenhouse.</translate>
# <reasoning>
# [1차 영어 번역문] "lady heather is waiting inside."를 한글로 번역하면 [1차 한글 번역문]은 "헤더 아가씨는 안쪽에서 기다리고 계십니다."가 됩니다.
# 하지만 [한글 대화]는 "아가씨께서는 안쪽에서 기다리고 계십니다."로, 특정 인물의 이름이 언급되지 않았습니다.
# 즉, [1차 영어 번역문]은 원문에 없는 정보를 추가하여 정보의 양이 다릅니다.
# 따라서 [1차 영어 번역문]은 무시하고 [한글 대화]만을 기준으로 새롭게 번역해야 합니다.
# 주어는 명확히 특정되지 않았지만, 앞 문맥에서 티파티를 주최한 인물(헤더 아덴 영애)로 추정되므로, 영어 번역에서는 일반적인 표현으로 처리하면 됩니다.
# </reasoning>
# <translate>The young lady is waiting inside.</translate>
# <reasoning>
# [1차 영어 번역문] "oh my."는 [한글 대화] "어머나,"를 비교적 잘 번역한 표현이다. "어머나"는 놀람, 감탄, 당황 등 다양한 감정을 표현할 수 있는 감탄사이며, 영어의 "oh my"도 유사한 감정을 전달할 수 있다.
# glossary에 해당 표현은 없으며, 문맥상 다른 보완도 필요 없어 보인다.
# </reasoning>
# <translate> oh my. </translate>
# <translate>Lady Fiona,</translate>
# <translate>Thank you for accepting my invitation. </translate>
# <translate>I’ve been waiting for you.</translate>
# <translate>Wow, she really is a glamorous beauty. </translate>
# <reasoning>
# [1차 영어 번역문] "so this is the person who tried to throw herself at siegren."의 [1차 한글 번역문]은 "이 사람이 시그렌에게 달려들려고 했던 사람이구나." 정도로 해석할 수 있습니다.
# 하지만 [한글 대화]는 "이런 사람이 시그렌에게 달려들었단 말이지."로, 여기서 "이런 사람"은 앞서 묘사된 "화려한 미인"을 지칭하며, 놀라움이나 비꼼의 뉘앙스를 담고 있습니다.
# 또한 "달려들었다"는 표현은 단순히 "호감을 표현했다" 이상의 적극적이고 도발적인 행동을 암시합니다.
# "throw herself at"은 이 의미를 잘 살리고 있지만, "so this is the person who..."는 다소 설명조이고 감탄이나 비꼼의 뉘앙스가 약합니다.
# 따라서 원문의 감탄과 비꼼의 어조를 살리기 위해 감탄문 형태로 재구성하는 것이 적절합니다.
# </reasoning>
# <translate>
# So this is the kind of woman who threw herself at Siegren.
# </translate>
# <translate>Please, have a seat.</translate>
# <reasoning> [한글 대화] "네, 고마워요."는 자연스럽고 공손한 응답으로, 상대의 초대나 배려에 대한 감사의 표현이다. [1차 영어 번역문] "yes, thank you."는 직역으로 보이며 의미는 대체로 일치하지만, 영어 대화에서는 "Yes"보다는 "Thank you" 또는 "Thank you very much" 단독으로 쓰는 것이 더 자연스럽다. 특히 티파티 초대에 대한 응답이라면 "Thank you"만으로도 충분히 공손하고 자연스럽다. 따라서 "Yes, thank you."는 어색할 수 있으며, "Thank you."로 수정하는 것이 더 적절하다. </reasoning>
# <translate> Thank you. </translate>
# <reasoning> [한글 대화] "이쪽은 근처 영지의 영애들이에요."는 "이쪽에 있는 분들은 근처 영지의 귀족 아가씨들이에요."라는 의미로, "영애"는 귀족 집안의 딸을 의미합니다. [1차 영어 번역문] "these ladies are from nearby territories."는 전체적인 의미는 비슷하지만, "영애"라는 신분적 의미가 빠져 있으며, 단순히 "여성들"로 번역되어 있어 원문의 뉘앙스를 충분히 반영하지 못합니다. 따라서 "ladies" 대신 "young ladies" 또는 "noble ladies"와 같은 표현을 사용해 귀족 신분을 강조하는 것이 더 적절합니다. </reasoning>
# <translate> These young ladies are from nearby territories. </translate>
# <translate>It’s an honor to meet two ladies of such renown. </translate>
# <reasoning>
# [한글 대화] "잘 부탁해요"는 한국어에서 상대에게 예의를 갖추며 앞으로 잘 지내보자는 의미로 자주 사용되는 표현이다. 이는 단순한 첫 만남의 인사인 "Nice to meet you"와는 뉘앙스가 다르다. "잘 부탁해요"는 앞으로의 관계에 대한 기대와 협조를 부탁하는 의미가 담겨 있다. 따라서 "Nice to meet you"는 정보의 양과 의미가 부족하며, 원문의 의미를 온전히 전달하지 못한다. 이 경우에는 "I look forward to getting along with you" 또는 "I hope we get along well" 같은 표현이 더 적절하다.
# </reasoning>
# <translate>I hope we get along well.</translate>
# <reasoning>
# [한글 대화] "뭐지?"는 상황에 따라 다양한 의미로 해석될 수 있는 감탄사 또는 의문 표현입니다. 이 경우, 앞뒤 맥락을 보면 피오나가 다른 영애들의 시선을 느끼고 이상함을 감지하는 장면입니다. 따라서 "뭐지?"는 단순히 "what is it?"보다는 "What's going on?" 또는 "What's this?"처럼 상황에 대한 의문이나 이상함을 표현하는 게 더 자연스럽습니다. "What is it?"은 누군가가 무언가를 건넸거나 말했을 때 쓰는 표현으로, 이 장면의 뉘앙스와는 다소 어울리지 않습니다.
# </reasoning>
# <translate>
# What's going on?
# </translate>
# <reasoning>
# [1차 영어 번역문] "I heard you were in the north, lady fiona."를 한글로 번역하면 "당신이 북부에 있었다고 들었어요, 피오나 영애."입니다.
# [한글 대화]는 "헤일론 영애는 북부에 있었다면서요."로, 여기서 "헤일론 영애"는 피오나를 지칭하는 것이 맞습니다.
#
# 의미적으로는 거의 일치하지만, 원문은 간접화법으로 "있었다면서요"라고 말하고 있고, 1차 번역문도 "I heard you were..."로 간접화법을 사용했기 때문에 표현 방식은 일치합니다.
#
# 하지만 glossary에 따르면 "피오나"는 "fiona"로 표기해야 하고, "영애"는 "lady"로 번역되므로 "Lady Fiona"가 맞습니다.
# 또한 "헤일론 영애"는 "Lady of Heilun" 또는 "Lady Fiona of Heilun"으로 번역할 수 있지만, 이 작품에서는 일반적으로 이름 + 영애 형식으로 번역하고 있으므로 "Lady Fiona"로 유지하는 것이 자연스럽습니다.
#
# 따라서 기존 번역은 의미는 맞지만, 표현을 조금 더 자연스럽게 다듬을 수 있습니다.
# </reasoning>
# <translate>
# I heard Lady Fiona was in the North.
# </translate>
# <translate>That's right. </translate>
# <reasoning>
# [한글 대화] "힘들지는 않았나요?"는 상대방이 북부에 있었다는 말을 듣고, 그 경험이 힘들지 않았는지를 정중하게 묻는 표현이다.
# [1차 영어 번역문] "wasn’t it difficult?"는 문법적으로는 맞지만, 주어가 없고 문맥상 누가 힘들었는지를 명확히 하지 않는다.
# 또한, 원문의 정중한 어조가 영어에서도 반영되어야 하므로, "Wasn't it difficult for you?" 또는 "Did you have a hard time?"처럼 주어를 명확히 하고 정중한 어투를 유지하는 것이 더 적절하다.
# </reasoning>
# <translate>
# Wasn't it difficult for you?
# </translate>
# <reasoning>
# [한글 대화] "사람 사는 곳이라 다들 비슷하답니다."는 직역하면 "사람이 사는 곳이기 때문에 다들 비슷하답니다."라는 의미로, 인간이 사는 곳은 어디나 비슷하다는 일반적인 진리를 담고 있다.
# [1차 영어 번역문] "it’s not that different from any other place."는 "다른 어떤 곳과도 그렇게 다르지 않다"는 의미로, 전체적인 의미는 유사하지만 원문의 "사람이 사는 곳이라"는 이유를 생략하고 있다.
# 즉, 정보의 양이 다르며 원문의 논리적 이유(사람이 사는 곳이기 때문에)를 반영하지 못하고 있다.
# 따라서 [1차 영어 번역문]은 무시하고 [한글 대화]를 기반으로 새롭게 번역해야 한다.
# </reasoning>
# <translate>
# People are people, so everywhere ends up being pretty similar.
# </translate>
# <reasoning>
# [1차 영어 번역문] "wait, that rumor spread all the way here?!"를 한글로 번역하면 [1차 한글 번역문]은 "잠깐, 그 소문이 여기까지 퍼졌다고?!" 정도가 됩니다.
# [한글 대화] "아니, 이 소문 여기까지 돌았냐!"는 놀람과 당혹감을 표현하는 감탄사 "아니"로 시작하며, 소문이 예상보다 멀리 퍼졌다는 사실에 대한 놀라움을 담고 있습니다.
#
# [1차 한글 번역문]과 [한글 대화]는 전반적으로 의미는 유사하지만, "wait"는 "아니"보다는 "잠깐"에 가까운 의미로, 감탄사로서의 뉘앙스가 다소 다릅니다.
# "아니"는 좀 더 감정적인 놀람을 표현하는 데 적합하며, 영어로는 "No way"나 "Seriously" 같은 표현이 더 자연스럽습니다.
#
# 따라서 감탄사와 놀람의 뉘앙스를 더 잘 살리기 위해 [1차 영어 번역문]을 수정합니다.
# </reasoning>
# <translate>No way, that rumor made it all the way here?!</translate>
# <translate>Speaking of rumors,</translate>
# <reasoning>
# [1차 영어 번역문] "I heard you weren’t originally from house hylon."을 한글로 번역하면 [1차 한글 번역문]은 "당신은 원래 헤일론 가문 출신이 아니라고 들었어요."가 됩니다.
# [한글 대화]는 "본래는 헤일론 쪽이 아니라고 들었어요."로, 의미상으로는 거의 동일합니다. "본래는" = "originally", "헤일론 쪽이 아니다" = "not from house Hylon"으로 자연스럽게 대응됩니다.
# glossary에 따르면 '헤일론'은 특별한 용어로 지정되어 있지 않으므로 그대로 'Hailon' 또는 'House Hailon'으로 표기하면 됩니다.
# 다만, 1차 번역문에서는 'house hylon'으로 표기되어 있는데, 이는 오타로 보이며 'Hailon'이 맞습니다.
# 따라서 오타를 수정한 형태로 번역문을 검토해 생성합니다.
# </reasoning>
# <translate>I heard you weren’t originally from House Hailon.</translate>
# <translate>From what I know,</translate>
# <reasoning>
# [1차 영어 번역문] "you’re an illegitimate child."를 한글로 번역하면 [1차 한글 번역문]은 "너는 사생아야." 또는 "당신은 사생아예요."가 됩니다.
# 하지만 [한글 대화]는 "사생아라던데."로, 이는 화자가 직접 단정하는 것이 아니라, 어디선가 들은 이야기를 전달하는 간접화법입니다.
# 즉, "사생아라던데"는 "I heard you're an illegitimate child." 또는 "They say you're an illegitimate child."처럼 번역되어야 의미가 정확히 일치합니다.
# 따라서 [1차 영어 번역문]은 정보의 전달 방식이 다르므로 무시하고, [한글 대화]에 맞춰 새롭게 번역해야 합니다.
# </reasoning>
# <translate>
# They say you're an illegitimate child.
# </translate>
# <translate>Yes, that's correct.</translate>
# <translate>I am an illegitimate child.</translate>
# <reasoning>
# [한글 대화] "정확히 알고 계시네요."는 상대방이 말한 내용이 사실이며, 그것을 아주 정확하게 알고 있다는 점을 인정하는 표현이다.
# [1차 영어 번역문] "you know very well."은 일반적으로 "당신은 잘 알고 있군요"라는 의미로, 뉘앙스는 비슷하지만 "정확히"라는 의미의 "정확도"는 빠져 있다.
# 따라서 정보의 양이 다르므로, [1차 영어 번역문]은 무시하고 [한글 대화]를 기준으로 다시 번역해야 한다.
# "정확히"에 해당하는 영어 표현은 "exactly" 또는 "accurately"가 적절하며, "알고 계시네요"는 "you know" 또는 "you are aware"로 표현할 수 있다.
# </reasoning>
# <translate>You know exactly right.</translate>
# <reasoning>
# [한글 대화] "웃어?"는 말하는 사람이 상대방이 웃고 있는 것을 보고 놀라거나 불쾌해서 "웃어?"라고 되묻는 상황이다. 이 표현은 감탄이나 분노, 조롱의 뉘앙스를 담고 있으며, 영어로는 "You're smiling?" 또는 "Are you smiling?"처럼 번역할 수 있다. 하지만 [1차 영어 번역문] "she’s smiling?"은 제3자의 시점에서 말하는 문장으로, 원문의 화자의 직접적인 반응과는 어울리지 않는다. 원문의 뉘앙스를 살리기 위해서는 2인칭을 사용한 직접적인 표현이 필요하다.
# </reasoning>
# <translate>You're smiling?</translate>
# <1차 한글 번역문> 네, 그들의 재산은 마약 거래에 연루되어 몰수당했어요.
#
# <reasoning> [한글 대화]는 "마약 사업 혐의로 재산을 몰수당했죠."로, 주어는 명확히 없지만 문맥상 피오나가 태어난 본가(가문)에 대한 이야기이다. 1차 영어 번역문은 "their involvement in the drug trade"라고 번역했는데, 이는 "마약 거래에 연루되어"라는 의미로, "혐의"보다는 실제 연루되었다는 뉘앙스를 준다. 하지만 원문은 "혐의로"라고 되어 있어, 실제 연루되었는지 여부는 확정되지 않은 상태이다. 따라서 "on suspicion of" 또는 "on charges of"와 같은 표현을 써서 혐의 수준임을 반영해야 한다. </reasoning>
#
# <translate> Yes. Their assets were confiscated on charges of involvement in the drug trade. </translate>
# <translate>I was the one who reported them myself. </translate>
# <reasoning>
# [1차 영어 번역문] "my goodness, I could never do that."를 한글로 번역하면 [1차 한글 번역문]은 "세상에, 나는 절대 그런 일 못 해." 정도가 됩니다. 이는 [한글 대화] "세상에, 저라면 도저히 못할 거예요."와 의미가 거의 일치합니다. 다만 "저라면"이라는 표현은 영어로 "if it were me" 또는 "in my case" 등으로 좀 더 명확히 번역할 수 있습니다. 또한 "도저히"는 "absolutely"나 "possibly" 같은 부사로 강조할 수 있습니다. 따라서 감탄사와 함께 문장을 조금 더 자연스럽고 원문에 충실하게 다듬을 수 있습니다.
# </reasoning>
# <translate>
# My goodness, if it were me, I absolutely couldn't do it.
# </translate>
# <translate>Only a beast would do such a thing. </translate>
# <reasoning>
# [1차 영어 번역문] "w-wait!"을 한글로 번역하면 [1차 한글 번역문]은 "자, 잠깐만요!"가 됩니다.
# 이는 [한글 대화]와 의미가 일치합니다.
# "자, 잠깐만요!"는 상황을 멈추거나 제지하려는 표현으로, 영어로는 "Wait a moment!" 또는 "Hold on a second!" 등으로도 번역할 수 있지만, 감정이 실린 짧은 외침이라면 "Wait!" 또는 "Just a moment!"가 자연스럽습니다.
# 1차 번역문 "w-wait!"은 말이 막히는 듯한 느낌을 주는 표현으로, 원문의 감정과도 잘 맞습니다.
# 따라서 의미도 일치하고 감정도 잘 전달되므로, 이 번역은 적절합니다.
# glossary에 해당 표현은 없으므로 그대로 사용해도 무방합니다.
# </reasoning>
# <translate>w-wait!</translate>
# <reasoning>
# [1차 영어 번역문] "so,"는 [한글 대화] "그래서,"를 직역한 형태로, 의미는 일치합니다.
# "그래서,"는 앞의 상황이나 대화에 대한 반응으로, 상대방의 말을 재촉하거나 요점을 요구하는 표현입니다.
# 따라서 "So?" 또는 "And?"와 같이 간결하게 의문형으로 처리하는 것이 자연스럽습니다.
# 문맥상 피오나가 상대방의 말을 이어서 듣고자 하는 상황이므로 "So?"가 적절합니다.
# </reasoning>
# <translate> So? </translate>
# <reasoning>
# [1차 영어 번역문] "what are you trying to say?"를 한글로 번역하면 "무슨 말을 하려는 거죠?" 또는 "무슨 말을 하려는 건가요?" 정도로 자연스럽게 해석됩니다.
# [한글 대화] "하고 싶은 말이 뭔가요?"는 말하고자 하는 바를 직접적으로 묻는 표현으로, 의미상으로는 "what are you trying to say?"와 거의 동일합니다.
# 따라서 의미는 일치합니다.
# glossary에 해당 표현은 없으므로, 기존 번역문을 그대로 사용해도 무방합니다.
# </reasoning>
# <translate> what are you trying to say? </translate>
# <reasoning> [한글 대화] "적당히 하라는 소리예요!"는 상대방의 언행이 지나치다고 판단하여 자제하라는 의미로, "그만 좀 해라", "선을 넘지 마라", "적당히 해라"는 뉘앙스를 담고 있다. 반면 [1차 영어 번역문] "I’m telling you to know your place!"는 "네 분수를 알아라"는 의미로, 계급이나 신분을 지적하며 상대를 깎아내리는 뉘앙스를 포함한다. 이는 원문의 의도와 다르며, 공격적인 어투로 의미가 왜곡되었다. 따라서 [1차 영어 번역문]은 무시하고 [한글 대화]만을 기준으로 새로운 번역이 필요하다. </reasoning>
# <translate>I'm telling you to watch yourself!</translate>
# <translate>Even if you were lucky enough to become an adopted daughter,</translate>
# <reasoning>
# [1차 영어 번역문] "you should know your place as a noble lady."를 한글로 번역하면 "귀족 영애로서 분수를 알아야죠." 정도가 됩니다.
# 하지만 [한글 대화]는 "귀족 영애라면 정도를 지켜야죠."로, 여기서 '정도'는 '도리를 지키다', '올바른 길을 가다'는 의미입니다.
# 즉, '분수를 알아야 한다'는 의미보다는 '도덕적 기준이나 품위를 지켜야 한다'는 의미에 가깝습니다.
# 따라서 [1차 영어 번역문]은 의미가 다소 왜곡되어 있으므로, 이를 무시하고 [한글 대화]를 기준으로 새롭게 번역해야 합니다.
# 주어는 생략 가능하며, 문맥상 상대방에게 훈계하는 말투이므로 명령형 또는 조언형 문장으로 구성하는 것이 자연스럽습니다.
# </reasoning>
# <translate>
# As a noble lady, you should uphold proper conduct.
# </translate>
# <reasoning>해당 대사는 단순히 인물의 이름 "시그렌"을 부르는 장면이다. 문맥상 피오나가 시그렌을 보고 이름을 부르는 것으로 보이며, 감탄사나 다른 감정 표현 없이 이름만 말하고 있다. 따라서 1차 영어 번역문 "siegren."은 의미가 일치한다. 또한 glossary에 따라 "시그렌"은 "siegren"으로 번역하는 것이 맞다. </reasoning>
# <translate>siegren. </translate>
# <translate>Lady Fiona, why are you looking away?</translate>
# <reasoning>
# [1차 영어 번역문] "can’t you see that I’m talking to you?"를 한글로 번역하면 "내가 너한테 말하고 있는 거 안 보여?" 정도로 해석할 수 있습니다.
# 하지만 [한글 대화]는 "지금 제가 말하고 있는 게 안 보이나요?"로, 좀 더 정중하고 간접적인 표현입니다.
# 1차 번역문은 직설적이고 공격적인 뉘앙스를 가지고 있으며, 반말 형태로 번역되어 있습니다. 반면, 원문은 존댓말을 사용하고 있으며, 직접적인 대상 지칭 없이 "제가 말하고 있는 게 안 보이나요?"라고 말하고 있어, 제3자에게 말하는 듯한 뉘앙스를 포함하고 있습니다.
# 따라서 1차 번역문은 원문의 정중함과 간접적인 표현을 반영하지 못하고 있으며, 의미도 다소 왜곡되어 있습니다.
# 그러므로 [1차 영어 번역문]은 무시하고, [한글 대화]를 기반으로 다시 번역해야 합니다.
# </reasoning>
# <translate>
# Can’t you see that I’m the one speaking right now?
# </translate>
# <translate>I still have more to say. </translate>
# <reasoning>
# [한글 대화] "잠깐."은 상황을 멈추거나 상대방의 말을 제지할 때 사용하는 표현으로, 영어로는 "Wait." 또는 "Hold on." 등으로 번역할 수 있습니다.
# [1차 영어 번역문] "wait."은 의미적으로는 맞지만, 영어 문장에서는 보통 첫 단어는 대문자로 시작하므로 "Wait."으로 수정해야 합니다.
# 또한, glossary에 반영할 표현은 없고, 문맥상 추가적인 추론 없이도 "Wait."이 적절합니다.
# </reasoning>
# <translate>Wait.</translate>
# <reasoning>
# [1차 영어 번역문] "lady heather, you’re going too far!"를 한글로 번역하면 "헤더 영애, 너무 지나치세요!" 또는 "헤더 영애, 너무 심하세요!" 정도로 해석할 수 있습니다.
# 하지만 [한글 대화]는 "아덴 영애, 말이 심하세요!"로, '말이 심하다'는 표현이 핵심입니다. 이는 단순히 '지나치다'는 의미보다는 '말이 거칠거나 모욕적이다'는 뉘앙스를 포함합니다.
# 따라서 'you’re going too far'는 다소 일반적인 표현이며, 'your words are too harsh' 또는 'that’s too harsh, Lady Aden'과 같이 '말'에 초점을 맞춘 표현이 더 정확합니다.
# 또한, '아덴 영애'는 glossary에 따라 'Lady Aden'으로 번역되어야 하므로 이를 반영합니다.
# </reasoning>
# <translate> Lady Aden, your words are too harsh! </translate>
# <reasoning>
# [1차 영어 번역문] "what do you mean?"을 한글로 번역하면 "무슨 말이에요?" 또는 "무슨 뜻이에요?"가 됩니다.
# 하지만 [한글 대화] "심하긴 뭐가 심해요."는 "심하다고요? 뭐가 심하다는 거죠?" 또는 "심하긴 뭐가 심해요?"처럼 상대방의 비난을 반박하며 되묻는 말입니다.
# 즉, "심하다는 게 말이 돼요?" 또는 "그게 뭐가 심하다는 거죠?"라는 의미로, 단순히 "무슨 말이에요?"와는 의미가 다릅니다.
# 따라서 [1차 영어 번역문]은 의미가 일치하지 않으므로 무시하고, [한글 대화]만을 바탕으로 새롭게 영어 번역문을 생성해야 합니다.
# 이 대사는 상대방이 "말이 심하다"고 지적하자, 화자가 "심하긴 뭐가 심하냐"며 반박하는 맥락입니다.
# 따라서 영어로는 "Harsh? What's so harsh about it?" 또는 "Harsh? How is that harsh?" 정도가 자연스럽습니다.
# </reasoning>
# <translate>
# Harsh? How is that harsh?
# </translate>
# <translate>I'm merely stating the facts. </translate>
# <reasoning>
# [한글 대화] "꺄,"는 놀람, 당황, 혹은 갑작스러운 상황에 대한 반응으로 흔히 쓰이는 감탄사입니다. 영어로는 상황에 따라 "Ah!", "Eek!", "Aah!", "Oh!" 등으로 번역될 수 있습니다. 1차 영어 번역문 "ah,"는 의미는 비슷하지만, 한국어의 "꺄"가 전달하는 놀람이나 당황의 뉘앙스를 충분히 살리지 못하고 있습니다. 특히 웹툰의 맥락상 누군가의 말에 놀라거나 충격을 받은 상황이므로 좀 더 강한 반응이 필요합니다. 따라서 "Ah!"보다는 "Eek!" 또는 "Aah!" 같은 감탄사가 더 적절합니다.
# </reasoning>
# <translate> Eek! </translate>
# <reasoning>
# [1차 영어 번역문] "aaah!"는 [한글 대화] "꺄아아악!"을 단순히 감탄사로 번역한 것으로 보입니다. 하지만 "꺄아아악!"은 놀람, 충격, 공포 등 강한 감정이 담긴 비명에 가까운 표현입니다. "aaah!"는 놀람이나 감탄의 표현으로도 쓰이지만, 강한 비명을 표현하기에는 다소 약한 느낌이 있습니다. 영어에서 강한 비명을 표현할 때는 "Aaaah!" 또는 "Aaaaahhh!"처럼 길게 늘이거나 느낌표를 추가하여 감정을 강조하는 경우가 많습니다. 따라서 감정의 강도를 반영하여 더 적절한 비명 표현으로 수정해야 합니다.
# </reasoning>
# <translate>Aaaaah!</translate>
# <reasoning>
# [1차 영어 번역문] "you’re right about everything."을 한글로 번역하면 "당신 말이 전부 맞아요." 또는 "당신이 말한 모든 게 맞아요."가 됩니다.
# 하지만 [한글 대화]는 "영애의 말은 다 맞아요."로, 여기서 '영애'는 특정 인물(헤더 아덴 영애)을 지칭하는 존칭 표현입니다.
# 따라서 단순히 "you"로 번역하는 것은 원문의 존칭과 대상의 명확성을 반영하지 못합니다.
# 또한 glossary에 따라 '영애'는 'young lady' 또는 이름과 함께 'Lady + 이름'으로 번역될 수 있습니다.
# 이 장면에서는 피오나가 헤더 아덴 영애에게 말하고 있으므로, "Lady Aden"으로 번역하는 것이 적절합니다.
# </reasoning>
# <translate>
# You're right about everything, Lady Aden.
# </translate>
# <translate> I'm an illegitimate child, and I destroyed the family I was born into myself. </translate>
# <reasoning>
# [1차 영어 번역문] "but there’s one thing that a smart lady like you failed to realize."를 한글로 번역하면 "하지만 당신처럼 똑똑한 영애가 하나 깨닫지 못한 게 있어요."입니다.
# 이는 [한글 대화] "하지만 똑똑한 아덴 영애가 하나 파악하지 못한 게 있네요."와 의미가 거의 일치합니다.
# 다만, 원문에는 "아덴 영애"라는 특정 인물이 명시되어 있는데, 1차 번역문에서는 "a smart lady like you"라고 일반화되어 있어 대상이 모호해졌습니다.
# 또한, glossary에 따라 "아덴 영애"는 "Lady Aden"으로 번역되어야 하므로 이를 반영해야 합니다.
# </reasoning>
# <translate>
# But there's one thing that smart Lady Aden failed to realize.
# </translate>
# <reasoning>
# [1차 영어 번역문] "that means even if I burn your hair right here and now," 를 한글로 번역하면 "그 말은 내가 지금 이 자리에서 네 머리카락을 불태운다고 해도," 정도가 됩니다.
# 하지만 [한글 대화]는 "지금 이 자리에서 제가 영애의 머리카락을 불태워도"로, "그 말은"이라는 전제가 없습니다. 즉, [1차 영어 번역문]은 원문에 없는 의미("that means")를 추가하고 있어 정보량이 다릅니다.
# 따라서 [1차 영어 번역문]은 무시하고 [한글 대화]만을 기준으로 다시 번역해야 합니다.
# 또한, "영애"는 귀족 여성에 대한 존칭으로, 이 장면에서는 상대방을 직접 지칭하는 표현이므로 "my lady" 또는 "your ladyship" 등으로 번역할 수 있습니다. 하지만 현대적인 톤과 맥락을 고려하면 "your hair"로 간결하게 표현하고, "burn your hair"는 그대로 유지해도 무방합니다.
# </reasoning>
# <translate> Even if I burn your hair right here and now, </translate>
# <reasoning>
# [1차 영어 번역문]을 한글로 번역하면 "당신의 아버지가 할 수 있는 일은 제 아버지에게 항의서 몇 장을 보내는 게 전부예요."가 됩니다. 이는 [한글 대화] "아덴 자작님은 제 아버지께 항의서 몇 장 보내는 게 고작일 거란 뜻이죠."와 의미가 대체로 일치합니다. 다만, 원문에서는 "아덴 자작님"이라는 특정 인물이 명시되어 있고, "제 아버지께"라는 방향도 명확히 표현되어 있습니다. 1차 번역문에서는 "your father"라고 번역되어 있지만, 이 인물이 누구인지 명확하지 않으며, "my father"로의 방향성은 유지되었으나, 원문의 뉘앙스인 "그게 고작일 거란 뜻이죠"라는 도발적인 어조가 약간 누락되어 있습니다.
#
# 또한 glossary에 따르면 "자작"은 별도로 정의되어 있지 않지만, "아덴 자작님"은 고유명사처럼 사용되므로 "Viscount Aden" 또는 "Lord Aden" 등으로 번역하는 것이 적절합니다. 따라서 전체 문장을 보다 자연스럽고 원문의 뉘앙스를 살려 다음과 같이 수정합니다.
# </reasoning>
# <translate>
# That means the most Lord Aden could do is send a few letters of protest to my father.
# </translate>
# <reasoning>
# [1차 영어 번역문] "you should know who you’re dealing with before you act like a brat."의 [1차 한글 번역문]은 "건방지게 굴기 전에 상대를 알아야 해." 정도로 해석할 수 있습니다.
# 하지만 [한글 대화]는 "망아지처럼 구는 것도 상대를 보면서 하세요."로, 여기서 "망아지처럼 굴다"는 표현은 '제멋대로 날뛰거나 경솔하게 행동하다'는 의미의 비유적 표현입니다.
# "act like a brat"도 비슷한 의미를 전달하지만, "brat"은 주로 버릇없는 아이를 지칭하는 단어로, 원문의 "망아지"라는 비유와는 어감이 다릅니다.
# 또한 "상대를 보면서 하세요"는 '상대가 누구인지 보고 행동하라'는 경고의 의미가 강하게 담겨 있습니다.
# 따라서 원문의 비유적 표현을 살리면서도 경고의 뉘앙스를 유지하는 방향으로 새롭게 번역해야 합니다.
# </reasoning>
# <translate>
# Before you start acting wild like a colt, you'd better consider who you're dealing with.
# </translate>
# <translate>You might get your head cut off. </translate>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 75
#      73 elif '...' not in review_li[i]:
#      74     review_text2 = f"{input_text}\n\n## review\n[한글 대화] {kor_li[i]}\n[1차 영어 번역문] {review_li[i]}\n\n"
# ---> 75     review_completion2 = openai_client.beta.chat.completions.parse(
#      76         model= GPT_BASE_MODEL,
#      77         messages = [
#      78             SYSTEM_REVIEW_PROMPT2,
#      79             {
#      80                 "role":"user",
#      81                 "content" : [{"type" : "text",
#      82                               "text" : review_text2
#      83                             }],
#      84             }
#      85         ],
#      86         temperature= 0.2,
#      87         top_p = 0.8
#      88     )
#      89     review2 = review_completion2.choices[0].message.content
#      90     print(review2)
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/openai/resources/beta/chat/completions.py:161, in Completions.parse(self, messages, model, audio, response_format, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, seed, service_tier, stop, store, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     154 def parser(raw_completion: ChatCompletion) -> ParsedChatCompletion[ResponseFormatT]:
#     155     return _parse_chat_completion(
#     156         response_format=response_format,
#     157         chat_completion=raw_completion,
#     158         input_tools=tools,
#     159     )
# --> 161 return self._post(
#     162     "/chat/completions",
#     163     body=maybe_transform(
#     164         {
#     165             "messages": messages,
#     166             "model": model,
#     167             "audio": audio,
#     168             "frequency_penalty": frequency_penalty,
#     169             "function_call": function_call,
#     170             "functions": functions,
#     171             "logit_bias": logit_bias,
#     172             "logprobs": logprobs,
#     173             "max_completion_tokens": max_completion_tokens,
#     174             "max_tokens": max_tokens,
#     175             "metadata": metadata,
#     176             "modalities": modalities,
#     177             "n": n,
#     178             "parallel_tool_calls": parallel_tool_calls,
#     179             "prediction": prediction,
#     180             "presence_penalty": presence_penalty,
#     181             "reasoning_effort": reasoning_effort,
#     182             "response_format": _type_to_response_format(response_format),
#     183             "seed": seed,
#     184             "service_tier": service_tier,
#     185             "stop": stop,
#     186             "store": store,
#     187             "stream": False,
#     188             "stream_options": stream_options,
#     189             "temperature": temperature,
#     190             "tool_choice": tool_choice,
#     191             "tools": tools,
#     192             "top_logprobs": top_logprobs,
#     193             "top_p": top_p,
#     194             "user": user,
#     195         },
#     196         completion_create_params.CompletionCreateParams,
#     197     ),
#     198     options=make_request_options(
#     199         extra_headers=extra_headers,
#     200         extra_query=extra_query,
#     201         extra_body=extra_body,
#     202         timeout=timeout,
#     203         post_parser=parser,
#     204     ),
#     205     # we turn the `ChatCompletion` instance into a `ParsedChatCompletion`
#     206     # in the `parser` function above
#     207     cast_to=cast(Type[ParsedChatCompletion[ResponseFormatT]], ChatCompletion),
#     208     stream=False,
#     209 )
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/openai/_base_client.py:1290, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1276 def post(
#    1277     self,
#    1278     path: str,
#    (...)
#    1285     stream_cls: type[_StreamT] | None = None,
#    1286 ) -> ResponseT | _StreamT:
#    1287     opts = FinalRequestOptions.construct(
#    1288         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1289     )
# -> 1290     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/openai/_base_client.py:967, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     964 else:
#     965     retries_taken = 0
# --> 967 return self._request(
#     968     cast_to=cast_to,
#     969     options=options,
#     970     stream=stream,
#     971     stream_cls=stream_cls,
#     972     retries_taken=retries_taken,
#     973 )
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/openai/_base_client.py:1003, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1000 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#    1002 try:
# -> 1003     response = self._client.send(
#    1004         request,
#    1005         stream=stream or self._should_stream_response_body(request=request),
#    1006         **kwargs,
#    1007     )
#    1008 except httpx.TimeoutException as err:
#    1009     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /opt/conda/lib/python3.10/ssl.py:1292, in SSLSocket.recv(self, buflen, flags)
#    1288     if flags != 0:
#    1289         raise ValueError(
#    1290             "non-zero flags not allowed in calls to recv() on %s" %
#    1291             self.__class__)
# -> 1292     return self.read(buflen)
#    1293 else:
#    1294     return super().recv(buflen, flags)
#
# File /opt/conda/lib/python3.10/ssl.py:1165, in SSLSocket.read(self, len, buffer)
#    1163         return self._sslobj.read(len, buffer)
#    1164     else:
# -> 1165         return self._sslobj.read(len)
#    1166 except SSLError as x:
#    1167     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
