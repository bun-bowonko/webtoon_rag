# %%
import re
from langchain_community.vectorstores import FAISS
from langchain.docstore.document import Document
import bs4
import ssl
import urllib3
import pandas as pd
import faiss
import os
from langchain.embeddings import HuggingFaceEmbeddings
import torch
import gc
from tqdm import tqdm
from openai import OpenAI

def instruct_structure(prompt):
    input_text, output_text = prompt.split('### target')
    input_text = input_text.replace('### glossaries', '### glossary').replace('\n* ', '\n• ')
    input_text = re.sub(r"\[[^\]]+\] ", "[UNK] ", input_text)
    return input_text

project_id = "prod-ai-project"

from google.cloud import bigquery
client = bigquery.Client(project=project_id)
sql = """select series_id, episode_id, org_input_text, org_output_text, prompt 
        from webtoon_translation.structured_240820_ep_line
        where data_split = 'romance_valid'"""
df = client.query(sql).result().to_dataframe()
tqdm.pandas()
df['prompt'] = df['prompt'].progress_apply(lambda x: instruct_structure(x))
answers = df['org_output_text']

GPT_FINE_TUNING_MODEL="ft:gpt-4o-2024-08-06:kakaoent:webtoon-sft-250225:B4j839q0"
openai_client = OpenAI(
    api_key='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')

GPT_BASE_MODEL = "chatgpt-4o-latest"
SYSTEM_PROMPT = {
            "role": "system",
            "content": [
                {
                    "type": "text",
                    "text": """You're an expert translator who translates Korean webtoon in English. Make sure the number of target sentences matches the number of source sentences. The result should be TSV formatted. 
            • Find a balance between staying true to the Korean meaning and keeping a natural flow. Don't be afraid to add to the text. Embellish it. 
            • Avoid translating word-for-word. Keep the general feeling and translate the text accordingly. 
            • Translate with an American audience in mind. This means easy-to-read, conversational English.""",
                }
            ],
        }

SYSTEM_REVIEW_PROMPT = {
            "role": "system",
            "content": [
                {
                    "type": "text",
                    "text": "너는 [한국어 대화문] 내의 연결된 대사들을 분석하고 이를 [대사 문단]으로 정의한 뒤, [1차 번역문] 상에서 [대사 문단]에 속한 원소들이 잘 번역되어 있는지 확인하는 태스크를 수행할거야. \
                    그리고 만약 [1차 번역문]이 잘못된 경우, 이를 수정해서 재생성하는 태스크를 수행할 거야. \
                    먼저 맥락을 이해하기 위해 한 회차의 모든 [한국어 대화문]이 주어지고, \
                    이를 1차 번역한 [1차 번역문]이 주어질거야. \
                    각 대사에는 번호가 붙어 있을 것이고, 같은 번호는 같은 문장을 지칭해. 즉 [한국어 대화문]의 005번 대사를 번역한 것은 [1차 번역문]의 005번 대사라고 생각하면 돼.\
                    지금부터 너는 [한국어 대화문]에서 동일한 한 명의 화자가 발화한 이어진 대사를 구별해내고,\
                    이 대사들이 결합되어 한 문장을 구성할 수 있는지 확인해. 그리고 이를 [대사 문단]에 넣고, \
                    추후에 [대사 문단]에 넣은 대사들이 [1차 번역문] 상에서 올바르게 번역되어 있는지 검수한 후, \
                    올바르게 번역되지 않았다면 [단어집]과 [대사 문단]의 각 원소를 참고해서 새롭게 번역하고, \
                    올바르게 번역 되어있다면 [1차 번역문]에 있는 그대로 생성할거야.\n\
                    \
                    먼저 배경지식을 알려주자면 웹툰에서 '...','…'은 이전 대사나 이후 대사와의 연결을 의미할 가능성이 커. 100%는 아니야. \
                    다시 말해서 '...','…'으로 시작하면 이전 대사와 현재 대사가 연결되어 있을 가능성이 크고, \
                    '...','…'으로 끝나면 다음 대사와 현재 대사가 연결되어 있을 가능성이 커.\
                    그리고 '(호칭 혹은 이름),' + '대사' 형태로 이어지는 경우도 많아\n\
                    \
                    태스크를 올바르게 수행하기 위해서 너는 첫 번째로 [대사 문단]을 찾아야해. \
                    [대사 문단]이란 [한국어 대화문] 내에서 동일한 한 명의 화자가 발화하는 연속되는 대사가 '모두 불완전한 대사'이거나, \
                    '2개 이상의 불완전한 대사와 불완전한 대사를 보완해주는 완전한 1문장의 결합'을 의미해. \
                    예를 들어 6개의 대사로 구성된 [한국어 대화문]과 [1차 번역문]이 있다고 가정해볼게. \n\
                    '[한국어 대화문]\n000\t어제,\n001\t나는 푸른...\n002\t하늘을 보았다.\n003\t어땠어?\n004\t정말,\n005...아름다웠어.\n' \
                    라는 [한국어 대화문]이 있다면 [대사 문단]은 [(000~002),(004~005)]로 구성될 수 있어.\
                    왜냐하면 000부터 002까지의 대사는 웹툰 내에서 동일한 한 명의 등장인물이 연속적으로 발화한 것으로 보이며, \
                    각 대사가 '모두' 불완전하고 3개의 대사를 결합했을 때 딱 한 문장으로 결합돼.\
                    ***important*** 여기서 개념을 하나 설명할게. 너가 수행하는 태스크에서 '불완전한 대사'를 예를 들어서 설명해줄게. \
                    '(1)000\t당신!\n001\t밥\n002\t먹었어?\n','(2)000\t너,\n001\t밥 먹었어?\n002\t난 이제 먹어야하는데...\n003\t뭐 먹었어?\n' 와 같은 예시가 주어졌다고 가정해보자.\
                    두 가지 예시 모두 '(1)당신! 밥 먹었어?','(2)너, 밥 먹었어? 난 이제 먹어야하는데 뭐 먹었어?' 와 같이 결합했을 때 \
                    (1)과 (2)모두 동일한 한 명의 화자가 연속적으로 발화하는 대사들이지만 (1)의 '당신!'과 (2)의 '난 이제 먹어야하는데...', '뭐 먹었어?' 같은 각각의 대사는 하나의 독립적인 완전한 대사로써, \
                    (1)대사 전체를 결합하면 완전한 대사 2개('당신!','밥 먹었어?')가 결합되어 2문장의 대사가 나오고, \
                    (2)대사 전체를 결합하면 완전한 대사 3개가 결합되어, 3문장의 대사가 나와. ('너, 밥 먹었어?', '난 이제 먹어야하는데...', '뭐 먹었어?') \
                    [대사 문단]에 넣기 위해서는 대사를 모두 결합했을 때 딱 한 문장의 대사가 나와야해.\n\
                    반면 (1)의 '밥','먹었어?'는 각각 하나의 독립적인 대사로 활용했을 때 불완전한 대사로 보기 때문에 이전 혹은 이후 대사와 결합해야해.\
                    좀 더 구체적으로 설명하자면 (1)의 '당신!'은 독립적으로 사용가능한 완전한 대사로 볼 수 있지만, 뒤에 있는 대사 '밥'과 '먹었어?'가 불완전한 대사이고, \
                    '밥 먹었어?' 라고 연결했을 때 한 문장으로 볼 수 있으므로, \
                    불완전한 두 개의 대사인 '밥'과 '먹었어?'를 결합하여 [대사 문단]의 한 원소로 넣는거야.\
                    하지만 '당신!'까지 결합하면 '당신! 밥 먹었어?'와 같이 완전한 대사가 2개가 포함된 2문장이 되기 때문에 [대사 문단]의 한 원소가 될 수 없어.\
                    즉 불완전한 대사 여러 개를 결합했을 때 한 문장이 될 수 있다는 걸 보여주는 예인거지.\n \
                    그리고 (2)의 001 번 째 대사인 '밥 먹었어?'같은 경우는 독립적으로 사용가능한 완전한 대사로 볼 수 있지만, 앞 대사가 '너,'라는 뒤에 있는 대사를 필요로 하는 불완전한 대사이고, \
                    '너, 밥 먹었어?'라고 연결했을 때 두 개 이상의 문장이 아닌, 한 문장으로 볼 수 있으므로, 불완전한 대사인 '너,'와 완전한 대사인 '밥 먹었어?'를 결합하여 [대사 문단]의 한 원소로 넣는거야. \
                    즉 불완전한 대사와 불완전한 대사가 필요로 하는 완전한 대사를 결합해도 한 문장이 될 가능성이 있지. \
                    그리고 불완전한 대사라는 걸 증명할 수 있는 근거가, 불완전한 대사들은 여러 개를 연속적으로 결합해도 최대 한 문장의 대사가 나오게 돼. \
                    즉 웹툰의 대사를 생각했을 떄 (1)의 모든 대사와 (2)의 일부 대사처럼 한 문장의 대사가 (여러 개의 불완전한 대사) 혹은 (여러 개의 불완전한 대사+한 개의 완전한 대사)로 나뉜 경우만 [대사 문단]의 한 원소가 될 수 있고, \
                    (2)의 '난 이제 먹어야하는데...', '뭐 먹었어?'처럼 완전한 대사 둘은 결합되면 두 문장이 되기 때문에, [대사 문단]의 한 원소가 될 수 없다는 뜻이야.\
                    또한 (2)의 '너', '밥 먹었어?', '난 이제 먹어야하는데...' 도 결합하면 '너, 밥먹었어? 난 이제 먹어야하는데...'와 같이 두 문장이 되기 때문에 '너', '밥 먹었어?'까지만 [대사 문단]으로 포함시켜야해. \
                    ***important*** 쉽게 생각하면 '두 개 이상의 불완전한 대사'들 혹은 '한 개 이상의 불완전한 대사와 불완전한 대사가 필요로하는 한 개의 완전한 대사'가 결합되어 한 문장을 이룬다면 [대사 문단]의 한 원소가 될 수 있지만, \
                    '한 문장을 구성할 수 있는 두 개 이상의 불완전한 대사'와 '완전한 대사'가 결합되거나, \
                    완전한 대사 둘 이상이 결합되면 두 문장 이상이 되기 때문에 [대사 문단]의 한 원소가 될 수 없어. \n\
                    다시 돌아가서, [대사 문단]을 찾을 때는 동일한 한 명의 화자가 연속적으로 발화한 대사인지를 엄격하게 검수한 후에, \
                    각 대사들을 결합했을 때 최대 한 문장이 된다면 해당 대사들을 묶어서 [대사 문단]의 한 원소로 정의하면 돼.\n\
                    명심해야할 건 아무리 하나의 완전한 대사가 불완전한 대사를 보완해준다고 하더라도, 결합했을 때 2문장 이상이 되면 [대사 문단]에 포함될 수 없어.\n\
                    그리고 [한국어 대화문]의 003은 앞과 뒤 화자와는 다른 화자임이 분명하고, 그 자체로 완전한 문장이며, 앞 뒤에 연결할 불완전한 대사가 없기 때문에 [대사 문단]의 한 원소로 포함될 수 없어. \
                    좀 더 다른 예를 들어 설명하자면 '(3)100\t너 말이야\n101\t뭐가?\n102\t좀 이상한 거 같애\n'라는 대사가 주어졌을 때 \
                    100 번 째 대사와 102 번 째 대사의 화자는 같은 것으로 판단되지만 중간에 101 번 째 대사는 다른 화자인 것으로 판단되기 때문에, 3가지의 대사는 연결된 대사가 아니고, 결합돼서는 안 돼. 즉 [대사 문단]의 한 원소로 포함될 수 없어.\n\
                    그리고 004~005 또한 동일한 한 명의 화자가 발화하고 있는 것으로 판단되고, 각 대사가 불완전하고, 각 대사를 결합하면 딱 한 문장이 되기 때문에, 결합하여 [대사 문단]의 한 원소로 포함시켜.\
                    ***important*** 특히 대사의 화자가 동일한지 판단할 때는 발화자에 대응하는 명사를 유심히 봐야하고, \
                    웹툰 내 대사는 발화자가 생략된 경우가 많기 때문에 이를 잘 유추해서 동일한 화자가 맞는지 잘 판단해야해.\n\
                    여기까지 내용을 요약해보자면, [대사 문단]의 한 원소가 되는 방법은 아래 조건을 모두 만족해야해. \
                    조건1) 동일한 한 명의 화자가 발화한 대사들이어야 함. 다른 화자가 발화한 대사가 섞이면 절대 안 됨.\
                    조건2) 대사들을 결합했을 때 한 문장이어야함. 두 문장 이상이 되면 절대 안 됨.\n\
                    \
                    그 다음에 [한국어 대화문]에 속한 모든 대사에 대해서 [대사 문단]의 모든 원소를 찾고 각 원소에 대해서 하나의 문장으로 결합해. \
                    위 예시대로라면 [(000~002,'어제 나는 푸른 하늘을 보았다.'),(004~005,'정말 아름다웠어…')] 라는 결과가 나올거야. \
                    [대사 문단]의 한 원소에 대한 각 대사들을 하나의 문단으로 결합할 때는 결합한 문장의 양 끝에 있는 특수문자를 제외하고, '.','...','…', ','와 같은 문장 중간에 들어가는 특수 문자는 제거해. \n\
                    그리고 이제 함께 주어진 [1차 번역문]이 다음과 같다고 해볼게.\n\
                    '[1차 번역문]\n000\tyesterday,\n001\tI...\n002\tsaw the blue sky.\n003\thow was it?\n004\tit was\n005really dark…\n'\
                    그랬을 때 [대사 문단]에 쓰여진 것과 동일하게 결합해. \
                    위 예에서는 [한국어 대화문] 상에서 (000~002), 그리고 (004~005)가 각각 결합되었기 때문에 \
                    동일하게 [1차 번역문] 상에서도 (000~002)와 (004~005)를 결합하고 (연결을 위한 특수 문자는 제거) 이전 결과물에 붙여. \
                    그렇게 하면, 다음과 같은 결과물을 얻을 수 있어.\n \
                    [((000~002),'어제 나는 푸른 하늘을 보았다.','yesterday I saw the blue sky.'),\
                    ((004~005),'정말 아름다웠어.','it was really dark…')]\n \
                    그 다음 리스트 내 각 원소의 한글 문장과 영어 문장의 의미를 비교해.\
                    만약 '어제 나는 푸른 하늘을 보았다.'와 'yesterday I saw the blue sky.'처럼 두 문장의 의미가 동일하다면 \
                    영어 문장을 해당 문장을 구성한 대사의 개수 n개(해당 예에서는 000~002:3개)로 나누고, 나뉘는 부분 양 쪽에 '...'를 삽입해. \n\
                    ***important*** 단, 나눌 때 해당 문장을 구성하는 대사 개수 n개로만 나눠야 하며, 나누는 개수를 유지하면서 최대한 웹툰 독자가 읽기에 편하도록 나누고, 나눈 이후의 각 요소는 적어도 하나의 단어를 포함하고 있어야 해.\n\
                    예를 들어 'yesterday', 'I saw', 'the blue sky.'로 나누는게 웹툰 대사상 적합하다고 생각한다면, \n\
                    '000\tyesterday...\n001\t...I saw...\n002\t...the blue sky.\n' 를 생성하는거야. \n\
                    그리고 이어서 003은 [대사 문단]에 속하지 않기 때문에 [1차 번역문]의 003번을 똑같이 생성해. 그러면 다음과 같이 될거야.\n \
                    '003\thow was it?\n'\n\
                    그 다음 004번과 005번이 [대사 문단]의 한 원소이기 때문에, '정말 아름다웠어…'와 'it was really dark…'의 의미를 비교하고, \
                    둘의 의미가 다르기 때문에 영어 문장을 무시하고, [결합된 한글 문장]을 재번역해. \
                    여기서는 'it was really dark…'를 무시하고, [결합된 한글 문장]인 '정말 아름다웠어…'를 번역하면 돼. 대신 재번역할 때 참고해야할 고유명사가 있을 수도 있으니 [단어집]을 참고해서 번역해. \
                    그럼 'it was really beautiful…'을 얻을 수 있고, 이를 똑같이 [대사 문단]을 구성하는 대사 개수인 n개(해당 예에서는 004~005:2개)로 나누고, 나뉘는 부분 양 쪽에 '...'를 삽입해. \n\
                    ***important*** 단, 나눌 때 해당 문장을 구성하는 대사 개수 n개로만 나눠야 하며, 나누는 개수를 유지하면서 최대한 웹툰 독자가 읽기 편하도록 나누고, 나눈 이후의 각 요소는 적어도 하나의 단어를 포함하고 있어야 해.\n\
                    예를 들어 'it was', 'really beautiful…'로 나누는게 웹툰 대사상 적합하다고 생각한다면, \
                    '004\tit was...\n005\t...really beautiful…\n'를 생성하는거야. \
                    위 예의 최종적인 출력형태는 다음과 같아. \n\
                    <translate>\n000\tyesterday...\n001\t...I saw...\n002\t...the blue sky.\n003\thow was it?\n004\tit was...\n005\t...really beautiful…\n</translate>\
                    그리고 만약 추론이 필요하다면 <reasoning>으로 시작해서 추론 내용을 입력하고 </reasoning>으로 마무리해. \
                    즉 정리하자면 출력 형태는 '<reasoning> ...추론 내용... </reasoning> <translate> 검토한 영어 번역문 </translate>' \
                    혹은 '<translate> 검토한 영어 번역문 </translate>' 가 될 거야.\n \
                    그리고 [검토한 영어 번역문]에는 [한국어 대화문]에 속한 모든 대사 개수만큼이 포함되어야 하는 것을 잊지마."
                }
            ],
}

SYSTEM_REVIEW_PROMPT2 = {
            "role": "system",
            "content": [
                {
                    "type": "text",
                    "text": "너는 1차 번역된 웹툰 대화를 검토하고 이를 수정하거나 아예 재생성하는 태스크를 수행할 거야. \
                    먼저 맥락을 이해하기 위해 한 회차의 모든 [한국어 대화문]이 주어지고, \
                    그 중에서 맨 마지막 두 줄에 [한글 대화]와 이 대화에 대응되는 [1차 영어 번역문]이 주어질 거야. \
                    먼저 [1차 영어 번역문]을 한글로 번역해서 [1차 한글 번역문]을 생성하고, [한글 대화]의 의미가 일치하는지 비교해.\n\
                    만약 의미가 일치한다면 그대로 생성해도 돼. \
                    하지만 만약 [1차 한글 번역문]과 [한글 대화]의 의미가 일치하지 않거나 정보의 양이 다르다면 \
                    [1차 영어 번역문]과 [1차 한글 번역문]은 무시하고 [한글 대화]에 대응하는 영어 번역문을 생성해.\
                    ***important*** 정보의 양에 대해서 설명할게. \
                    예를 들어 [한글 대화]가 '사과'인데 [1차 한글 번역문]이 '붉은 사과'라면 \
                    이는 [한글 대화]에 [1차 한글 번역문]의 일부만 제공된 상태이기 때문에 정보의 양이 다른 것으로 판단해. \
                    하지만 예외적으로 [한글 대화]가 '달렸다'인데 [1차 한글 번역문]이 '주어가 달렸다'라면 \
                    이는 정보의 양이 같은 것으로 판단해. \
                    왜냐하면 웹툰은 영어로 번역할 때 생략된 주어도 넣어줘야하기 때문에 주어의 추가는 정보의 양이 다른 걸로 판단하지 않아.\
                    하지만 반대로 [한글 대화]가 '주어가 달렸다'인데 [1차 한글 번역문]이 '달렸다'라면 이건 정보의 누락이 발생한 것으로 보고 정보의 양이 다르다고 판단해.\
                    그리고 [한글 대화]가 '그녀는 잠을 잔다'인데 [1차 한글 번역문]이 '그것을 잠을 잔다'라면 [한국어 대화문]에서 그것이 그녀와 일치하는지를 판단해.\
                    만약 일치한다면 이는 정보의 양이 같은 것이고, 일치하지 않는다면 정보의 양이 다른 거야. 웹툰은 사람도 '이것', '저것'이라고 표현할 수 있어.\n\
                    \
                    따라서 [1차 한글 번역문]과 [한글 대화]의 의미가 일치하지 않거나 정보의 양이 다르면,\
                    [1차 한글 번역문]과 [1차 영어 번역문]은 무시하고 [한글 대화]만을 가지고 다시 번역하면 돼.\n \
                    그리고 새롭게 생성한 영어 번역문은 <translate>로 시작하고 </translate>로 끝내, \
                    만약 추론이 필요하다면 <reasoning>으로 시작해서 추론 내용을 입력하고 </reasoning>으로 마무리해. \
                    추론할 때는 이 대사의 주어가 무엇인지도 생각해. 평서문이나 의문문에서 주어는 무조건 [검토한 영어 번역문]에 있어야 해.\
                    ***important*** 그리고 출력에 다음 대사나 이전 대사의 내용을 추가하지말고, 주어진 [한글 대화]의 내용만으로 번역문을 구성해. \
                    대신 [한글 대화]가 의문문이나 평서문인데 주어가 없는 경우 알맞은 주어를 추가해서 번역해야해. \
                    즉 정리하자면 출력 형태는 '<reasoning> ...추론 내용... </reasoning> <translate> 검토한 영어 번역문 </translate>' \
                    혹은 '<translate> 검토한 영어 번역문 </translate>' 가 될 거야"
                }
            ],
}
# Out:
# /home/bun.2/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/google/cloud/bigquery/table.py:1820: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 74/74 [00:00<00:00, 19327.39it/s]

# %%
def clean_text(text):
    return text.replace("[UNK] ","")
    
def clean_text2(text):
    return re.sub(r'^\d+\s+','', text)

def extract_translation(text):
    match = re.search(r'<translate>(.*?)</translate>', text, re.DOTALL)
    return match.group(1).strip() if match else None

for data_idx in range(58, 60+1):
    data = df['prompt'][data_idx]
    example = data.split("### source")[1].strip()
    chat_completion = openai_client.beta.chat.completions.parse(
        model= GPT_FINE_TUNING_MODEL,
        messages = [
            SYSTEM_PROMPT,
            {
                "role":"user",
                "content" : [{"type" : "text",
                              "text" : data
                            }],
            }
        ],
        temperature= 0.2,
        top_p = 0.8
    )
    response = chat_completion.choices[0].message.content
    response_split = [clean_text2(res) for res in response.split('\n')]
    source = data.split("### source")[1].strip()
    glossary = data.split("### source")[0].strip()
    
    kor = clean_text(source)
    en = response
    input_text = f"[한국어 대화문]\n{kor}\n\n[1차 번역문]\n{en}\n\n[단어집]\n{glossary}"

    review_text = f"{input_text}\n\n### review\n\n" 
    kor_li = [clean_text2(k) for k in kor.split('\n')]
    
    en_li = en.split('\n')
    #print(kor_li)
    review_li = []
    while True:
        if len(review_li) == len(kor_li):
            break
        # else:
        #     print(len(review_li),len(kor_li))
        review_completion = openai_client.beta.chat.completions.parse(
            model= GPT_BASE_MODEL,
            messages = [
                SYSTEM_REVIEW_PROMPT,
                {
                    "role":"user",
                    "content" : [{"type" : "text",
                                  "text" : input_text
                                }],
                }
            ],
            temperature= 0.2,
            top_p = 0.6
        )
        review = review_completion.choices[0].message.content
        print(review)
        review_li = extract_translation(review).split('\n')
        print(len(review_li),len(kor_li))

    #review_li : 1차 번역문에서 이어진 문장 처리한 2차 번역문
    #kor : 한글 대화문
    #glossary : 용어집
    print("="*20)
    input_text = f"{glossary}\n\n{kor}"
    review_li2 = []
    for i, review in enumerate(review_li):
        r = clean_text2(review)
        if '...' in r:#이어지는 문장이면 검수 안 하고 패스
            review_li2.append(r)
        elif '...' not in r:#이어지는 문장이 아니면 검수하고 
            review_text2 = f"{input_text}\n\n## review\n[한글 대화] {kor_li[i]}\n[1차 영어 번역문] {r}\n\n"
            review_completion2 = openai_client.beta.chat.completions.parse(
                model= GPT_BASE_MODEL,
                messages = [
                    SYSTEM_REVIEW_PROMPT2,
                    {
                        "role":"user",
                        "content" : [{"type" : "text",
                                      "text" : review_text2
                                    }],
                    }
                ],
                temperature= 0.2,
                top_p = 0.8
            )
            review2 = review_completion2.choices[0].message.content
            print(review2)#검수 아웃풋
            review_li2.append(extract_translation(review2))#검수 결과
    assert len(review_li2) == len(review_li) #기존 한글 대사의 개수와 2차 번역한 대사의 개수가 같아야 함

    #kor_li # 한글 대화 리스트
    #response_split#2차 번역 리스트
    #review_li2 #3차 번역 리스트
    import csv
    labels = answers[data_idx]
    with open(f"data/2nd_review_testset/result_{data_idx}_try3.csv", mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['hangle', 'first_translate', 'second_translate', 'label'])
        for row in zip(kor_li, response_split, review_li2, labels):
            writer.writerow(row)
# Out:
# <reasoning>
# 먼저 [대사 문단]을 추출하기 위해 [한국어 대화문]을 분석한다.
#
# (000~003): 000~003은 모두 동일한 화자가 발화한 것으로 보이며, 000~001, 002~003이 각각 연결된 문장으로 보인다. 전체적으로 하나의 초대 메시지로 구성되며, 결합하면 "『금일 오후, 온실에서 있을 티 파티에 영애를 초대하고 싶습니다.』 『시간이 나신다면 꼭 참석해 주세요, 헤더 아덴 자작 영애.』"로 하나의 문장으로 볼 수 있다. 따라서 (000~003)은 [대사 문단]의 한 원소가 된다.
#
# (004~005): 동일한 화자가 연속적으로 발화하며, "이 사람, 어제 시그렌이랑 일이 있었던 그 영애 아냐?"로 하나의 문장으로 결합 가능. [대사 문단]의 한 원소.
#
# (007~008): "내가 괜히 신경 쓸 만한 이유는 없지. 잘못한 건 그쪽이고."는 두 개의 완전한 문장으로 구성되어 있으므로 [대사 문단]에 포함될 수 없음.
#
# (017~018): "…그래도 마차에도 와 주세요. 혼자서는 심심해서…."는 연결된 문장으로 하나의 문장으로 결합 가능. 동일 화자. [대사 문단]의 한 원소.
#
# (023~027): "어머나, 피오나 영애, 유니스 영애… 초대에 응해주셔서 감사해요. 기다리고 있었답니다."는 모두 동일 화자이며, 연결된 문장으로 하나의 문장으로 결합 가능. [대사 문단]의 한 원소.
#
# (044~049): "소문 이야기가 나와서 말인데요, 듣자 하니… 영애의 핏줄은 조금 특별하다면서요? 본래는 헤일론 쪽이 아니라고 들었어요. 제가 알기로는, 사생아라던데."는 동일 화자이며, 연결된 문장으로 하나의 문장으로 결합 가능. [대사 문단]의 한 원소.
#
# (084~086): "하지만 똑똑한 아덴 영애가 하나 파악하지 못한 게 있네요. 저는 그 덕분에 권력과 힘, 두 개 다 가지고 있답니다."는 동일 화자이며, 하나의 문장으로 결합 가능. [대사 문단]의 한 원소.
#
# (087~088): "지금 이 자리에서 제가 영애의 머리카락을 불태워도 아덴 자작님은 제 아버지께 항의서 몇 장 보내는 게 고작일 거란 뜻이죠."는 하나의 문장. [대사 문단]의 한 원소.
#
# (089~090): "망아지처럼 구는 것도 상대를 보면서 하세요. 그러다 목 잘려요."는 두 개의 완전한 문장으로 구성되어 있으므로 [대사 문단]에 포함될 수 없음.
#
# (098~100): "마지막으로 충고 하나 할게요. 남의 남자 탐내지 마세요. 이건 지금 내 거거든."은 세 개의 완전한 문장으로 구성되어 있으므로 [대사 문단]에 포함될 수 없음.
#
# 최종 [대사 문단]은 다음과 같다:
# [(000~003), (004~005), (017~018), (023~027), (044~049), (084~086), (087~088)]
#
# 각 문단을 결합하면 다음과 같다:
# (000~003): "『금일 오후, 온실에서 있을 티 파티에 영애를 초대하고 싶습니다.』 『시간이 나신다면 꼭 참석해 주세요, 헤더 아덴 자작 영애.』"
# (004~005): "이 사람, 어제 시그렌이랑 일이 있었던 그 영애 아냐?"
# (017~018): "…그래도 마차에도 와 주세요. 혼자서는 심심해서…."
# (023~027): "어머나, 피오나 영애, 유니스 영애… 초대에 응해주셔서 감사해요. 기다리고 있었답니다."
# (044~049): "소문 이야기가 나와서 말인데요, 듣자 하니… 영애의 핏줄은 조금 특별하다면서요? 본래는 헤일론 쪽이 아니라고 들었어요. 제가 알기로는, 사생아라던데."
# (084~086): "하지만 똑똑한 아덴 영애가 하나 파악하지 못한 게 있네요. 저는 그 덕분에 권력과 힘, 두 개 다 가지고 있답니다."
# (087~088): "지금 이 자리에서 제가 영애의 머리카락을 불태워도 아덴 자작님은 제 아버지께 항의서 몇 장 보내는 게 고작일 거란 뜻이죠."
#
# 이제 [1차 번역문]의 해당 부분을 확인하고, 의미가 일치하는지 검토한다.
#
# (000~003): "I would like to invite you, my lady, to a tea party in the greenhouse this afternoon.” “Please attend if you have time, lady heather adens.” → 의미 일치. 4개 대사이므로 4개로 나눔.
#
# (004~005): "isn’t this... the lady who caused trouble with siegren yesterday?" → 의미 일치. 2개 대사이므로 2개로 나눔.
#
# (017~018): "please come to the carriage sometimes. it’s boring by myself..." → 의미 일치. 2개 대사이므로 2개로 나눔.
#
# (023~027): "oh my, lady fiona, lady eunice... thank you for accepting my invitation. I’ve been waiting for you." → 의미 일치. 5개 대사이므로 5개로 나눔.
#
# (044~049): "speaking of rumors, I heard... your bloodline is a bit special. I heard you’re not originally from house hylon. from what I know, you’re an illegitimate child." → 의미 일치. 6개 대사이므로 6개로 나눔.
#
# (084~086): "but there’s one thing a smart lady like you hasn’t realized. thanks to that, I now have both power... and authority." → 의미 일치. 3개 대사이므로 3개로 나눔.
#
# (087~088): "that means even if I burn your hair right here, the most your father could do is send a few letters of complaint to my father." → 의미 일치. 2개 대사이므로 2개로 나눔.
#
# </reasoning>
#
# <translate>
# 000	“I would like...
# 001	...to invite you, my lady,...
# 002	...to a tea party in the greenhouse this afternoon.”
# 003	“Please attend if you have time,...
# 004	...lady heather adens.”
# 005	isn’t this...
# 006	...the lady who caused trouble with siegren yesterday?
# 007	should I really attend a tea party hosted by someone like that?
# 008	well, there’s no reason for me to be concerned.
# 009	she’s the one who did something wrong.
# 010	and I might be able to see eunice at the tea party.
# 011	please tell her I’ll be happy to attend.
# 012	lady eunice.
# 013	lady fiona!
# 014	were you invited as well?
# 015	yes.
# 016	we’re traveling together, but I haven’t had a chance to see you.
# 017	please come...
# 018	...to the carriage sometimes.
# 019	it’s boring by myself...
# 020	she must have felt lonely surrounded by knights and soldiers.
# 021	welcome.
# 022	this is the greenhouse.
# 023	oh my,...
# 024	...lady fiona,...
# 025	...lady eunice...
# 026	...thank you for accepting my invitation.
# 027	...I’ve been waiting for you.
# 028	wow, she really is a stunning beauty.
# 029	she’s the one who threw herself at siegren.
# 030	please, have a seat.
# 031	yes, thank you.
# 032	these ladies are from nearby territories.
# 033	it’s an honor to meet you both.
# 034	yes...
# 035	pleased to meet you.
# 036	what’s this?
# 037	I feel like they’re giving me strange looks...
# 038	I heard you were in the north, lady fiona.
# 039	that’s right.
# 040	wasn’t it difficult?
# 041	I heard a very barbaric and cruel sorcerer lives there...
# 042	it’s just like any other place where people live.
# 043	wait, that rumor spread all the way here?!
# 044	speaking of rumors,...
# 045	...I heard...
# 046	...your bloodline is a bit special.
# 047	...I heard you’re not originally from house hylon.
# 048	...from what I know,...
# 049	...you’re an illegitimate child.
# 050	yes, that’s true.
# 051	I am an illegitimate child.
# 052	you know exactly what you’re talking about.
# 053	she’s smiling?
# 054	and your original family...
# 055	yes, their wealth was confiscated due to drug trafficking.
# 056	I was the one who reported them.
# 057	goodness, I could never do something like that.
# 058	betraying your own family with your own hands, no matter the reason...
# 059	only a beast would do something like that.
# 060	w-wait!
# 061	lady fiona...
# 062	so,
# 063	what are you trying to say?
# 064	I’m telling you to know your place!
# 065	even if you were lucky enough to be adopted,
# 066	you should know your place as a noble lady.
# 067	so...
# 068	...you too...
# 069	siegren.
# 070	lady fiona, why are you looking elsewhere?
# 071	can’t you see I’m talking to you?
# 072	I still have more to say.
# 073	you...
# 074	...flirted with his highness while staying at someone else’s manor, didn’t you?
# 075	my maid told me about what happened last night--
# 076	wait.
# 077	lady heather, you’re going too far!
# 078	what do you mean, too far?
# 079	I’m just stating the facts--
# 080	ah,
# 081	aaah!
# 082	you’re right about everything you said.
# 083	I’m an illegitimate child, and I destroyed the family I was born into.
# 084	but there’s one thing...
# 085	...a smart lady like you hasn’t realized.
# 086	...thanks to that, I now have both power and authority.
# 087	that means even if I burn your hair right here,...
# 088	...the most your father could do is send a few letters of complaint to my father.
# 089	you should know who you’re dealing with before you act like a brat.
# 090	you might lose your head.
# 091	and...
# 092	your...
# 093	your highness...
# 094	it looks like you’re having a very enjoyable tea party,
# 095	lady heather adens.
# 096	I-I...
# 097	after what happened yesterday, she can’t even look at him.
# 098	let me give you one last piece of advice.
# 099	don’t covet someone else’s man.
# 100	he’s mine now.
# </translate>
# 101 101
# ====================
# <reasoning> [한글 대화]는 "내가 괜히 신경 쓸 만한 이유는 없지."로, 이는 화자가 스스로에게 '내가 굳이 신경 쓸 필요는 없다'고 말하며 마음을 다잡는 표현이다. 반면 [1차 영어 번역문] "should I really attend a tea party hosted by someone like that?"는 '내가 그런 사람이 주최한 티파티에 정말 가야 할까?'라는 의문문으로, 전혀 다른 의미다. 원문은 자기 확신을 표현하는 평서문이고, 1차 번역은 의심을 나타내는 의문문이다. 따라서 의미가 일치하지 않으며, 새로운 번역이 필요하다. 주어는 'I'로 명확하다. </reasoning>
# <translate> There's no reason for me to worry about it. </translate>
# <reasoning> [한글 대화]는 "잘못한 건 그쪽이고."로, 명확하게 누가 잘못했는지를 지적하는 내용이다. 이는 상대방에게 책임이 있다는 의미다. 반면 [1차 영어 번역문] "well, there’s no reason for me to be concerned."는 "내가 신경 쓸 이유가 없다"는 말로, 책임 소재에 대한 언급 없이 단순히 자신의 감정 상태만을 표현하고 있다. 따라서 정보의 양이 다르고 의미도 일치하지 않는다. 주어는 화자인 'I'로 추론할 수 있다. </reasoning>
# <translate> They're the one at fault, not me. </translate>
# <reasoning>
# [한글 대화]는 "어쩌면 티파티에서 유니스를 만날 수 있을지도 모르니까."로, 화자가 티파티에 가는 이유 중 하나가 유니스를 만날 수 있을지도 모른다는 기대감을 표현한 문장이다. 이는 추측을 나타내는 표현이며, 주어는 화자 자신이다.
#
# 반면 [1차 영어 번역문] "she’s the one who did something wrong."은 "그녀가 잘못한 사람이다"라는 의미로, 전혀 다른 내용을 담고 있다. 이는 [한글 대화]의 의미와 전혀 일치하지 않으며, 정보의 양도 다르다. 따라서 [1차 영어 번역문]은 무시하고 [한글 대화]를 기준으로 새롭게 번역해야 한다.
#
# 이 문장은 추측을 나타내므로 "maybe", "perhaps", 또는 "I might" 등의 표현이 적절하며, 주어는 "I"로 명시해야 한다.
# </reasoning>
# <translate>I might be able to see Eunice at the tea party.</translate>
# <reasoning> [한글 대화]는 "기쁜 마음으로 응하겠다고 전해줘."로, 이는 화자가 초대에 기꺼이 응하겠다는 의사를 전달해 달라는 내용이다. 반면 [1차 영어 번역문]은 "and I might be able to see eunice at the tea party."로, 이는 유니스를 티파티에서 볼 수 있을지도 모른다는 기대를 표현한 문장이다. 두 문장은 의미가 전혀 다르며, [1차 영어 번역문]에는 초대에 응한다는 내용이 전혀 포함되어 있지 않다. 따라서 정보의 양이 다르고 의미도 일치하지 않으므로, [한글 대화]를 기준으로 새롭게 번역해야 한다. 주어는 화자이며, 전달을 부탁하는 대상은 명시되어 있지 않지만 일반적으로 "please tell them" 또는 "please let them know"와 같은 표현을 사용한다. </reasoning>
# <translate>Please let them know that I gladly accept the invitation. </translate>
# <reasoning> [한글 대화]는 "유니스 영애."로, 이는 단순히 "Lady Eunice."라고 부르는 호칭 또는 상대를 지칭하는 말이다. 반면 [1차 영어 번역문] "please tell her I’ll be happy to attend."는 "그녀에게 내가 기쁜 마음으로 참석하겠다고 전해줘."라는 의미로, 이는 [한글 대화]보다 훨씬 많은 정보를 담고 있다. 즉, [1차 영어 번역문]은 발화의 목적, 감정, 전달 대상 등을 포함하고 있어 정보의 양이 다르다. 따라서 [한글 대화]에 맞춰 새롭게 번역해야 한다. 이 대사는 단순히 유니스를 부르는 말이므로, 영어로는 "Lady Eunice."로 번역하면 된다. </reasoning>
# <translate> Lady Eunice. </translate>
# <reasoning> [한글 대화]는 "피오나 영애…!"로, 이는 피오나를 부르거나 놀라움, 반가움 등의 감정을 담아 그녀의 이름을 외치는 표현이다. 그러나 [1차 영어 번역문]은 "lady eunice."로, 전혀 다른 인물인 유니스를 지칭하고 있다. 이는 인물 자체가 잘못 번역된 것으로, 의미가 일치하지 않으며 정보도 완전히 다르다. 따라서 [1차 영어 번역문]은 무시하고 새로 번역해야 한다. 이 대사의 주어는 생략되어 있지만, 감탄사 형태로 피오나를 부르는 것이므로 영어로는 감탄 표현을 담아 "Lady Fiona!"로 번역하는 것이 적절하다. </reasoning>
# <translate> Lady Fiona…! </translate>
# <reasoning>
# [한글 대화]는 "유니스 영애도 초대받은 건가요?"로, 이는 유니스가 초대를 받았는지를 묻는 질문이다. 주어는 화자이며, 대상은 유니스다. 반면 [1차 영어 번역문]은 "lady fiona!"로, 이는 단순히 피오나 영애를 부르는 말일 뿐이며, 질문의 의미가 전혀 담겨 있지 않다. 따라서 의미가 일치하지 않고 정보의 양도 다르다. 그러므로 [한글 대화]만을 바탕으로 새로운 영어 번역문을 생성해야 한다. 이 문장은 의문문이며, 주어는 생략되어 있으므로 영어 번역에서는 주어를 명시해야 한다.
# </reasoning>
# <translate>Was Lady Eunice invited as well? </translate>
# <reasoning> [한글 대화]는 "네."로, 이는 단순히 상대방의 질문에 대한 긍정의 대답이다. 반면 [1차 영어 번역문]은 "were you invited as well?"로, 이는 의문문이며 새로운 정보를 묻고 있다. 즉, [한글 대화]는 대답이고 [1차 영어 번역문]은 질문이기 때문에 의미가 일치하지 않는다. 따라서 [1차 영어 번역문]은 무시하고 [한글 대화]에 맞는 영어 번역문을 새로 생성해야 한다. 주어는 생략되어 있지만 문맥상 유니스가 말한 것으로 보이며, 영어에서는 주어를 명시해야 하므로 "Yes, I was."가 적절하다. </reasoning>
# <translate> Yes, I was. </translate>
# <reasoning> [한글 대화]는 "피오나 영애와는 같은 일행임에도 계속 얼굴을 볼 수가 없었네요."로, 피오나와 같은 일행이었지만 계속 얼굴을 볼 수 없었다는 아쉬움을 표현하고 있습니다. 그러나 [1차 영어 번역문]은 단순히 "yes"로, 원문의 의미를 전혀 담고 있지 않으며 정보의 양도 현저히 부족합니다. 따라서 [1차 영어 번역문]은 무시하고 [한글 대화]를 기반으로 새롭게 번역해야 합니다. 주어는 "I"로, 말하는 사람이 자신을 기준으로 이야기하고 있으므로 포함되어야 합니다. </reasoning>
# <translate>I was in the same group as Lady Fiona, but I hardly got to see her. </translate>
# <reasoning>
# [한글 대화]는 "전 말을 타고 있었거든요."로, 화자가 말을 타고 있었기 때문에 상대방을 볼 수 없었다는 이유를 설명하는 문장이다. 주어는 "저"이며, 동사는 "타고 있었거든요"로 과거 진행형이다.
#
# 반면 [1차 영어 번역문] "we’re traveling together, but I haven’t had a chance to see you."는 "우리는 함께 여행 중이지만, 당신을 볼 기회가 없었어요."라는 의미로, 말 타고 있었다는 구체적인 이유가 빠져 있고, 현재완료 시제를 사용하여 시점도 다르다.
#
# 즉, [1차 영어 번역문]은 [한글 대화]의 구체적인 이유(말을 타고 있었다)를 반영하지 않았기 때문에 정보의 양이 다르며 의미도 일치하지 않는다. 따라서 [한글 대화]만을 기반으로 새로운 영어 번역문을 생성해야 한다.
# </reasoning>
# <translate>I was on horseback. </translate>
# <reasoning> [한글 대화]는 "어서 오십시오."로, 이는 손님을 환영하는 인사말이다. 반면 [1차 영어 번역문]은 "she must have felt lonely surrounded by knights and soldiers."로, 어떤 여성이 기사와 병사들 사이에서 외로움을 느꼈을 것이라는 추측을 나타낸다. 이는 전혀 다른 의미이며, 정보의 양도 다르다. 따라서 [1차 영어 번역문]은 무시하고 [한글 대화]를 새롭게 번역해야 한다. 이 대사는 환영 인사이므로 주어는 생략되어 있지만 영어 번역에서는 주어를 넣어야 하므로 "Welcome"에 "You are"를 붙여서 "You are welcome" 또는 "Welcome"으로 번역할 수 있다. 하지만 자연스러운 상황 묘사를 위해 "Welcome"이 가장 적절하다. </reasoning>
# <translate> Welcome. </translate>
# <reasoning> [한글 대화] "이쪽이 온실입니다."는 특정 장소인 '온실'로 안내하면서 위치를 알려주는 설명문입니다. 주어는 생략되어 있지만, 문맥상 안내하는 인물(하인 등)이 말하고 있는 것으로 보이며, 영어로 번역할 때는 주어를 보완해야 합니다. 반면 [1차 영어 번역문] "welcome."은 단순한 환영 인사로, 장소 안내나 설명의 의미가 전혀 포함되어 있지 않기 때문에 정보의 양과 의미가 모두 다릅니다. 따라서 새롭게 번역해야 합니다. </reasoning>
# <translate> This way to the greenhouse. </translate>
# <reasoning>
# [한글 대화] "아가씨께서는 안쪽에서 기다리고 계십니다."는 "The young lady is waiting inside."라는 의미이다. 이는 누군가가 손님을 안내하면서 주최자가 안쪽에서 기다리고 있다는 정보를 전달하는 문장이다. 반면 [1차 영어 번역문] "this is the greenhouse."는 단순히 장소를 소개하는 문장으로, '기다리고 있다'는 정보가 완전히 누락되어 있다. 따라서 정보의 양이 다르며, 의미도 일치하지 않는다. 그러므로 [한글 대화]를 기준으로 새롭게 영어 번역문을 생성해야 한다. 주어는 'The young lady'로 명확히 넣어줘야 한다.
# </reasoning>
# <translate>The young lady is waiting inside.</translate>
# <translate>Wow, she really is a glamorous beauty.</translate>
# <reasoning>
# [한글 대화]는 "이런 사람이 시그렌에게 달려들었단 말이지."로, 화자가 상대 인물의 외모나 분위기를 보고 놀라며 "이런 사람이"라는 표현을 통해 예상 밖이라는 뉘앙스를 담고 있다. 또한 "달려들었다"는 표현은 단순히 접근했다는 의미보다 더 적극적이고 공격적인 느낌을 준다.
#
# 반면 [1차 영어 번역문] "she’s the one who threw herself at siegren."은 "그녀가 시그렌에게 달려든 사람이다"라는 의미로, 주어가 명확히 있고, "threw herself at"이라는 표현은 적극적으로 구애했다는 의미를 담고 있어 원문의 "달려들었다"와 유사한 뉘앙스를 전달하고 있다.
#
# 그러나 "이런 사람이"라는 감탄과 놀람의 뉘앙스는 영어 번역문에 반영되어 있지 않다. 즉, [1차 영어 번역문]은 단순한 사실 전달에 그치고 있으며, 원문의 감정적 반응이나 놀람의 뉘앙스가 누락되어 정보의 양이 다르다.
#
# 따라서 [1차 영어 번역문]은 사용할 수 없으며, [한글 대화]의 의미를 살려 새롭게 번역해야 한다. 주어는 화자이며, 감탄과 놀람의 뉘앙스를 담아야 한다.
# </reasoning>
# <translate>I can't believe someone like her threw herself at Siegren. </translate>
# <translate>Please, have a seat.</translate>
# <translate>Yes, thank you. </translate>
# <translate>These young ladies are from nearby territories. </translate>
# <reasoning> [한글 대화]는 "명성이 자자한 두 분을 만나서 영광이에요."로, '명성이 자자한'이라는 수식어가 포함되어 있습니다. 그러나 [1차 영어 번역문] "it’s an honor to meet you both."는 단순히 "두 분을 만나서 영광이에요"라는 의미만 담고 있으며, '명성이 자자한'이라는 정보가 누락되어 있습니다. 따라서 정보의 양이 다르므로 [1차 영어 번역문]은 사용할 수 없습니다. 주어는 생략되어 있지만, 영어 번역에서는 이를 보완해 "It is an honor to meet both of you, who are so well-known."과 같이 표현할 수 있습니다. </reasoning>
# <translate>It’s an honor to meet both of you, who are so well-known. </translate>
# <reasoning>
# [한글 대화] "잘 부탁해요."는 한국어에서 상대방에게 예의를 갖추며 앞으로 잘 지내보자는 의미로 자주 사용되는 표현이다. 이는 단순한 첫 만남의 인사인 "Pleased to meet you."와는 의미가 다르다. "Pleased to meet you."는 처음 만났을 때의 인사말로, 상대방을 만나게 되어 기쁘다는 의미에 초점이 있다. 반면 "잘 부탁해요."는 앞으로의 관계에 대한 기대와 협조를 부탁하는 의미가 담겨 있다. 따라서 정보의 양과 의미가 일치하지 않으므로, [1차 영어 번역문]은 사용할 수 없다. 이 대사는 평서문이며 주어가 없으므로, 적절한 주어(I)를 추가하여 번역해야 한다.
# </reasoning>
# <translate>I look forward to getting along with you.</translate>
# <reasoning> [한글 대화] "뭐지?"는 상황에 대한 의문이나 이상함을 느낄 때 쓰는 표현으로, 영어로는 "What is this?" 또는 "What's going on?" 등으로 번역될 수 있다. 하지만 [1차 영어 번역문] "what’s this?"는 물리적인 사물에 대한 질문처럼 들릴 수 있다. 예를 들어, 어떤 물건을 보고 "이게 뭐지?"라고 할 때 쓰는 표현이다. 반면, [한글 대화]의 "뭐지?"는 주변 사람들의 시선이나 분위기에 대한 의문을 표현하는 맥락이므로, 단순히 "What's this?"보다는 "What's going on?"이나 "What's with this?"처럼 상황에 대한 의문을 나타내는 표현이 더 적절하다. 따라서 의미가 일치하지 않으므로 새로 번역해야 한다. 주어는 생략되어 있지만, 영어에서는 "What is going on?"처럼 주어를 포함시켜야 한다. </reasoning>
# <translate> What's going on? </translate>
# <reasoning>원문의 [한글 대화]는 "헤일론 영애는 북부에 있었다면서요."로, 여기서 주어는 "헤일론 영애"이며, 그녀가 북부에 있었다는 사실을 확인하는 의문문이다. 반면 [1차 영어 번역문]은 "I heard you were in the north, lady fiona."로 번역되어 있는데, 여기서는 "you"라는 2인칭 주어를 사용하여 직접 피오나에게 말하는 형태이다. 하지만 원문의 "헤일론 영애"가 피오나를 지칭하는 것인지 명확하지 않다. 그러나 전체 맥락을 보면, 피오나가 사생아이며 북부에 있었던 인물로 보이고, 이후 대화에서 그녀가 직접 북부에 있었다고 답변하는 것으로 보아 "헤일론 영애"는 피오나를 지칭하는 것이 맞다. 따라서 "you"를 사용하는 것은 적절하다. 정보의 양도 동일하며 의미도 일치한다. </reasoning>
# <translate>I heard you were in the north, Lady Fiona. </translate>
# <translate>That's right. </translate>
# <reasoning>
# [한글 대화] "힘들지는 않았나요?"는 존댓말로, 상대방의 안부나 경험에 대해 공손하게 묻는 표현이다.
# [1차 영어 번역문] "wasn’t it difficult?"는 문법적으로는 맞지만, 주어가 명확하지 않다.
# 웹툰 번역에서는 주어가 생략된 경우라도 영어에서는 명확히 넣어줘야 하므로, "Wasn't it difficult?"는 "그것은 힘들지 않았나요?"라는 의미가 된다.
# 하지만 원문의 의미는 "당신은 힘들지 않았나요?"로, 사람을 주어로 하는 것이 맞다.
# 따라서 정보의 양이 다르며, 주어를 명확히 포함한 문장으로 재번역해야 한다.
# </reasoning>
# <translate> Wasn't it difficult for you? </translate>
# <translate>It's just like any other place where people live. </translate>
# <translate>Wait, that rumor made it all the way here?!</translate>
# <translate>Yes, that's true.</translate>
# <translate>I am an illegitimate child. </translate>
# <reasoning>
# [한글 대화] "정확히 알고 계시네요."는 상대방이 말한 정보가 정확하다는 것을 인정하고, 그 사실을 알고 있다는 것에 감탄하거나 놀람을 표현하는 말이다. 주어는 생략되어 있지만, 영어로 번역할 때는 "You"를 주어로 넣어야 한다.
#
# [1차 영어 번역문] "you know exactly what you’re talking about."는 "당신이 말하는 것에 대해 정확히 알고 있다"는 의미로, 일반적으로 상대방이 어떤 주제에 대해 잘 알고 있음을 칭찬하거나 인정할 때 쓰인다. 하지만 이 표현은 다소 구어체이며, "정확히 알고 계시네요"라는 말의 정중하고 감탄 섞인 뉘앙스를 충분히 담고 있지 않다. 또한 "what you're talking about"는 특정 주제에 대한 언급이 있어야 자연스럽지만, 원문에서는 그런 맥락이 없다.
#
# 따라서 원문의 정중한 어조와 감탄의 의미를 살리기 위해 새롭게 번역해야 한다.
# </reasoning>
# <translate> You are very well-informed. </translate>
# <reasoning> [한글 대화]는 "웃어?"로, 이는 상대방이 웃고 있는 것을 보고 화자(피오나)가 의문을 제기하는 짧은 문장이다. 주어는 생략되어 있지만, 영어로 번역할 때는 주어를 명확히 해야 하므로 "Are you smiling?"이 자연스럽다. 반면 [1차 영어 번역문]은 "she’s smiling?"으로, 이는 제3자에 대한 질문이다. 하지만 원문에서는 제3자가 아닌, 대화 상대에게 직접 묻는 말이므로 주어가 다르다. 따라서 [1차 영어 번역문]은 원문의 의미와 일치하지 않으며, 정보의 양도 다르다. 그러므로 새롭게 번역해야 한다. </reasoning>
# <translate> Are you smiling? </translate>
