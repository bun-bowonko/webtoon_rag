# %%
import re
from langchain_community.vectorstores import FAISS
from langchain.docstore.document import Document
import bs4
import ssl
import urllib3
import pandas as pd
import faiss
import os
from langchain.embeddings import HuggingFaceEmbeddings
import torch
import gc

def instruct_structure(prompt):
    input_text, output_text = prompt.split('### target')
    input_text = input_text.replace('### glossaries', '### glossary').replace('\n* ', '\n• ')
    input_text = re.sub(r"\[[^\]]+\] ", "[UNK] ", input_text)
    return input_text


project_id = "prod-ai-project"

from google.cloud import bigquery
client = bigquery.Client(project=project_id)
sql = """select series_id, episode_id, org_input_text, org_output_text, prompt 
        from webtoon_translation.structured_240820_ep_line
        where data_split = 'romance_valid'"""
df = client.query(sql).result().to_dataframe()
from tqdm import tqdm
tqdm.pandas()
df['prompt'] = df['prompt'].progress_apply(lambda x: instruct_structure(x))
# Out:
# /home/bun.2/.cache/pypoetry/virtualenvs/poetry-env-eDEwtiIl-py3.10/lib/python3.10/site-packages/google/cloud/bigquery/table.py:1820: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 74/74 [00:00<00:00, 19380.49it/s]

# %%
data_idx = 58
data = df['prompt'][data_idx]
example = data.split("### source")[1].strip()
#print(example)

# %%
from openai import OpenAI
GPT_FINE_TUNING_MODEL="ft:gpt-4o-2024-08-06:kakaoent:webtoon-sft-250225:B4j839q0"
openai_client = OpenAI(
    api_key='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')
#example_li = example.split('\n')

GPT_BASE_MODEL = "chatgpt-4o-latest"

# %%
print(data)
# Out:
# ### glossary
# • 시그렌 (M): siegren
# • 유니스 (F): eunice
# • 피오나 (F): fiona
# • 마법사: mage / sorcerer
# • 하녀: maid
#
# ### source
# 000	[UNK] 『금일 오후,
# 001	[UNK] 온실에서 있을 티 파티에 영애를 초대하고 싶습니다.』
# 002	[UNK] 『시간이 나신다면 꼭 참석해 주세요,
# 003	[UNK] 헤더 아덴 자작 영애.』
# 004	[UNK] 이 사람,
# 005	[UNK] 어제 시그렌이랑 일이 있었던 그 영애 아냐?
# 006	[UNK] 그런 사람이 여는 티파티에 내가 가도 되는 건가?
# 007	[UNK] 내가 괜히 신경 쓸 만한 이유는 없지.
# 008	[UNK] 잘못한 건 그쪽이고.
# 009	[UNK] 어쩌면 티파티에서 유니스를 만날 수 있을지도 모르니까.
# 010	[UNK] 기쁜 마음으로 응하겠다고 전해줘.
# 011	[UNK] 유니스 영애.
# 012	[UNK] 피오나 영애…!
# 013	[UNK] 유니스 영애도 초대받은 건가요?
# 014	[UNK] 네.
# 015	[UNK] 피오나 영애와는 같은 일행임에도 계속 얼굴을 볼 수가 없었네요.
# 016	[UNK] 전 말을 타고 있었거든요.
# 017	[UNK] …그래도 마차에도 와 주세요.
# 018	[UNK] 혼자서는 심심해서….
# 019	[UNK] 주변에 온통 기사랑 병사라서 쓸쓸했나 봐.
# 020	[UNK] 어서 오십시오.
# 021	[UNK] 이쪽이 온실입니다.
# 022	[UNK] 아가씨께서는 안쪽에서 기다리고 계십니다.
# 023	[UNK] 어머나,
# 024	[UNK] 피오나 영애,
# 025	[UNK] 유니스 영애…
# 026	[UNK] 초대에 응해주셔서 감사해요.
# 027	[UNK] 기다리고 있었답니다.
# 028	[UNK] 와, 역시 화려한 미인이야.
# 029	[UNK] 이런 사람이 시그렌에게 달려들었단 말이지.
# 030	[UNK] 자, 어서 앉으세요.
# 031	[UNK] 네, 고마워요.
# 032	[UNK] 이쪽은 근처 영지의 영애들이에요.
# 033	[UNK] 명성이 자자한 두 분을 만나서 영광이에요.
# 034	[UNK] 네…
# 035	[UNK] 잘 부탁해요.
# 036	[UNK] 뭐지?
# 037	[UNK] 묘하게 시선이 불온한 것 같은 느낌이….
# 038	[UNK] 헤일론 영애는 북부에 있었다면서요.
# 039	[UNK] 맞아요.
# 040	[UNK] 힘들지는 않았나요?
# 041	[UNK] 거기에는 굉장히 야만적이고 잔혹한 마법사가 산다고 들었는데….
# 042	[UNK] 사람 사는 곳이라 다들 비슷하답니다.
# 043	[UNK] 아니, 이 소문 여기까지 돌았냐!
# 044	[UNK] 소문 이야기가 나와서 말인데요,
# 045	[UNK] 듣자 하니…
# 046	[UNK] 영애의 핏줄은 조금 특별하다면서요?
# 047	[UNK] 본래는 헤일론 쪽이 아니라고 들었어요.
# 048	[UNK] 제가 알기로는,
# 049	[UNK] 사생아라던데.
# 050	[UNK] 네, 맞는 말이에요.
# 051	[UNK] 전 사생아입니다.
# 052	[UNK] 정확히 알고 계시네요.
# 053	[UNK] 웃어?
# 054	[UNK] 게다가 그 본가는…
# 055	[UNK] 네. 마약 사업 혐의로 재산을 몰수당했죠.
# 056	[UNK] 제가 직접 고발한 일이고요.
# 057	[UNK] 세상에, 저라면 도저히 못할 거예요.
# 058	[UNK] 무슨 이유에서든 가족을 자기 손으로 배신하는 건…
# 059	[UNK] 짐승이나 할 짓이죠.
# 060	[UNK] 자, 잠깐만요!
# 061	[UNK] 피오나 영애…
# 062	[UNK] 그래서,
# 063	[UNK] 하고 싶은 말이 뭔가요?
# 064	[UNK] 적당히 하라는 소리예요!
# 065	[UNK] 운 좋게 양녀가 되었다고 해도,
# 066	[UNK] 귀족 영애라면 정도를 지켜야죠.
# 067	[UNK] …해서, …
# 068	[UNK] 영애도……
# 069	[UNK] 시그렌.
# 070	[UNK] 피오나 영애 왜 딴 곳을 보시죠.
# 071	[UNK] 지금 제가 말하고 있는 게 안 보이나요?
# 072	[UNK] 아직 할 말이 더 있답니다.
# 073	[UNK] 영애,
# 074	[UNK] 남의 저택에서 신세를 지고 있는 와중에 전하께 꼬리를 치셨죠?
# 075	[UNK] 제 하녀가 말해주었단 말이에요. 어젯밤에-
# 076	[UNK] 잠깐.
# 077	[UNK] 아덴 영애, 말이 심하세요!
# 078	[UNK] 심하긴 뭐가 심해요.
# 079	[UNK] 저는 그저 사실을 말하는 것뿐…
# 080	[UNK] 꺄,
# 081	[UNK] 꺄아아악!
# 082	[UNK] 영애의 말은 다 맞아요.
# 083	[UNK] 전 사생아고, 제가 태어난 가문도 직접 부수었죠.
# 084	[UNK] 하지만 똑똑한 아덴 영애가 하나 파악하지 못한 게 있네요.
# 085	[UNK] 저는 그 덕분에 권력과 힘,
# 086	[UNK] 두 개 다 가지고 있답니다.
# 087	[UNK] 지금 이 자리에서 제가 영애의 머리카락을 불태워도
# 088	[UNK] 아덴 자작님은 제 아버지께 항의서 몇 장 보내는 게 고작일 거란 뜻이죠.
# 089	[UNK] 망아지처럼 구는 것도 상대를 보면서 하세요.
# 090	[UNK] 그러다 목 잘려요.
# 091	[UNK] 그리고,
# 092	[UNK] 화,
# 093	[UNK] 황자 전하….
# 094	[UNK] 티파티가 꽤나 즐거워 보이는군.
# 095	[UNK] 헤더 아덴 영애.
# 096	[UNK] 그, 그게…
# 097	[UNK] 어제 그런 일이 있었으니 고개를 못 들겠지.
# 098	[UNK] 마지막으로 충고 하나 할게요.
# 099	[UNK] 남의 남자 탐내지 마세요.
# 100	[UNK] 이건 지금 내 거거든.

# %%
SYSTEM_PROMPT = {
            "role": "system",
            "content": [
                {
                    "type": "text",
                    "text": """You're an expert translator who translates Korean webtoon in English. Make sure the number of target sentences matches the number of source sentences. The result should be TSV formatted. 
            • Find a balance between staying true to the Korean meaning and keeping a natural flow. Don't be afraid to add to the text. Embellish it. 
            • Avoid translating word-for-word. Keep the general feeling and translate the text accordingly. 
            • Translate with an American audience in mind. This means easy-to-read, conversational English.""",
                }
            ],
        }

chat_completion = openai_client.beta.chat.completions.parse(
    model= GPT_FINE_TUNING_MODEL,
    messages = [
        SYSTEM_PROMPT,
        {
            "role":"user",
            "content" : [{"type" : "text",
                          "text" : data
                        }],
        }
    ],
    temperature= 0.2,
    top_p = 0.8
)
response = chat_completion.choices[0].message.content

# %%
print(response)
# Out:
# 000	“I would like to invite you, my lady,
# 001	to a tea party in the greenhouse this afternoon.”
# 002	“Please attend if you have time,
# 003	lady heather adens.”
# 004	isn’t this...
# 005	...the lady from yesterday who was with siegren?
# 006	is it okay for me to go to a tea party hosted by her?
# 007	well, I don’t see why I shouldn’t.
# 008	she’s the one who did something wrong.
# 009	and I might be able to see eunice there.
# 010	tell her I’ll be happy to attend,
# 011	lady eunice.
# 012	lady fiona...!
# 013	were you invited as well?
# 014	yes.
# 015	we’re traveling together, but I haven’t been able to see you.
# 016	I’ve been riding a horse.
# 017	please come to the carriage sometimes...
# 018	it’s boring being alone...
# 019	she must have been lonely because she was surrounded by knights and soldiers.
# 020	welcome.
# 021	this way to the greenhouse.
# 022	my lady is waiting inside.
# 023	oh my,
# 024	lady fiona,
# 025	lady eunice...
# 026	thank you for accepting my invitation.
# 027	I’ve been waiting for you.
# 028	wow, she’s really pretty.
# 029	she’s the one who tried to get with siegren.
# 030	please, have a seat.
# 031	thank you.
# 032	these are ladies from nearby lands.
# 033	it’s an honor to meet you both.
# 034	yes...
# 035	it’s nice to meet you.
# 036	what’s this?
# 037	I feel like they’re looking at me strangely...
# 038	I heard you were in the north, lady fiona.
# 039	yes, I was.
# 040	wasn’t it hard?
# 041	I heard a very barbaric and cruel sorcerer lives there...
# 042	it’s just like any other place where people live.
# 043	wait, that rumor reached all the way here?!
# 044	speaking of rumors,
# 045	I heard...
# 046	...that you have a special bloodline.
# 047	I heard you’re not originally from house hylon.
# 048	from what I know,
# 049	you’re an illegitimate child.
# 050	yes, you’re right.
# 051	I am an illegitimate child.
# 052	you know exactly who I am.
# 053	she’s smiling?
# 054	and your original family...
# 055	yes, their wealth was confiscated for drug trafficking.
# 056	I was the one who reported them.
# 057	my goodness, I would never be able to do that.
# 058	betraying your family with your own hands for whatever reason...
# 059	...is something only a beast would do.
# 060	w-wait!
# 061	lady fiona...
# 062	so,
# 063	what are you trying to say?
# 064	I’m telling you to know your place!
# 065	even if you were lucky enough to be adopted,
# 066	you should know your place as a noble lady.
# 067	so...
# 068	...you should...
# 069	siegren.
# 070	lady fiona, why are you looking elsewhere?
# 071	can’t you see I’m talking to you?
# 072	I’m not done talking.
# 073	my lady,
# 074	you tried to seduce his highness while staying in someone else’s manor, didn’t you?
# 075	my maid told me about last night--
# 076	wait.
# 077	lady heather, you’re going too far!
# 078	what do you mean?
# 079	I’m just stating the facts--
# 080	ah,
# 081	aaah!
# 082	you’re right about everything.
# 083	I’m an illegitimate child, and I destroyed the family I was born into.
# 084	but there’s one thing you didn’t realize, lady heather.
# 085	because of that, I now have both power...
# 086	...and strength.
# 087	that means even if I burn your hair right now,
# 088	the most your father would do is send a few letters of complaint to my father.
# 089	know your place before you start acting like a brat.
# 090	you might lose your head.
# 091	and...
# 092	your...
# 093	your highness...
# 094	it looks like you’re having a lot of fun at this tea party,
# 095	lady heather adens.
# 096	I-I...
# 097	she can’t even look at him after what happened yesterday.
# 098	let me give you one last piece of advice.
# 099	don’t go after someone else’s man.
# 100	he’s mine.

# %%
response_split = response.split('\n')
source = data.split("### source")[1].strip()
glossary = data.split("### source")[0].strip()

# %%
def clean_text(text):
    return text.replace("[UNK] ","") 
#print(clean_text(source))

# %%
kor = clean_text(source)
en = response
input_text = f"[한국어 대화문]\n{kor}\n\n[1차 번역문]\n{en}\n\n[단어집]\n{glossary}"
print(input_text)
# Out:
# [한국어 대화문]
# 000	『금일 오후,
# 001	온실에서 있을 티 파티에 영애를 초대하고 싶습니다.』
# 002	『시간이 나신다면 꼭 참석해 주세요,
# 003	헤더 아덴 자작 영애.』
# 004	이 사람,
# 005	어제 시그렌이랑 일이 있었던 그 영애 아냐?
# 006	그런 사람이 여는 티파티에 내가 가도 되는 건가?
# 007	내가 괜히 신경 쓸 만한 이유는 없지.
# 008	잘못한 건 그쪽이고.
# 009	어쩌면 티파티에서 유니스를 만날 수 있을지도 모르니까.
# 010	기쁜 마음으로 응하겠다고 전해줘.
# 011	유니스 영애.
# 012	피오나 영애…!
# 013	유니스 영애도 초대받은 건가요?
# 014	네.
# 015	피오나 영애와는 같은 일행임에도 계속 얼굴을 볼 수가 없었네요.
# 016	전 말을 타고 있었거든요.
# 017	…그래도 마차에도 와 주세요.
# 018	혼자서는 심심해서….
# 019	주변에 온통 기사랑 병사라서 쓸쓸했나 봐.
# 020	어서 오십시오.
# 021	이쪽이 온실입니다.
# 022	아가씨께서는 안쪽에서 기다리고 계십니다.
# 023	어머나,
# 024	피오나 영애,
# 025	유니스 영애…
# 026	초대에 응해주셔서 감사해요.
# 027	기다리고 있었답니다.
# 028	와, 역시 화려한 미인이야.
# 029	이런 사람이 시그렌에게 달려들었단 말이지.
# 030	자, 어서 앉으세요.
# 031	네, 고마워요.
# 032	이쪽은 근처 영지의 영애들이에요.
# 033	명성이 자자한 두 분을 만나서 영광이에요.
# 034	네…
# 035	잘 부탁해요.
# 036	뭐지?
# 037	묘하게 시선이 불온한 것 같은 느낌이….
# 038	헤일론 영애는 북부에 있었다면서요.
# 039	맞아요.
# 040	힘들지는 않았나요?
# 041	거기에는 굉장히 야만적이고 잔혹한 마법사가 산다고 들었는데….
# 042	사람 사는 곳이라 다들 비슷하답니다.
# 043	아니, 이 소문 여기까지 돌았냐!
# 044	소문 이야기가 나와서 말인데요,
# 045	듣자 하니…
# 046	영애의 핏줄은 조금 특별하다면서요?
# 047	본래는 헤일론 쪽이 아니라고 들었어요.
# 048	제가 알기로는,
# 049	사생아라던데.
# 050	네, 맞는 말이에요.
# 051	전 사생아입니다.
# 052	정확히 알고 계시네요.
# 053	웃어?
# 054	게다가 그 본가는…
# 055	네. 마약 사업 혐의로 재산을 몰수당했죠.
# 056	제가 직접 고발한 일이고요.
# 057	세상에, 저라면 도저히 못할 거예요.
# 058	무슨 이유에서든 가족을 자기 손으로 배신하는 건…
# 059	짐승이나 할 짓이죠.
# 060	자, 잠깐만요!
# 061	피오나 영애…
# 062	그래서,
# 063	하고 싶은 말이 뭔가요?
# 064	적당히 하라는 소리예요!
# 065	운 좋게 양녀가 되었다고 해도,
# 066	귀족 영애라면 정도를 지켜야죠.
# 067	…해서, …
# 068	영애도……
# 069	시그렌.
# 070	피오나 영애 왜 딴 곳을 보시죠.
# 071	지금 제가 말하고 있는 게 안 보이나요?
# 072	아직 할 말이 더 있답니다.
# 073	영애,
# 074	남의 저택에서 신세를 지고 있는 와중에 전하께 꼬리를 치셨죠?
# 075	제 하녀가 말해주었단 말이에요. 어젯밤에-
# 076	잠깐.
# 077	아덴 영애, 말이 심하세요!
# 078	심하긴 뭐가 심해요.
# 079	저는 그저 사실을 말하는 것뿐…
# 080	꺄,
# 081	꺄아아악!
# 082	영애의 말은 다 맞아요.
# 083	전 사생아고, 제가 태어난 가문도 직접 부수었죠.
# 084	하지만 똑똑한 아덴 영애가 하나 파악하지 못한 게 있네요.
# 085	저는 그 덕분에 권력과 힘,
# 086	두 개 다 가지고 있답니다.
# 087	지금 이 자리에서 제가 영애의 머리카락을 불태워도
# 088	아덴 자작님은 제 아버지께 항의서 몇 장 보내는 게 고작일 거란 뜻이죠.
# 089	망아지처럼 구는 것도 상대를 보면서 하세요.
# 090	그러다 목 잘려요.
# 091	그리고,
# 092	화,
# 093	황자 전하….
# 094	티파티가 꽤나 즐거워 보이는군.
# 095	헤더 아덴 영애.
# 096	그, 그게…
# 097	어제 그런 일이 있었으니 고개를 못 들겠지.
# 098	마지막으로 충고 하나 할게요.
# 099	남의 남자 탐내지 마세요.
# 100	이건 지금 내 거거든.
#
# [1차 번역문]
# 000	“I would like to invite you, my lady,
# 001	to a tea party in the greenhouse this afternoon.”
# 002	“Please attend if you have time,
# 003	lady heather adens.”
# 004	isn’t this...
# 005	...the lady from yesterday who was with siegren?
# 006	is it okay for me to go to a tea party hosted by her?
# 007	well, I don’t see why I shouldn’t.
# 008	she’s the one who did something wrong.
# 009	and I might be able to see eunice there.
# 010	tell her I’ll be happy to attend,
# 011	lady eunice.
# 012	lady fiona...!
# 013	were you invited as well?
# 014	yes.
# 015	we’re traveling together, but I haven’t been able to see you.
# 016	I’ve been riding a horse.
# 017	please come to the carriage sometimes...
# 018	it’s boring being alone...
# 019	she must have been lonely because she was surrounded by knights and soldiers.
# 020	welcome.
# 021	this way to the greenhouse.
# 022	my lady is waiting inside.
# 023	oh my,
# 024	lady fiona,
# 025	lady eunice...
# 026	thank you for accepting my invitation.
# 027	I’ve been waiting for you.
# 028	wow, she’s really pretty.
# 029	she’s the one who tried to get with siegren.
# 030	please, have a seat.
# 031	thank you.
# 032	these are ladies from nearby lands.
# 033	it’s an honor to meet you both.
# 034	yes...
# 035	it’s nice to meet you.
# 036	what’s this?
# 037	I feel like they’re looking at me strangely...
# 038	I heard you were in the north, lady fiona.
# 039	yes, I was.
# 040	wasn’t it hard?
# 041	I heard a very barbaric and cruel sorcerer lives there...
# 042	it’s just like any other place where people live.
# 043	wait, that rumor reached all the way here?!
# 044	speaking of rumors,
# 045	I heard...
# 046	...that you have a special bloodline.
# 047	I heard you’re not originally from house hylon.
# 048	from what I know,
# 049	you’re an illegitimate child.
# 050	yes, you’re right.
# 051	I am an illegitimate child.
# 052	you know exactly who I am.
# 053	she’s smiling?
# 054	and your original family...
# 055	yes, their wealth was confiscated for drug trafficking.
# 056	I was the one who reported them.
# 057	my goodness, I would never be able to do that.
# 058	betraying your family with your own hands for whatever reason...
# 059	...is something only a beast would do.
# 060	w-wait!
# 061	lady fiona...
# 062	so,
# 063	what are you trying to say?
# 064	I’m telling you to know your place!
# 065	even if you were lucky enough to be adopted,
# 066	you should know your place as a noble lady.
# 067	so...
# 068	...you should...
# 069	siegren.
# 070	lady fiona, why are you looking elsewhere?
# 071	can’t you see I’m talking to you?
# 072	I’m not done talking.
# 073	my lady,
# 074	you tried to seduce his highness while staying in someone else’s manor, didn’t you?
# 075	my maid told me about last night--
# 076	wait.
# 077	lady heather, you’re going too far!
# 078	what do you mean?
# 079	I’m just stating the facts--
# 080	ah,
# 081	aaah!
# 082	you’re right about everything.
# 083	I’m an illegitimate child, and I destroyed the family I was born into.
# 084	but there’s one thing you didn’t realize, lady heather.
# 085	because of that, I now have both power...
# 086	...and strength.
# 087	that means even if I burn your hair right now,
# 088	the most your father would do is send a few letters of complaint to my father.
# 089	know your place before you start acting like a brat.
# 090	you might lose your head.
# 091	and...
# 092	your...
# 093	your highness...
# 094	it looks like you’re having a lot of fun at this tea party,
# 095	lady heather adens.
# 096	I-I...
# 097	she can’t even look at him after what happened yesterday.
# 098	let me give you one last piece of advice.
# 099	don’t go after someone else’s man.
# 100	he’s mine.
#
# [단어집]
# ### glossary
# • 시그렌 (M): siegren
# • 유니스 (F): eunice
# • 피오나 (F): fiona
# • 마법사: mage / sorcerer
# • 하녀: maid

# %%
GPT_BASE_MODEL = "chatgpt-4o-latest"
SYSTEM_REVIEW_PROMPT = {
            "role": "system",
            "content": [
                {
                    "type": "text",
                    "text": "너는 [한국어 대화문] 내의 연결된 대사들을 분석하고 이를 [대사 문단]으로 정의한 뒤, [1차 번역문] 상에서 잘 번역되어 있는지 확인하는 태스크를 수행할거야. \
                    그리고 만약 [1차 번역문]이 잘못된 경우, 이를 수정해서 재생성하는 태스크를 수행할 거야. \
                    먼저 맥락을 이해하기 위해 한 회차의 모든 [한국어 대화문]이 주어지고, \
                    이를 1차 번역한 [1차 번역문]이 주어질거야. \
                    각 대사에는 번호가 붙어 있을 것이고, 같은 번호는 같은 문장을 지칭해. 즉 [한국어 대화문]의 005번 대사를 번역한 것은 [1차 번역문]의 005번 대사라고 생각하면 돼.\
                    지금부터 너는 [한국어 대화문]에서 이어진 대사를 구별해내고, 이어진 대사들이 동일한 한 명의 화자가 발화한 것이라면, [1차 번역문] 상에서 올바르게 번역되어 있는지 검수한 후, \
                    올바르게 번역되지 않았다면 [단어집]을 참고해서 새롭게 번역하고, \
                    올바르게 번역 되어있다면 그대로 생성할거야.\n\
                    먼저 배경지식을 알려주자면 웹툰에서 '...','…'은 이전 대사나 이후 대사와의 연결성을 의미할 가능성이 커. 100%는 아니야. \
                    다시 말해서 '...','…'으로 시작하면 이전 대사와 현재 대사가 연결되어 있을 가능성이 크고, \
                    '...','…'으로 끝나면 다음 대사와 현재 대사가 연결되어 있을 가능성이 커.\n\
                    태스크를 올바르게 수행하기 위해서 너는 첫 번째로 [대사 문단]을 찾아야해. \
                    [대사 문단]이란 간단히 말해서 [한국어 대화문] 내에서 이전 혹은 다음 대사들과 연결했을 때 더 자연스러운 대사들을 결합한 것을 의미해. \
                    하지만 조건이 있어. 1)연속되는 대사가 최대 한 개를 제외하고 \
                    모두 불완전하고(모두 불완전한 대사인 경우, 2개 이상의 불완전한 대사+불완전한 대사가 필요로 하는 완전한 문장 최대 1개인 경우),\
                    2)화자가 한 명으로 동일해야하고, 3)결합된 문장이 한 문장이어야해. \n\
                    예를 들어 6개의 대사로 구성된 [한국어 대화문]과 [1차 번역문]이 있다고 가정해볼게. \n\
                    '[한국어 대화문]\n000\t어제,\n001\t나는 푸른...\n002\t하늘을 보았다.\n003\t어땠어?\n004\t정말,\n005...아름다웠어.\n' \
                    라는 [한국어 대화문]이 있다면 [대사 문단]은 [(000~002),(004~005)]로 구성될 수 있어.\
                    왜냐하면 000부터 002까지의 대사는 연결된 대사처럼 보이고 1)각 대사가 '모두' 불완전하고 2)웹툰 내에서 동일한 한 명의 등장인물이 연속적으로 발화한 것으로 보이며, \
                    3)세 개의 대사를 결합했을 때 딱 한 문장으로 결합돼.\n\
                    ***important*** 여기서 개념을 하나 설명할게. 너가 수행하는 태스크에서 '불완전한 대사'를 명확히 설명해줄게. \
                    '(1)000\t당신!\n001\t밥\n002\t먹었어?\n','(2)000\t너,\n001\t밥 먹었어?\n002\t난 이제 먹어야하는데...\n003\t뭐 먹었어?\n' 와 같은 예시가 주어졌다고 가정해보자.\
                    두 가지 예시 모두 '(1)당신 밥 먹었어?','(2)너 밥 먹었어? 난 이제 먹어야하는데... 뭐 먹었어?' 와 같이 결합했을 때 \
                    (1)과 (2)모두 동일한 한 명의 화자가 연속적으로 발화하는 대사들이지만 (1)의 '당신!'과 (2)의 '난 이제 먹어야하는데...', '뭐 먹었어?' 같은 각각의 대사는 하나의 독립적인 완전한 대사로써, \
                    (1) 전체를 결합하면 완전한 대사 2개('당신!','밥 먹었어?')가 나오고, (2) 전체를 결합하면 완전한 대사 3개가 결합되어, 3문장의 대사가 나와. ('너, 밥 먹었어?', '난 이제 먹어야하는데...', '뭐 먹었어?') \
                    [대사 문단]에 넣기 위해서는 대사를 모두 결합했을 때 딱 한 문장의 대사가 나와야해.\n\
                    반면 (1)의 '밥','먹었어?'와 (2)의 '너,','밥 먹었어?'는 각각 하나의 독립적인 대사로 활용했을 때 불완전한 대사로 보기 때문에 이전 혹은 이후 대사와 결합해야해.\
                    좀 더 구체적으로 설명하자면 (1)의 '당신!'은 독립적으로 사용가능한 완전한 대사로 볼 수 있지만, 뒤에 있는 대사 '밥'과 '먹었어?'가 불완전한 대사이고, \
                    '밥 먹었어?' 라고 연결했을 때 한 문장으로 볼 수 있으므로, \
                    불완전한 두 개의 대사인 '밥'과 '먹었어?'를 결합하여 [대사 문단]의 한 원소로 넣는거야.\
                    즉 불완전한 대사 여러 개를 결합하면 한 문장이 될 가능성이 있지. \
                    그리고 (2)의 001 번 째 대사인 '밥 먹었어?'같은 경우는 독립적으로 사용가능한 완전한 대사로 볼 수 있지만, 앞 대사가 '너,'라는 뒤에 있는 대사를 필요로 하는 불완전한 대사이고, \
                    '너, 밥 먹었어?'라고 연결했을 때 한 문장으로 볼 수 있으므로, 불완전한 대사인 '너,'와 완전한 대사인 '밥 먹었어?'를 결합하여 [대사 문단]의 한 원소로 넣는거야. \
                    즉 불완전한 대사와 불완전한 대사가 필요로 하는 완전한 대사를 결합해도 한 문장이 될 가능성이 있지. \
                    그리고 불완전한 대사라는 걸 증명할 수 있는 근거가, 불완전한 대사들은 여러 개를 연속적으로 결합해도 최대 한 문장의 대사가 나오게 돼. \
                    즉 웹툰의 대사를 생각했을 떄 (1)의 모든 대사와 (2)의 일부 대사처럼 한 문장의 대사가 (여러 개의 불완전한 대사+최대 한 개의 완전한 대사)로 나뉜 경우만 [대사 문단]의 한 원소가 될 수 있고, \
                    (2)의 '난 이제 먹어야하는데...', '뭐 먹었어?'처럼 완전한 대사 둘은 결합되면 두 문장이 되기 때문에, [대사 문단]의 한 원소가 될 수 없다는 뜻이야.\
                    ***important*** 쉽게 생각하면 '두 개 이상의 불완전한 대사'들 혹은 '한 개 이상의 불완전한 대사와 불완전한 대사가 필요로하는 한 개의 완전한 대사'가 결합되어 한 문장을 이룬다면 [대사 문단]의 한 원소가 될 수 있지만, \
                    '두 개 이상의 불완전한 대사'와 '불완전한 대사가 필요로 하지 않는 완전한 대사'가 결합되거나, \
                    완전한 대사 둘 이상이 결합되면 두 문장 이상이 되기 때문에 [대사 문단]의 한 원소가 될 수 없어. \n\
                    다시 돌아가서, [대사 문단]을 찾을 때는 1)연결된 대사들을 찾고, 2)대사들이 동일한 한 명의 화자가 연속적으로 발화한 대사인지를 엄격하게 검수한 후에, \
                    3)각 대사들을 결합했을 때 한 문장이 된다면 해당 대사들을 묶어서 [대사 문단]의 한 원소로 정의하면 돼.\
                    명심해야할 건 아무리 하나의 완전한 대사가 불완전한 대사를 보완해준다고 하더라도, 결합했을 때 2문장 이상이 되면 [대사 문단]에 포함될 수 없어.\n\
                    그리고 003은 앞과 뒤 화자와는 다른 화자임이 분명하고, 그 자체로 완전한 문장이며, 앞 뒤에 연결할 불완전한 대사가 없기 때문에 [대사 문단]의 한 원소로 포함될 수 없어. \
                    좀 더 다른 예를 들어 설명하자면 '(3)100\t너 말이야\n101\t뭐가?\n102\t좀 이상한 거 같애\n'라는 대사가 주어졌을 때 \
                    100 번 째 대사와 102 번 째 대사의 화자는 같은 것으로 판단되지만 중간에 101 번 째 대사는 다른 화자인 것으로 판단되기 때문에, 3가지의 대사는 연결된 대사가 아니고, 결합돼서는 안 돼. 즉 [대사 문단]의 한 원소로 포함될 수 없어.\n\
                    그리고 004~005 또한 동일한 한 명의 화자가 발화하고 있는 것으로 판단되고, 각 대사가 불완전하고, 각 대사를 결합하면 딱 한 문장이 되기 때문에, 결합하여 [대사 문단]의 한 원소로 포함시켜.\
                    ***important*** 특히 대사의 화자가 동일한지 판단할 때는 발화자에 대응하는 명사를 유심히 봐야하고, \
                    웹툰 내 대사는 발화자가 생략된 경우가 많기 때문에 이를 잘 유추해서 동일한 화자가 맞는지 잘 판단해야해.\n\
                    그 다음에 [한국어 대화문]에 속한 모든 대사에 대해서 [대사 문단]의 각 원소를 찾고 실제 하나의 [대사 문단]으로 결합해. \
                    위 예시대로라면 [(000~002,'어제 나는 푸른 하늘을 보았다.'),(004~005,'정말 아름다웠어.')] 라는 결과가 나올거야. \
                    [대사 문단]의 한 원소에 대한 각 대사들을 하나의 문단으로 결합할 때는 '...','…', ','와 같은 연결을 위한 특수 문자는 제거해.\n\
                    그리고 이제 함께 주어진 [1차 번역문]이 다음과 같다고 해볼게.\n\
                    '[1차 번역문]\n000\tyesterday,\n001\tI...\n002\tsaw the blue sky.\n003\thow was it?\n004\tit was\n005really dark.\n'\
                    그랬을 때 [대사 문단]에 쓰여진 것과 동일하게 결합해. 위 예에서는 [한국어 대화문] 상에서 (000~002), 그리고 (004~005)가 각각 결합되었기 때문에 \
                    동일하게 [1차 번역문] 상에서도 (000~002)와 (004~005)를 결합하고 (연결을 위한 특수 문자는 제거) 이전 결과물에 붙여. \
                    그렇게 하면, 다음과 같은 결과물을 얻을 수 있어.\n \
                    [((000~002),'어제 나는 푸른 하늘을 보았다.','yesterday I saw the blue sky.'),\
                    ((004~005),'정말 아름다웠어.','it was really dark.')]\n \
                    그 다음 리스트 내 각 원소의 한글 문장과 영어 문장의 의미를 비교해.\
                    만약 '어제 나는 푸른 하늘을 보았다.'와 'yesterday I saw the blue sky.'처럼 두 문장의 의미가 동일하다면 \
                    영어 문장을 해당 문장을 구성한 대사의 개수 n개(해당 예에서는 000,001,002:3개)로 나누고, 나뉘는 부분 양 쪽에 '...'를 삽입해. \n\
                    ***important*** 단, 나눌 때 해당 문장을 구성하는 대사 개수 n개로만 나눠야 하며, 나누는 개수를 유지하면서 최대한 웹툰 독자가 읽기에 편하도록 나누고, 나눈 이후의 각 요소는 적어도 하나의 단어를 포함하고 있어야 해.\n\
                    예를 들어 'yesterday', 'I saw', 'the blue sky.'로 나누는게 웹툰 대사상 적합하다고 생각한다면, \n\
                    '000\tyesterday...\n001\t...I saw...\n002\t...the blue sky.\n' 를 생성하는거야. \n\
                    그리고 이어서 003은 [대사 문단]에 속하지 않기 때문에 [1차 번역문]의 003번을 똑같이 생성해. 그러면 다음과 같이 될거야.\n \
                    '003\thow was it?\n'\n\
                    그 다음 004번과 005번이 [대사 문단]의 한 원소이기 때문에 '정말 아름다웠어.'와 'it was really dark.'의 의미를 비교하고, \
                    둘의 의미가 다른 경우에는 영어 문장을 무시하고, 한글 문장을 번역해. \
                    여기서는 'it was really dark.'를 무시하고, '정말 아름다웠어.'를 번역하면 돼. 대신 재번역할 때 참고해야할 고유명사가 있을 수도 있으니 [단어집]을 참고해서 번역해. \
                    그럼 'it was really beautiful.'을 얻을 수 있고, 이를 똑같이 [대사 문단]을 구성하는 대사 개수인 n개(해당 예에서는 004,005:2개)로 나누고, 나뉘는 부분 양 쪽에 '...'를 삽입해. \n\
                    ***important*** 단, 나눌 때 해당 문장을 구성하는 대사 개수 n개로만 나눠야 하며, 나누는 개수를 유지하면서 최대한 웹툰 독자가 읽기 편하도록 나누고, 나눈 이후의 각 요소는 적어도 하나의 단어를 포함하고 있어야 해.\n\
                    예를 들어 'it was', 'really beautiful'로 나누는게 웹툰 대사상 적합하다고 생각한다면, \
                    '004\tit was...\n005\t...really beautiful.\n'를 생성하는거야. \
                    위 예의 최종적인 출력형태는 다음과 같아. \n\
                    <translate>\n000\tyesterday...\n001\t...I saw...\n002\t...the blue sky.\n003\thow was it?\n004\tit was...\n005\t...really beautiful.\n</translate>\
                    그리고 만약 추론이 필요하다면 <reasoning>으로 시작해서 추론 내용을 입력하고 </reasoning>으로 마무리해. \
                    즉 정리하자면 출력 형태는 '<reasoning> ...추론 내용... </reasoning> <translate> 검토한 영어 번역문 </translate>' \
                    혹은 '<translate> 검토한 영어 번역문 </translate>' 가 될 거야.\n \
                    그리고 [검토한 영어 번역문]에는 [한국어 대화문]에 속한 모든 대사 개수만큼이 포함되어야 하는 것을 잊지마."
                }
            ],
}

# %%
import re
def extract_translation(text):
    match = re.search(r'<translate>(.*?)</translate>', text, re.DOTALL)
    return match.group(1).strip() if match else None


review_text = f"{input_text}\n\n### review\n\n" 
#en, kor
kor_li = kor.split('\n')
en_li = en.split('\n')
review_li = []
while True:
    if len(review_li) == len(kor_li):
        break
    review_completion = openai_client.beta.chat.completions.parse(
        model= GPT_BASE_MODEL,
        messages = [
            SYSTEM_REVIEW_PROMPT,
            {
                "role":"user",
                "content" : [{"type" : "text",
                              "text" : input_text
                            }],
            }
        ],
        temperature= 0.2,
        top_p = 0.8
    )
    review = review_completion.choices[0].message.content
    print(review)
    review_li = extract_translation(review).split('\n')
# Out:
# <reasoning>
# [대사 문단]을 찾기 위해 [한국어 대화문]을 분석한다.
#
# 우선 (000~003)은 편지 형식의 초대 문구로, 동일한 화자가 연속적으로 발화한 것으로 보이며, 각 대사가 불완전하거나 연결된 문장으로 보인다. 결합하면 "『금일 오후, 온실에서 있을 티 파티에 영애를 초대하고 싶습니다.』 『시간이 나신다면 꼭 참석해 주세요, 헤더 아덴 자작 영애.』"로 한 문장이 된다. 따라서 (000~003)은 하나의 [대사 문단]이다.
#
# (004~005)는 "이 사람, 어제 시그렌이랑 일이 있었던 그 영애 아냐?"로 연결되며, 동일 화자이고, 결합 시 한 문장이 된다. (004~005)는 [대사 문단]이다.
#
# (006)은 독립된 완전한 문장이다. (007~008)은 "내가 괜히 신경 쓸 만한 이유는 없지. 잘못한 건 그쪽이고."로 두 문장이므로 [대사 문단]이 될 수 없다.
#
# (009)은 독립된 문장이다.
#
# (010~011)은 "기쁜 마음으로 응하겠다고 전해줘. 유니스 영애."로 연결되며, 동일 화자이고, 결합 시 한 문장이 된다. [대사 문단]이다.
#
# (012)은 감탄사성 독립 대사. (013~014)는 질문과 대답으로 서로 다른 화자이므로 묶을 수 없다.
#
# (015~016)은 "피오나 영애와는 같은 일행임에도 계속 얼굴을 볼 수가 없었네요. 전 말을 타고 있었거든요."로 두 문장이므로 [대사 문단]이 될 수 없다.
#
# (017~018)은 "그래도 마차에도 와 주세요. 혼자서는 심심해서…."로 두 문장이므로 [대사 문단]이 될 수 없다.
#
# (019)은 독립된 문장.
#
# (020~022)은 안내하는 말로, 동일 화자이며, "어서 오십시오. 이쪽이 온실입니다. 아가씨께서는 안쪽에서 기다리고 계십니다."로 세 문장이므로 [대사 문단]이 될 수 없다.
#
# (023~027)은 인사와 환영의 말로, 동일 화자이며, "어머나, 피오나 영애, 유니스 영애… 초대에 응해주셔서 감사해요. 기다리고 있었답니다."로 두 문장이므로 [대사 문단]이 될 수 없다.
#
# (028~029)는 감탄과 판단으로, "와, 역시 화려한 미인이야. 이런 사람이 시그렌에게 달려들었단 말이지."로 두 문장이므로 [대사 문단]이 될 수 없다.
#
# (030~031)은 서로 다른 화자이므로 묶을 수 없다.
#
# (032~033)은 동일 화자이며, "이쪽은 근처 영지의 영애들이에요. 명성이 자자한 두 분을 만나서 영광이에요."로 두 문장이므로 [대사 문단]이 될 수 없다.
#
# (034~035)은 동일 화자이며, "네… 잘 부탁해요."로 두 문장이므로 [대사 문단]이 될 수 없다.
#
# (036~037)은 동일 화자이며, "뭐지? 묘하게 시선이 불온한 것 같은 느낌이…."로 두 문장이므로 [대사 문단]이 될 수 없다.
#
# (038~039)은 질문과 대답으로 서로 다른 화자이므로 묶을 수 없다.
#
# (040~041)은 질문과 설명으로 두 문장이므로 [대사 문단]이 될 수 없다.
#
# (042)은 독립된 문장.
#
# (043)은 감탄문.
#
# (044~049)은 루머에 대한 언급으로, 동일 화자이며, "소문 이야기가 나와서 말인데요, 듣자 하니… 영애의 핏줄은 조금 특별하다면서요? 본래는 헤일론 쪽이 아니라고 들었어요. 제가 알기로는, 사생아라던데."로 결합 시 한 문장이 된다. [대사 문단]이다.
#
# (050~052)은 동일 화자이며, "네, 맞는 말이에요. 전 사생아입니다. 정확히 알고 계시네요."로 세 문장이므로 [대사 문단]이 될 수 없다.
#
# (053~054)은 감탄과 연결된 말이지만, (055~056)까지 포함하면 "게다가 그 본가는… 네. 마약 사업 혐의로 재산을 몰수당했죠. 제가 직접 고발한 일이고요."로 세 문장이므로 [대사 문단]이 될 수 없다.
#
# (057~059)은 동일 화자이며, "세상에, 저라면 도저히 못할 거예요. 무슨 이유에서든 가족을 자기 손으로 배신하는 건… 짐승이나 할 짓이죠."로 세 문장이므로 [대사 문단]이 될 수 없다.
#
# (060~061)은 감탄과 호명으로, 결합 시 한 문장이 되지 않음.
#
# (062~066)은 동일 화자이며, "그래서, 하고 싶은 말이 뭔가요? 적당히 하라는 소리예요! 운 좋게 양녀가 되었다고 해도, 귀족 영애라면 정도를 지켜야죠."로 세 문장이므로 [대사 문단]이 될 수 없다.
#
# (067~068)은 "…해서, … 영애도……"로 불완전한 대사이며, 결합 시 한 문장이 되지 않음.
#
# (069)은 시그렌의 이름만 언급된 불완전한 대사.
#
# (070~072)은 동일 화자이며, "피오나 영애 왜 딴 곳을 보시죠. 지금 제가 말하고 있는 게 안 보이나요? 아직 할 말이 더 있답니다."로 세 문장이므로 [대사 문단]이 될 수 없다.
#
# (073~075)는 "영애, 남의 저택에서 신세를 지고 있는 와중에 전하께 꼬리를 치셨죠? 제 하녀가 말해주었단 말이에요. 어젯밤에-"로 세 문장이므로 [대사 문단]이 될 수 없다.
#
# (076~077)은 서로 다른 화자이므로 묶을 수 없다.
#
# (078~079)은 동일 화자이며, "심하긴 뭐가 심해요. 저는 그저 사실을 말하는 것뿐…"으로 두 문장이므로 [대사 문단]이 될 수 없다.
#
# (080~081)은 감탄사.
#
# (082~086)은 동일 화자이며, "영애의 말은 다 맞아요. 전 사생아고, 제가 태어난 가문도 직접 부수었죠. 하지만 똑똑한 아덴 영애가 하나 파악하지 못한 게 있네요. 저는 그 덕분에 권력과 힘, 두 개 다 가지고 있답니다."로 네 문장이므로 [대사 문단]이 될 수 없다.
#
# (087~088)은 동일 화자이며, "지금 이 자리에서 제가 영애의 머리카락을 불태워도 아덴 자작님은 제 아버지께 항의서 몇 장 보내는 게 고작일 거란 뜻이죠."로 한 문장이므로 [대사 문단]이다.
#
# (089~090)은 동일 화자이며, "망아지처럼 구는 것도 상대를 보면서 하세요. 그러다 목 잘려요."로 두 문장이므로 [대사 문단]이 될 수 없다.
#
# (091~093)은 감탄과 호명으로, 결합 시 한 문장이 되지 않음.
#
# (094~095)은 동일 화자이며, "티파티가 꽤나 즐거워 보이는군. 헤더 아덴 영애."로 한 문장이므로 [대사 문단]이다.
#
# (096)은 감탄사.
#
# (097)은 독립된 문장.
#
# (098~100)은 동일 화자이며, "마지막으로 충고 하나 할게요. 남의 남자 탐내지 마세요. 이건 지금 내 거거든."으로 세 문장이므로 [대사 문단]이 될 수 없다.
#
# 최종 [대사 문단]은 다음과 같다:
# [(000~003, '『금일 오후, 온실에서 있을 티 파티에 영애를 초대하고 싶습니다.』 『시간이 나신다면 꼭 참석해 주세요, 헤더 아덴 자작 영애.』'),
#  (004~005, '이 사람, 어제 시그렌이랑 일이 있었던 그 영애 아냐?'),
#  (010~011, '기쁜 마음으로 응하겠다고 전해줘. 유니스 영애.'),
#  (044~049, '소문 이야기가 나와서 말인데요, 듣자 하니 영애의 핏줄은 조금 특별하다면서요? 본래는 헤일론 쪽이 아니라고 들었어요. 제가 알기로는, 사생아라던데.'),
#  (087~088, '지금 이 자리에서 제가 영애의 머리카락을 불태워도 아덴 자작님은 제 아버지께 항의서 몇 장 보내는 게 고작일 거란 뜻이죠.'),
#  (094~095, '티파티가 꽤나 즐거워 보이는군. 헤더 아덴 영애.')]
#
# 이제 각 [대사 문단]에 해당하는 [1차 번역문]을 확인한다.
#
# (000~003): "I would like to invite you, my lady, to a tea party in the greenhouse this afternoon.” “Please attend if you have time, lady heather adens.” → 의미 일치. 4개 대사이므로 4분할.
#
# (004~005): "isn’t this... the lady from yesterday who was with siegren?" → 의미 일치. 2개 대사이므로 2분할.
#
# (010~011): "tell her I’ll be happy to attend, lady eunice." → 의미 일치. 2개 대사이므로 2분할.
#
# (044~049): "speaking of rumors, I heard... that you have a special bloodline. I heard you’re not originally from house hylon. from what I know, you’re an illegitimate child." → 의미 일치. 6개 대사이므로 6분할.
#
# (087~088): "that means even if I burn your hair right now, the most your father would do is send a few letters of complaint to my father." → 의미 일치. 2개 대사이므로 2분할.
#
# (094~095): "it looks like you’re having a lot of fun at this tea party, lady heather adens." → 의미 일치. 2개 대사이므로 2분할.
#
# </reasoning>
# <translate>
# 000	“I would like...
# 001	...to invite you, my lady,...
# 002	...to a tea party in the greenhouse this afternoon.”
# 003	...Please attend if you have time, lady heather adens.”
# 004	isn’t this...
# 005	...the lady from yesterday who was with siegren?
# 006	is it okay for me to go to a tea party hosted by her?
# 007	well, I don’t see why I shouldn’t.
# 008	she’s the one who did something wrong.
# 009	and I might be able to see eunice there.
# 010	tell her I’ll be happy to attend...
# 011	...lady eunice.
# 012	lady fiona...!
# 013	were you invited as well?
# 014	yes.
# 015	we’re traveling together, but I haven’t been able to see you.
# 016	I’ve been riding a horse.
# 017	please come to the carriage sometimes...
# 018	it’s boring being alone...
# 019	she must have been lonely because she was surrounded by knights and soldiers.
# 020	welcome.
# 021	this way to the greenhouse.
# 022	my lady is waiting inside.
# 023	oh my,
# 024	lady fiona,
# 025	lady eunice...
# 026	thank you for accepting my invitation.
# 027	I’ve been waiting for you.
# 028	wow, she’s really pretty.
# 029	she’s the one who tried to get with siegren.
# 030	please, have a seat.
# 031	thank you.
# 032	these are ladies from nearby lands.
# 033	it’s an honor to meet you both.
# 034	yes...
# 035	it’s nice to meet you.
# 036	what’s this?
# 037	I feel like they’re looking at me strangely...
# 038	I heard you were in the north, lady fiona.
# 039	yes, I was.
# 040	wasn’t it hard?
# 041	I heard a very barbaric and cruel sorcerer lives there...
# 042	it’s just like any other place where people live.
# 043	wait, that rumor reached all the way here?!
# 044	speaking of rumors...
# 045	...I heard...
# 046	...that you have a special bloodline.
# 047	...I heard you’re not originally from house hylon.
# 048	...from what I know...
# 049	...you’re an illegitimate child.
# 050	yes, you’re right.
# 051	I am an illegitimate child.
# 052	you know exactly who I am.
# 053	she’s smiling?
# 054	and your original family...
# 055	yes, their wealth was confiscated for drug trafficking.
# 056	I was the one who reported them.
# 057	my goodness, I would never be able to do that.
# 058	betraying your family with your own hands for whatever reason...
# 059	...is something only a beast would do.
# 060	w-wait!
# 061	lady fiona...
# 062	so,
# 063	what are you trying to say?
# 064	I’m telling you to know your place!
# 065	even if you were lucky enough to be adopted,
# 066	you should know your place as a noble lady.
# 067	so...
# 068	...you should...
# 069	siegren.
# 070	lady fiona, why are you looking elsewhere?
# 071	can’t you see I’m talking to you?
# 072	I’m not done talking.
# 073	my lady,
# 074	you tried to seduce his highness while staying in someone else’s manor, didn’t you?
# 075	my maid told me about last night--
# 076	wait.
# 077	lady heather, you’re going too far!
# 078	what do you mean?
# 079	I’m just stating the facts--
# 080	ah,
# 081	aaah!
# 082	you’re right about everything.
# 083	I’m an illegitimate child, and I destroyed the family I was born into.
# 084	but there’s one thing you didn’t realize, lady heather.
# 085	because of that, I now have both power...
# 086	...and strength.
# 087	that means even if I burn your hair right now...
# 088	...the most your father would do is send a few letters of complaint to my father.
# 089	know your place before you start acting like a brat.
# 090	you might lose your head.
# 091	and...
# 092	your...
# 093	your highness...
# 094	it looks like you’re having a lot of fun at this tea party...
# 095	...lady heather adens.
# 096	I-I...
# 097	she can’t even look at him after what happened yesterday.
# 098	let me give you one last piece of advice.
# 099	don’t go after someone else’s man.
# 100	he’s mine.
# </translate>

# %%
for k, e, r in zip(kor_li, en_li, review_li):
    if e != r:
        print(f'[한글] {k}')
        print(f'[1차 번역]{e}')
        print(f'[리뷰]{r}')
        print()
# Out:
# [한글] 000	『금일 오후,
# [1차 번역]000	“I would like to invite you, my lady,
# [리뷰]000	“I would like...
#
# [한글] 001	온실에서 있을 티 파티에 영애를 초대하고 싶습니다.』
# [1차 번역]001	to a tea party in the greenhouse this afternoon.”
# [리뷰]001	...to invite you, my lady,...
#
# [한글] 002	『시간이 나신다면 꼭 참석해 주세요,
# [1차 번역]002	“Please attend if you have time,
# [리뷰]002	...to a tea party in the greenhouse this afternoon.”
#
# [한글] 003	헤더 아덴 자작 영애.』
# [1차 번역]003	lady heather adens.”
# [리뷰]003	...Please attend if you have time, lady heather adens.”
#
# [한글] 010	기쁜 마음으로 응하겠다고 전해줘.
# [1차 번역]010	tell her I’ll be happy to attend,
# [리뷰]010	tell her I’ll be happy to attend...
#
# [한글] 011	유니스 영애.
# [1차 번역]011	lady eunice.
# [리뷰]011	...lady eunice.
#
# [한글] 044	소문 이야기가 나와서 말인데요,
# [1차 번역]044	speaking of rumors,
# [리뷰]044	speaking of rumors...
#
# [한글] 045	듣자 하니…
# [1차 번역]045	I heard...
# [리뷰]045	...I heard...
#
# [한글] 047	본래는 헤일론 쪽이 아니라고 들었어요.
# [1차 번역]047	I heard you’re not originally from house hylon.
# [리뷰]047	...I heard you’re not originally from house hylon.
#
# [한글] 048	제가 알기로는,
# [1차 번역]048	from what I know,
# [리뷰]048	...from what I know...
#
# [한글] 049	사생아라던데.
# [1차 번역]049	you’re an illegitimate child.
# [리뷰]049	...you’re an illegitimate child.
#
# [한글] 087	지금 이 자리에서 제가 영애의 머리카락을 불태워도
# [1차 번역]087	that means even if I burn your hair right now,
# [리뷰]087	that means even if I burn your hair right now...
#
# [한글] 088	아덴 자작님은 제 아버지께 항의서 몇 장 보내는 게 고작일 거란 뜻이죠.
# [1차 번역]088	the most your father would do is send a few letters of complaint to my father.
# [리뷰]088	...the most your father would do is send a few letters of complaint to my father.
#
# [한글] 094	티파티가 꽤나 즐거워 보이는군.
# [1차 번역]094	it looks like you’re having a lot of fun at this tea party,
# [리뷰]094	it looks like you’re having a lot of fun at this tea party...
#
# [한글] 095	헤더 아덴 영애.
# [1차 번역]095	lady heather adens.
# [리뷰]095	...lady heather adens.
